# %% [markdown]
# # Temporal and Spatial Analysis of Red Alerts in Israel
#
# 1. **Data extraction**
# 2. **Data preprocessing**
#    - Creating a general dataset
#    - Creating a dataset with an indication of detailed localities
#    - Creating a dataset where zones of large cities are combined into a single record
# 3. **Conclusion**

# %% [markdown]
# # Data extraction
#
# The data used in this analysis was obtained from the [Cumta Telegram channel](https://t.me/CumtaAlertsEnglishChannel), which provides real-time alerts about rocket sirens (Red Alerts) in Israel. The channel broadcasts information about alerts, including affected regions, cities, and timestamps. The dataset consists of extracted historical messages from this channel for further analysis and visualization.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os
import re
from collections import Counter
from scipy.interpolate import make_interp_spline
import numpy as np

# %%
# Path to the folder containing files
path_to_files = r"C:\Users\Vera\Documents\DA Practicum\work files\datasets\cumta_2"

# Create an empty list to store data
data = []

# Iterate over all files with the prefix 'messages'
for file in os.listdir(path_to_files):
    if file.startswith('messages') and file.endswith('.html'):
        # Open the file in UTF-8 encoding
        with open(os.path.join(path_to_files, file), 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f, 'html.parser')
            
            # Process messages and find associated dates
            for msg in soup.find_all('div', class_='text'):
                # Find the nearest previous date element
                date = msg.find_previous('div', class_='pull_right date details')
                data.append({
                    'date': date['title'] if date and 'title' in date.attrs else None,
                    'text': msg.text.strip()
                })

# Convert the collected data into a DataFrame
raw_df = pd.DataFrame(data)

raw_df
# Out:
#                                date  \
# 0                              None
# 1     26.12.2018 11:05:08 UTC+03:00
# 2     02.01.2019 11:05:05 UTC+03:00
# 3     07.01.2019 04:18:52 UTC+03:00
# 4     09.01.2019 11:39:23 UTC+03:00
# ...                             ...
# 7688  08.06.2024 10:46:43 UTC+03:00
# 7689  08.06.2024 10:47:54 UTC+03:00
# 7690  08.06.2024 10:50:11 UTC+03:00
# 7691  08.06.2024 11:38:47 UTC+03:00
# 7692  08.06.2024 12:59:20 UTC+03:00
#
#                                                    text
# 0                                    Red Alerts - Cumta
# 1     Red Alert at Dan (155,156,157,158,159,160,161,...
# 2     Red Alert at Eilat 311, Arabah 310 [10:05]: 02...
# 3     Red Alert at Lakhish 246 [03:18]: 07/01/2019 0...
# 4     Good morning,Starting this week the Home Front...
# ...                                                 ...
# 7688  Red Alert at Zarit [10:46]:08/06/2024 10:46:42...
# 7689  Red Alert at Zarit [10:47]:08/06/2024 10:47:53...
# 7690  Red Alert at Zarit [10:49]:08/06/2024 10:49:22...
# 7691  Unrecognized Aircraft at HaGalil HaElyon, Mero...
# 7692  Red Alert at Kissufim [12:59]:08/06/2024 12:59...
#
# [7693 rows x 2 columns]

# %% [markdown]
# #  Data preprocessing
# ## Creating a general dataset

# %%
# Convert the 'date' column to datetime format with dayfirst=True
raw_df['date'] = pd.to_datetime(raw_df['date'], dayfirst=True)

# Sort the DataFrame by date in ascending order
raw_df = raw_df.sort_values(by='date', ascending=True).reset_index(drop=True)

# Checking the minimum and maximum dates in the dataset
print(f"Minimum date: {raw_df['date'].min()}")
print(f"Maximum date: {raw_df['date'].max()}")
# Out:
# Minimum date: 2018-12-26 11:05:08+03:00
# Maximum date: 2025-10-05 18:35:50+03:00

# %%
# Check
raw_df
# Out:
#                           date  \
# 0    2018-12-26 11:05:08+03:00
# 1    2019-01-02 11:05:05+03:00
# 2    2019-01-07 04:18:52+03:00
# 3    2019-01-09 11:39:23+03:00
# 4    2019-01-12 21:59:18+03:00
# ...                        ...
# 7688                       NaT
# 7689                       NaT
# 7690                       NaT
# 7691                       NaT
# 7692                       NaT
#
#                                                    text
# 0     Red Alert at Dan (155,156,157,158,159,160,161,...
# 1     Red Alert at Eilat 311, Arabah 310 [10:05]: 02...
# 2     Red Alert at Lakhish 246 [03:18]: 07/01/2019 0...
# 3     Good morning,Starting this week the Home Front...
# 4     Red Alert at Gaza Containment Zone (224,225) [...
# ...                                                 ...
# 7688                                 Red Alerts - Cumta
# 7689                                 Red Alerts - Cumta
# 7690                                 Red Alerts - Cumta
# 7691                                 Red Alerts - Cumta
# 7692                                 Red Alerts - Cumta
#
# [7693 rows x 2 columns]

# %%
# Delete rows where the value in the date column is NaT
raw_df = raw_df.dropna(subset=['date']).reset_index(drop=True)
raw_df
# Out:
#                           date  \
# 0    2018-12-26 11:05:08+03:00
# 1    2019-01-02 11:05:05+03:00
# 2    2019-01-07 04:18:52+03:00
# 3    2019-01-09 11:39:23+03:00
# 4    2019-01-12 21:59:18+03:00
# ...                        ...
# 7672 2025-10-01 14:00:45+03:00
# 7673 2025-10-01 20:49:07+03:00
# 7674 2025-10-05 04:59:22+03:00
# 7675 2025-10-05 18:34:40+03:00
# 7676 2025-10-05 18:35:50+03:00
#
#                                                    text
# 0     Red Alert at Dan (155,156,157,158,159,160,161,...
# 1     Red Alert at Eilat 311, Arabah 310 [10:05]: 02...
# 2     Red Alert at Lakhish 246 [03:18]: 07/01/2019 0...
# 3     Good morning,Starting this week the Home Front...
# 4     Red Alert at Gaza Containment Zone (224,225) [...
# ...                                                 ...
# 7672  Red Alert at Sha'ar HaNegev, Sdot Negev [14:00...
# 7673  Red Alert at Ashdod, Hof Ashkelon [20:48]:01/1...
# 7674  Red Alert at Beit Shemesh, Lod, Ness Ziona, Mo...
# 7675  Red Alert at Eilat [18:34]:05/10/2025 18:34:40...
# 7676  Unrecognized Aircraft at Eilat [18:32]:05/10/2...
#
# [7677 rows x 2 columns]

# %%
# Display general information 
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7677 entries, 0 to 7676
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7677 non-null   datetime64[ns, UTC+03:00]
#  1   text    7677 non-null   object
# dtypes: datetime64[ns, UTC+03:00](1), object(1)
# memory usage: 120.1+ KB

# %%
# --- Hidden because of the large size ---
# Let's see the whole dataframe
#raw_df.to_string()

# %%
# A function for determining the type of threat
def extract_threat_type(text):
    if text.startswith("Red Alert") or text.startswith("An alert"):
        return "Red Alert"
    elif text.startswith("Unrecognized Aircraft"):
        return "Unrecognized Aircraft"
    elif text.startswith("An unrecognized aircraft"):
        return "Unrecognized Aircraft"
    elif text.startswith("Terrorist Infiltration"):
        return "Terrorist Infiltration"
    elif text.startswith("Earthquake"):
        return "Earthquake"
    elif text.startswith("Interception pieces"):
        return "Interception pieces"
    return None

# Removing update messages (starting with 'Good morning', 'Dear' or similar)
raw_df = raw_df[~raw_df['text'].str.lower().str.startswith(('good', 'starting', 
                                                            'dear', "home", 
                                                            'a new'))].reset_index(drop=True)

raw_df = raw_df.copy()
raw_df['threat_type'] = raw_df['text'].apply(extract_threat_type)

# %%
# A function for extracting a region
def extract_region(text):
    match = re.search(r'at (.*?) \[\d{2}:\d{2}\]', text)
    return match.group(1).strip() if match else None

# A function for extracting time
def extract_time(text):
    match = re.search(r'\[(\d{2}:\d{2})\]', text)
    return match.group(1) if match else None

# Functions for extracting major cities and regional councils

def extract_major_cities(text):
    match = re.search(r'[Mm]ajor [Cc]ities: (.+?)(?:\|\||$)', text)
    return match.group(1).strip() if match else None

def extract_regional_councils(text):
    match = re.search(r'Regional Councils: (.+?)\|\|', text)
    return match.group(1).strip() if match else None

# Adding new columns
raw_df['region'] = raw_df['text'].apply(extract_region)
raw_df['major_cities'] = raw_df['text'].apply(extract_major_cities)
raw_df['regional_councils'] = raw_df['text'].apply(extract_regional_councils)

# Resetting the index for the resulting DataFrame
raw_df.reset_index(drop=True, inplace=True)

# %%
# Check
raw_df
# Out:
#                           date  \
# 0    2018-12-26 11:05:08+03:00
# 1    2019-01-02 11:05:05+03:00
# 2    2019-01-07 04:18:52+03:00
# 3    2019-01-12 21:59:18+03:00
# 4    2019-02-06 11:05:01+03:00
# ...                        ...
# 7662 2025-10-01 14:00:45+03:00
# 7663 2025-10-01 20:49:07+03:00
# 7664 2025-10-05 04:59:22+03:00
# 7665 2025-10-05 18:34:40+03:00
# 7666 2025-10-05 18:35:50+03:00
#
#                                                    text  \
# 0     Red Alert at Dan (155,156,157,158,159,160,161,...
# 1     Red Alert at Eilat 311, Arabah 310 [10:05]: 02...
# 2     Red Alert at Lakhish 246 [03:18]: 07/01/2019 0...
# 3     Red Alert at Gaza Containment Zone (224,225) [...
# 4     Red Alert at Jerusalem 194, Maale Adumim 200, ...
# ...                                                 ...
# 7662  Red Alert at Sha'ar HaNegev, Sdot Negev [14:00...
# 7663  Red Alert at Ashdod, Hof Ashkelon [20:48]:01/1...
# 7664  Red Alert at Beit Shemesh, Lod, Ness Ziona, Mo...
# 7665  Red Alert at Eilat [18:34]:05/10/2025 18:34:40...
# 7666  Unrecognized Aircraft at Eilat [18:32]:05/10/2...
#
#                 threat_type  \
# 0                 Red Alert
# 1                 Red Alert
# 2                 Red Alert
# 3                 Red Alert
# 4                 Red Alert
# ...                     ...
# 7662              Red Alert
# 7663              Red Alert
# 7664              Red Alert
# 7665              Red Alert
# 7666  Unrecognized Aircraft
#
#                                                  region  \
# 0     Dan (155,156,157,158,159,160,161,162,165), Sha...
# 1                                 Eilat 311, Arabah 310
# 2                                           Lakhish 246
# 3                       Gaza Containment Zone (224,225)
# 4          Jerusalem 194, Maale Adumim 200, Samaria 127
# ...                                                 ...
# 7662                         Sha'ar HaNegev, Sdot Negev
# 7663                               Ashdod, Hof Ashkelon
# 7664  Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabi...
# 7665                                              Eilat
# 7666                                              Eilat
#
#                                            major_cities  \
# 0     Tel Aviv, Holon, Herzliya, Ramat Gan, Bnei Bra...
# 1                                                 Eilat
# 2                                              Ashkelon
# 3                                                  None
# 4                              Jerusalem, Ma'ale Adumim
# ...                                                 ...
# 7662                                               None
# 7663                                             Ashdod
# 7664  Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabi...
# 7665                                              Eilat
# 7666                                              Eilat
#
#                           regional_councils
# 0                           Southern Sharon
# 1     Hevel Eilot, Tamar, HaArava HaTichona
# 2                              Hof Ashkelon
# 3                Sdot Negev, Sha'ar HaNegev
# 4               Gush Etzion, Mateh Binyamin
# ...                                     ...
# 7662                                   None
# 7663                                   None
# 7664                                   None
# 7665                                   None
# 7666                                   None
#
# [7667 rows x 6 columns]

# %% [markdown]
# ### 1 st october 2024 check
# Let's check how strings are stored during very powerful attacks, when a lot of settlements were involved.

# %%
# looking at the lines with the date of October 1, 2024 from 19 to 20 (the Iranian attack)
raw_df[
    (raw_df['date'] >= '2024-10-01 19:00:00') &
    (raw_df['date'] < '2024-10-01 20:00:00')
]
# Out:
#                           date  \
# 5640 2024-10-01 19:31:39+03:00
# 5641 2024-10-01 19:35:36+03:00
# 5642 2024-10-01 19:35:37+03:00
# 5643 2024-10-01 19:35:37+03:00
# 5644 2024-10-01 19:35:38+03:00
# 5645 2024-10-01 19:40:17+03:00
# 5646 2024-10-01 19:40:17+03:00
# 5647 2024-10-01 19:40:18+03:00
# 5648 2024-10-01 19:40:18+03:00
# 5649 2024-10-01 19:40:25+03:00
# 5650 2024-10-01 19:40:25+03:00
# 5651 2024-10-01 19:40:29+03:00
# 5652 2024-10-01 19:40:29+03:00
# 5653 2024-10-01 19:40:35+03:00
# 5654 2024-10-01 19:42:45+03:00
# 5655 2024-10-01 19:42:45+03:00
# 5656 2024-10-01 19:42:46+03:00
# 5657 2024-10-01 19:42:47+03:00
# 5658 2024-10-01 19:42:51+03:00
# 5659 2024-10-01 19:46:05+03:00
# 5660 2024-10-01 19:46:09+03:00
# 5661 2024-10-01 19:52:31+03:00
# 5662 2024-10-01 19:52:32+03:00
# 5663 2024-10-01 19:52:33+03:00
# 5664 2024-10-01 19:52:33+03:00
# 5665 2024-10-01 19:52:34+03:00
# 5666 2024-10-01 19:52:34+03:00
# 5667 2024-10-01 19:52:35+03:00
# 5668 2024-10-01 19:53:12+03:00
# 5669 2024-10-01 19:59:09+03:00
# 5670 2024-10-01 19:59:09+03:00
# 5671 2024-10-01 19:59:12+03:00
# 5672 2024-10-01 19:59:20+03:00
#
#                                                    text threat_type  \
# 5640  Red Alert at Be'er Sheva, Kiryat Arba, Arad, Y...   Red Alert
# 5641  Red Alert at Gdera, Yavne, Tel Aviv - Jaffa, O...   Red Alert
# 5642  • Lachish - Kedma, Ad Halom Industrial Zone, M...        None
# 5643  • Sharon - Bnei Zion, Ahituv, Bitan Aharon, Ne...        None
# 5644  • Center Negev - Laqiya, Beer Sheva - East, Be...        None
# 5645  Red Alert at Kiryat Arba, Dimona, Hevron Jewis...   Red Alert
# 5646  Red Alert at Kiryat Arba, Dimona, Hevron Jewis...   Red Alert
# 5647  • West Lachish - Ashkelon Northern Industrial ...        None
# 5648  • West Lachish - Ashkelon Northern Industrial ...        None
# 5649  • Bika'a - Niran, Tomer, Petza'el, Argaman, Ma...        None
# 5650  • Bika'a - Niran, Tomer, Petza'el, Argaman, Ma...        None
# 5651  • Sharon - Geulim, HaMa'apil, Netanya - West, ...        None
# 5652  • Sharon - Geulim, HaMa'apil, Netanya - West, ...        None
# 5653  • Wadi Ara - Ayn al-Sahla, Kfar Kara, Ramot Me...        None
# 5654  Red Alert at Yehud - Monoson, Modi'in-Maccabim...   Red Alert
# 5655  • Shomron - Eli, Amichai, Ofra, Paduel, Psagot...        None
# 5656  • Yehuda - Rosh Tzurim, Bat Ayin, Abu-Nuwar, M...        None
# 5657  Red Alert at Yehud - Monoson, Modi'in-Maccabim...   Red Alert
# 5658  • Center Negev - Hura, Kramim, AlSayid • Yehud...        None
# 5659  Red Alert at Rishon LeZion, Ramat Gan, Ramat H...   Red Alert
# 5660  • Dead Sea - Dead Sea Hotels - Center, Ein Bok...        None
# 5661  Red Alert at Be'er Sheva, Or Akiva, umm al-Fah...   Red Alert
# 5662  • Jerusalem - Even Sapir, Jerusalem - North, O...        None
# 5663  • Sharon - Hadar Am, Azriel, Gelilot - Pi Comp...        None
# 5664  • HaShfela - Ge'alya01/10/2024 19:50:48: • Sou...        None
# 5665  • Yehuda - Asa'el, Adorayim, Hevron Jewish Set...        None
# 5666  • Wadi Ara - Yokneam Moshava and HaZoreah, Yok...        None
# 5667  || Major cities: Be'er Sheva, Or Akiva, umm al...        None
# 5668  Red Alert at Dimona, Golan, HaGalil HaTahton, ...   Red Alert
# 5669  Red Alert at Be'er Sheva, Beit Shemesh, Beitar...   Red Alert
# 5670  • Center Negev - Dvira Junction, Shoval, Beit ...        None
# 5671  • Center Negev - Dvira Junction, Shoval, Beit ...        None
# 5672  • Center Negev - Dvira Junction, Shoval, Beit ...        None
#
#                                                  region  \
# 5640  Be'er Sheva, Kiryat Arba, Arad, Yeruham, Dimon...
# 5641  Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bne...
# 5642                                               None
# 5643                                               None
# 5644                                               None
# 5645  Kiryat Arba, Dimona, Hevron Jewish Settlement,...
# 5646  Kiryat Arba, Dimona, Hevron Jewish Settlement,...
# 5647                                               None
# 5648                                               None
# 5649                                               None
# 5650                                               None
# 5651                                               None
# 5652                                               None
# 5653                                               None
# 5654  Yehud - Monoson, Modi'in-Maccabim-Re'ut, Shoha...
# 5655                                               None
# 5656                                               None
# 5657  Yehud - Monoson, Modi'in-Maccabim-Re'ut, Shoha...
# 5658                                               None
# 5659  Rishon LeZion, Ramat Gan, Ramat HaSharon, Ra'a...
# 5660                                               None
# 5661  Be'er Sheva, Or Akiva, umm al-Fahm, Pardes Han...
# 5662                                               None
# 5663                                               None
# 5664                                               None
# 5665                                               None
# 5666                                               None
# 5667                                               None
# 5668  Dimona, Golan, HaGalil HaTahton, Misgav, Emek ...
# 5669  Be'er Sheva, Beit Shemesh, Beitar Illit, Jerus...
# 5670                                               None
# 5671                                               None
# 5672                                               None
#
#                                            major_cities regional_councils
# 5640  Be'er Sheva, Kiryat Arba, Arad, Yeruham, Dimon...              None
# 5641                                               None              None
# 5642                                               None              None
# 5643                                               None              None
# 5644  Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bne...              None
# 5645                                               None              None
# 5646                                               None              None
# 5647                                               None              None
# 5648                                               None              None
# 5649                                               None              None
# 5650                                               None              None
# 5651                                               None              None
# 5652                                               None              None
# 5653  Kiryat Arba, Dimona, Hevron Jewish Settlement,...              None
# 5654                                               None              None
# 5655                                               None              None
# 5656  Yehud - Monoson, Modi'in-Maccabim-Re'ut, Shoha...              None
# 5657                                               None              None
# 5658                                               None              None
# 5659                                               None              None
# 5660  Rishon LeZion, Ramat Gan, Ramat HaSharon, Ra'a...              None
# 5661                                               None              None
# 5662                                               None              None
# 5663                                               None              None
# 5664                                               None              None
# 5665                                               None              None
# 5666                                               None              None
# 5667  Be'er Sheva, Or Akiva, umm al-Fahm, Pardes Han...              None
# 5668                                             Dimona              None
# 5669                                               None              None
# 5670  Be'er Sheva, Beit Shemesh, Beitar Illit, Jerus...              None
# 5671  Be'er Sheva, Beit Shemesh, Beitar Illit, Jerus...              None
# 5672  Be'er Sheva, Beit Shemesh, Beitar Illit, Jerus...              None

# %%
# Checking the text in the 'text' column (row 5643)
raw_df.loc[5641, 'text']
# Out:
# "Red Alert at Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Herzeliya, Holon, Yehud - Monoson, Kfar Shmaryahu, Modi'in-Maccabim-Re'ut, Mikveh Israel, Ariel, Rishon LeZion, Ramat Gan, Or Akiva, Be'er Yacov, Pardes Hanna - Karkur, Ramla, Hadera, Ramat HaSharon, Kfar Saba, Lod, Hod HaSharon, Rosh HaAyin, Ness Ziona, Elad, Netanya, Kfar Kassem, Petach Tikva, Tira, Qalansawe, Rehovot, Caesarea, Shoham, Kiryat Ono, Karnei Shomron, Ra'anana, Savyon, bqa al-Gharbiyye, Kadima-Zoran, Tayibe, Ashdod, Kiryat Gat, Gan Yavne, Kiryat Malachi, Jerusalem, Beit Shemesh, Beitar Illit, Mevasseret Zion, Ashkelon, Ofakim, Be'er Sheva, Sderot, Yeruham, Netivot, Arad, Hevel Yavne, R.C. Be'er Tuvia, Gederot, Brenner, Nahal Sorek, Gan Raveh, Yoav, Emek Hefer, Drom HaSharon, Hevel Modi'in, Mateh Binyamin, Gezer, Hof HaSharon, Sdot Dan, Shomron, Lev HaSharon, Menashe, Hof HaCarmel, Mateh Yehuda, Lakhish, Shafir, Hof Ashkelon, Gush Etzion, Sha'ar HaNegev, Merhavim, Bnei Shimon, Ramat Negev, Neve Midbar, Har Hevron, Sdot Negev, Eshkol [19:32]:01/10/2024 19:32:54: • Lachish - Givat Washington, Neveh Mivtach, Kfar Aviv, Bnaya, Maon Tzofia, Ben Zakai, Gan HaDarom, Hafetz Haim, Asseret, Kfar HaNagid, Bnei Ayish, Meishar, Bnei Darom Compound, Kfar Mordechai, Kannot, Kerem BeYavne, Kannot Industrial Zone, Beit Elazari, Bitzaron, Revadim Industrial Zone, Kidron, Gdera, Misgav Dov, Yavne, Hatzav, Ganei Tal, Shdema, Beit Hilkia, Yad Binyamin, Gedera Industrial Area, Agrigada Factory, Kvutzat Yavne, Beit Gamliel, Nir Galim, Bnei Darom, Ashdod - Northen Industrial Zone • HaShfela - Ge'alya01/10/2024 19:32:57: • Dan - Tel Aviv - South and Jaffa, Tel Aviv - East, Tel Aviv - City Center, Tel Aviv - Across the Yarkon, Or Yehuda, Azor, Bnei Brak, Bat-Yam, Givat HaShlosha, Givat Shmuel, Givatayim, Gat Rimon, Herzliya - West, Herzeliya - Center and Glil Yam, Holon, Yehud - Monoson, Kfar Sirkin, Kfar Shmaryahu, Maas, Mikveh Israel • Sharon - Avihail, Givat Hen • HaShfela - Gibton, Gan Shlomo • Yarkon - Gimzo, Hashmonaim, Kfar Daniel, Kfar Rut, Lapid, Mevo Horon, Mevo Modi'im, Modi'in - Ligad Center, Modi'in Maccabim Re'ut, Modi'in Illit, Matityahu, Noff Ayalon01/10/2024 19:32:59: • Shomron - Ariel, Ariel Industrial Park, Havat Gil'ad, Neria, Brukhin, Yakir, Havat Yair, Nofim, Nili, Halamish, Avnei Hefetz, Ofarim, Beit Arie, Kdumim, Paduel, Elei Zahav, Na'aleh, Barkan, Einav, Kiryat Netafim, Karnei Shomron, Bar On Industrial Zone, Barkan Industrial Park, Nachliel, Immanuel, Revava"

# %%
raw_df.loc[5642, 'text']
# Out:
# "• Lachish - Kedma, Ad Halom Industrial Zone, Menucha, Merkaz Shapira, Masuot Itzhak, Nachla, Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Givati, Gat, Aluma, Shafir, Zrahia, Ezer, Nir Banim, Uzza, Emunim, Azrikam, Even Shmuel, Kommemiut, Ashdod - Gimmel, Vav, Zain, Sdeh Moshe, Ashdod - Alef, Bet, Dalet, Heh, Ein Tzurim, Vardon, Shalva, Kiryat Gat - Industrial Zone, Sgula, Sdeh Uziahu, Beit Ezra, Ahuzam, Revacha, Noam, Zavdiel, Shtulim, Ashdod-11,12,15,17,Marine,City, Kiryat Gat , Karmei Gat, Eitan • West Lachish - Nitzanim Beach, Nitzan, Nitzanim01/10/2024 19:33:36: • Lachish - Timorim, Orot, Re'em Industrial Park, Timorimg Industrial Zone, Kiryat Mal'akhi-Yoav train station, Arugot, Revadim, Al Azi, Be'er Tuvia, Be'er Tuvia Industrial Zone, Yinon, Talmei Yehiel, Kfar HaRif and Re'em Junction, Gan Yavne, Lakhish, Kiryat Malachi, Avigdor, Hatzor, Achva, Kfar Warburg, Bnei Re'em, Kfar Achim • Shfelat Yehuda - Galon, Beit Nir, Kfar Menachem, Beit Guvrin, Kfar Zoharim, Sdot Micha, Nehusha, Tzafririm, Zekharia, Srigim-Li On, Tirosh, Ha'Ela Junction, Luzit, Geffen, Agur, Givat Ishayahu, Mata, Aviezer, Kfar Uriah, Kiryat Yearim, Sha’ar HaGai, Yad HaShmona, Tzur Hadassa, Kiryat Ye'arim Youth Village, Aderet, Ksalon, Tzora, Mevo Beitar, Ein Naqquba, Givat Yearim, Bar Giora, Ma'aleh HaHamisha, Kiryat Anavim, Zanoah, Ein Rafa, Nataf, Neveh Michael (Rogalit), Netiv HaLamed-Heh, Giv'ot Eden, Mesillat Zion, Shoeva, Har Tuv - Tzora Industrial Zone, Retorno - Givat Shesh, Taoz, Tarom, Beit Nekofa, Ramat Raziel, Shoresh, Tzuba, Beit Shemesh, Naham, Eshtaol, Mahsiya, Yish'i, Beit Meir, Abu Gosh, Ness Harim, Har Adar, Brosh Industrial Zone, Neveh Ilan • Shomron - Beit Horon, Talmon, Kerem Reim, Dolev, Horasha • Jerusalem - Ora, Givon HaHadasha, Nebi Samuel, Jerusalem - West, Jerusalem - North, Beit Zayit, Jerusalem - South, Givat Ze'ev, Even Sapir, Motza Illit, Mevasseret Zion, Ein Kerem Boarding School, Aminadav • Yehuda - Karmei Tzur, Neveh Daniel, Rosh Tzurim, Bat Ayin, Gvaot, Kfar Etzion, Har Gilo, Alon Shvut, Beitar Illit, Elazar01/10/2024 19:33:36: • Gaza Envelope - Yad Mordechai, Karmia, Or HaNer01/10/2024 19:33:37: • Lachish - Noga, Tlamim, Otzem, Sdeh Yoav, Yad Natan, Nir Chen, Shachar, Negba, Zohar, Nehora, Sdeh David • West Lachish - Hodaya, Heletz, Mishan, Ashkelon - South, Nir Israel, Be'er Ganim, Berekhya, Ashkelon - North, Talmei Yaffe, Beit Shikma, Ashkelon Southern Industrial Zone, Bat Hadar, Ashkelon Northern Industrial Zone, Kokhav Michael, Ge'a, Mavki'im, Kfar Silver • West Negev - Bror Hayil, Rochama • Gaza Envelope - Gvaram01/10/2024 19:34:08: • Jerusalem - Givon HaHadasha, Givat Ze'ev, Nebi Samuel, Even Sapir, Ora • Shfelat Yehuda - Giv'ot Eden, Zanoah, Yish'i, Kfar Uriah, Mahsiya, Mesillat Zion, Neveh Michael (Rogalit), Naham, Netiv HaLamed-Heh, Tzora, Retorno - Givat Shesh, Sha’ar HaGai, Taoz, Tarom, Abu Gosh, Beit Meir, Bar Giora, Givat Yearim, Yad HaShmona, Ksalon, Kiryat Ye'arim Youth Village, Mevo Beitar, Mata • Yehuda - Har Gilo, Kfar Etzion, Karmei Tzur, Neveh Daniel, Rosh Tzurim • Shomron - Beit Horon, Dolev, Talmon01/10/2024 19:34:14: • Sharon - Gan Haim, Ganei Am, Hod HaSharon, Hagor, Horashim, Herut, Tayibe, Tira, Ya'af, Yafhiv, Yarkona, Kokhav Ya'ir - Tzur Yigal, Kafr Bara • HaShfela - Gan Sorek, Yashresh • Dan - Ganei Tikva • Menashe - Hadera - East, Hadera - West, Hadera - Center, Hadera - Neveh Haim01/10/2024 19:34:16: • West Negev - Maslul, Merhavim Educational Campus, Renan, Tifrach, Eshel HaNassi, Daniel, Ofakim, Bitha, Pduim, Duda'im Site, Gilat • Center Negev - Dvira Junction, Shoval, Lehavim, Beit Kama, Lahav, Idan HaNegev Industrial Zone, Tirabin, Dvir, Goral Hills, Giv'ot Bar, Rahat, Mishmar HaNegev01/10/2024 19:34:17:"

# %%
raw_df.loc[5643, 'text']
# Out:
# '• Sharon - Bnei Zion, Ahituv, Bitan Aharon, Neveh Yamin, Matan, Nir Eliyahu, Yafhiv, Sha\'arei Tikva, Zemer, Elishema, Kfar Yona, Yarkona, Haniel, Tzur Itzhak, Gelilot - Pi Compound, Bahan, HaSharon Prison, Bnei Dror, Yad Hana, Kfar Saba, Be\'erotaim, Ramat HaKovesh, Eyal, Mikhmoret, Nitzanei Oz, Beit Herut, Kfar HaRoeh, Geulim, Hagor, Kfar Vitkin, Herev Le\'Et, Hadar Am, Beit Yehoshua, Hod HaSharon, Tel Itzhak, Bat Chen, Elyachin, Havatzelet HaSharon and Tzukei Yam, Alfei Menashe, Kafr Misr, Azriel, Kokhav Ya\'ir - Tzur Yigal, Shfayim "Haneh Ve\'sa" Compound, Netanya - West, Gan Haim, Kfar Hess, Porat, Oranit, Kfar Yavetz, Horashim, Amatz, Batzra, Ein Sarid, Burgata, Tel Mond, HaOgen, Yanuv, Beit Berl, Kfar Kassem, Bat Hefer, Kfar Haim, Even Yehuda, Kfar Avoda, Adanim, Kfar Monash, Shefayim, Ramot HaShavim, Kfar Netter, Tira Industrial Area, Ein HaHoresh, Tira, Beit Yithak - Sha\'ar Hefer, Herut, Salit, Harutzim, Ginot Hadar, Southern Sharon Regional Center, Qalansawe, Ma\'abarot, Neveh Yarak, Beit HaLevi, Etz Ephraim, Sha\'ar Efraim, Nirit, Shoshanat Ha\'Amakim, Mishmar HaSharon, Udim, Geulei Teiman, Elkana, HaMa\'apil, Tnuvot, Ganei Am, Zufim, Tzur Natan, Yakum, Ruppin Academic Center, Kfar Yona Industrial Zone, Givat Haim (Ihud), Beit Yannai, Olesh, Tzur Moshe, Sdeh Warburg, Tzofit, Hofit, Hibat Zion, Netanya - East, Emek Heffer Industrial Zone, Gan Yoshia, Ra\'anana, Givat Haim (Meuhad), Kafr Bara, Beit Hazon, Wingate Institute, Neurim, Arsuf, Ein Vered, Nordia, Kfar Yedidia, Rishpon, Ga\'ash, Jaljulia, Pardessiya, Sdei Hemed, Givat Shapira, Qadima - Zoran, Hogla, Ya\'af, Tayibe, Elyashiv • Shfelat Yehuda - Latrun, Mini Israel - Nachshon, Harel, Tzalfon, Nachshon, Tal Shachar, Gizo, Beko\'a, Neveh Shalom • Yarkon - Beit Arif, Nachshonim, Modi\'in - Ishpro Center, Nechalim, Airport City, Einat, Rinatya, Bareket, Sha\'alabim, Bnei Atarot, Beit Nechemia, Rosh HaAyin, Elad, Shilat, Be\'erot Itzhak, Giv\'at Ko\'ah, Afek and Lev Ha"aretz Industrial Zone, Nofech, Mazor, Kfar HaOranim, Tirat Yehuda, Hevel Modi\'in Industrial Zone, Hatzav Industrial Zone, Shoham, Rosh Ha’Ayin Train Station, Hadid, Kfar Truman, Neot Kedumim • HaShfela - Irus, Kfar Shmuel, Yesodot, Kfar Bin Nun, Nir Zvi, Rishon LeZion - West, Mishmar Ayalon, Ben Shemen, Beit Uziel, Be\'er Yacov, Ramla, Yagel, Netzer Hazani, Beit Hashmonai, Beit Oved, Ben Shemen Youth Village, Sitria, Tzafria, Matzliach, Kfar Bilu, Ahisemech, Nesher Industrial Zone (Ramla), Hulda, Ptachia, Ganei Yochanan, Lod, Ramla, Regional Council Gezer, Regional Council Hevel Modi\'in Industrial Park, Ayanot, Beit Dagan, Palmachin Industrial Park, Pdaya, Yatzitz, Mishmar David, Ness Ziona, Gezer, Ginaton, Azaria, Zeitan, Mazkeret Batya, Hemed, Rishon LeZion - East, Ganot, Fast Lane Parking Lot, Yad Rambam, Na\'an, Ramot Meir, Gan Sorek, Rehovot, Beit Hanan, Zrifin Industrial Zone, Mishmar HaShiva, Achiezer, Ganei Hadar, Kiryat Ekron, Yashresh, Kfar Chabad, Neta\'im, Netzer Sireni, Karmei Yossef • Dan - Morasha Cemetery, Ramat Gan - East, Ramat Gan - West, Ramat HaSharon, Cinema City Glilot, Magshimim, Petach Tikva, Kiryat Ono, Ganei Tikva, Savyon • Wadi Ara - Jatt, Magal, bqa al-Gharbiyye • Lachish - Givat Brenner, Palmachim • Menashe - Or Akiva, Pardes Hanna - Kakur, Hadera - Center, Caesarea Industrial Zone, Maor, Hadera - East, Sdot Yam, Mishmeret, Lehavot Haviva, Gan Shmuel, Sdeh Itzhak, Ein Shemer, Shvil HaTapuzim Compound, Caesarea, Caesarea Marine Center, Hadera - Neveh Haim, Sha\'ar Menashe, Talmei Elazar, Gan HaShomron, Hadera - West01/10/2024 19:33:17: • Yarkon - Giv\'at Ko\'ah01/10/2024 19:33:22: • Sharon - Beit Yannai01/10/2024 19:33:27: • HaShfela - Ginaton01/10/2024 19:33:32: • Sharon - Beit Yithak - Sha\'ar Hefer01/10/2024 19:33:35:'

# %%
raw_df.loc[5644, 'text']
# Out:
# "• Center Negev - Laqiya, Beer Sheva - East, Beer Sheva - West, Hatzerim, Beer Sheva - North, Eshkolot, Beer Sheva - South, Omer • South Negev - Tlalim, Bir Hadaj, Revivim, Ashalim, Wadi el Na'am South, Retamim, Mashabei Sadeh • Yehuda - Neta, Shomria01/10/2024 19:34:18: • Gaza Envelope - Alumim, Yevul, Tkuma, Gavim, Sapir College, Or HaNer, Yated, Sufa, Havat Izra'am, Sdeh Nitzan, Pri Gan, Shlomit, Nir Am, Yad Mordechai, Nirim, Sderot, Ibim, Erez, Ein HaShlosha, Sdeh Avraham, Kfar Azza, Mivtahim, Ami'oz, Yesha, Shokeda, Dekel, Bnei Netzarim, Nir Am Shooting Range, Zohar, Ohad, Reim, Holit, Ein HaBsor, Netiv HaAssara, Magen, Nir Itzhak, Be'eri, Kissufim, Sa'ad, Nir Oz, Zimrat, Shuva, Kfar Maimon and Tushia, Talmei Eliyahu, Naveh, Mefalsim, Yakhini, Nachal Oz, Avshalom, Talmei Yossef, Gvaram • West Negev - Yoshivia, Mabu'im, Ta'ashur, Zru'a, Shavei Darom, Havat Shikmim, Bror Hayil, Noam Industrial Zone, Ma'galim, Giv'olim, M'lilot, Sdeh Zvi, Netivot, Urim, Shibolim, Brosh, Eshbol, Tidhar, Klachim, Nir Akiva, Ze'elim, Gvulot, Dorot, Rochama, Beit HaGdi, Talmei Bilu, Sharsheret, Patish, Nir Moshe, Pa'amei Tashaz • South Negev - Sa'wa, Ar'ara BaNegev, Yeruham, Hiran, Abu Qrenat, Abu Talul, Qasr al-Sir • Center Negev - Hura, Segev Shalom, Carmit, Tel Sheva, Kramim, Meitar, Sansana, AlSayid, Shoket Junction Center, Nevatim, Umm Batin • Yehuda - Teneh Omarim • Lachish - Sdeh David, Tlamim, Zohar • West Lachish - Heletz01/10/2024 19:34:35: • Center Negev - Eshkolot, Hatzerim, Laqiya, Omer • South Negev - Ashalim, Bir Hadaj, Tlalim, Mashabei Sadeh, Revivim, Retamim • Yehuda - Neta, Shomria01/10/2024 19:34:40: • Shfelat Yehuda - Tzuba, Kiryat Anavim, Aviezer, Aderet, Har Tuv - Tzora Industrial Zone, Eshtaol, Beit Shemesh • Yehuda - Alon Shvut, Elazar, Beitar Illit, Bat Ayin01/10/2024 19:34:45: • Shfelat Yehuda - Neveh Ilan, Nataf, Ness Harim, Ein Naqquba, Ein Rafa • Jerusalem - Aminadav01/10/2024 19:34:51: • Shfelat Yehuda - Tzur Hadassa, Kiryat Yearim, Ramat Raziel, Shoeva, Shoresh, Brosh Industrial Zone • Yehuda - Gvaot • Shomron - Horasha, Kerem Reim01/10/2024 19:35:12: • Shfelat Yehuda - Har Adar, Ma'aleh HaHamisha • Jerusalem - Mevasseret Zion, Motza Illit, Ein Kerem Boarding School01/10/2024 19:35:36: • South Negev - Arad, Kuseife, El For'eh, Tel Arad|| Major cities: Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Herzeliya, Holon, Yehud - Monoson, Kfar Shmaryahu, Modi'in-Maccabim-Re'ut, Mikveh Israel, Ariel, Rishon LeZion, Ramat Gan, Or Akiva, Be'er Yacov, Pardes Hanna - Karkur, Ramla, Hadera, Ramat HaSharon, Kfar Saba, Lod, Hod HaSharon, Rosh HaAyin, Ness Ziona, Elad, Netanya, Kfar Kassem, Petach Tikva, Tira, Qalansawe, Rehovot, Caesarea, Shoham, Kiryat Ono, Karnei Shomron, Ra'anana, Savyon, bqa al-Gharbiyye, Kadima-Zoran, Tayibe, Ashdod, Kiryat Gat, Gan Yavne, Kiryat Malachi, Jerusalem, Beit Shemesh, Beitar Illit, Mevasseret Zion, Ashkelon, Ofakim, Be'er Sheva, Sderot, Yeruham, Netivot, Arad |||| Regional councils: Hevel Yavne, R.C. Be'er Tuvia, Gederot, Brenner, Nahal Sorek, Gan Raveh, Yoav, Emek Hefer, Drom HaSharon, Hevel Modi'in, Mateh Binyamin, Gezer, Hof HaSharon, Sdot Dan, Shomron, Lev HaSharon, Menashe, Hof HaCarmel, Mateh Yehuda, Lakhish, Shafir, Hof Ashkelon, Gush Etzion, Sha'ar HaNegev, Merhavim, Bnei Shimon, Ramat Negev, Neve Midbar, Har Hevron, Sdot Negev, Eshkol ||Sent by @CumtaAlertsEnglishChannel"

# %% [markdown]
# The information in the 'text' column gets truncated. The reason for this truncation is that a single message we want to process is split across multiple **div class="text"** blocks. The code processes only one **div class="text"** at a time without combining them into a single message. As a result, the message text is incomplete, and subsequent parts are saved as separate rows.
#
# Rows that start with messages like "• Center Negev - Dvira Junction," have None in the threat_type, region, and time columns but actually belong to the previous message. We can process these rows by taking the threat_type from the previous message. If the text starts with "• ", we append this text to the text field of the previous row and then delete the current row.

# %%
# Sort indices in descending order to avoid conflicts when modifying rows
for idx in sorted(raw_df[raw_df['text'].str.match(r"\d{2}/\d{2}/\d{4} \d{2}:\d{2}:\d{2}:|• ", 
                                                  na=False)].index, reverse=True):
    # Check if the previous row exists
    if idx - 1 in raw_df.index:
        # Append the current text to the 'text' of the previous row
        raw_df.loc[idx - 1, 'text'] += f" {raw_df.loc[idx, 'text']}"
        # Drop the current row
        raw_df.drop(index=idx, inplace=True)

# Reset the index after modifications
raw_df.reset_index(drop=True, inplace=True)

# %%
# Checking problematic rows (1 st october 2024, 19.00-20.00)
raw_df[
    (raw_df['date'] >= '2024-10-01 19:00:00') &
    (raw_df['date'] < '2024-10-01 20:00:00')
]
# Out:
#                           date  \
# 5625 2024-10-01 19:31:39+03:00
# 5626 2024-10-01 19:35:36+03:00
# 5627 2024-10-01 19:40:17+03:00
# 5628 2024-10-01 19:40:17+03:00
# 5629 2024-10-01 19:42:45+03:00
# 5630 2024-10-01 19:42:47+03:00
# 5631 2024-10-01 19:46:05+03:00
# 5632 2024-10-01 19:52:31+03:00
# 5633 2024-10-01 19:52:35+03:00
# 5634 2024-10-01 19:53:12+03:00
# 5635 2024-10-01 19:59:09+03:00
#
#                                                    text threat_type  \
# 5625  Red Alert at Be'er Sheva, Kiryat Arba, Arad, Y...   Red Alert
# 5626  Red Alert at Gdera, Yavne, Tel Aviv - Jaffa, O...   Red Alert
# 5627  Red Alert at Kiryat Arba, Dimona, Hevron Jewis...   Red Alert
# 5628  Red Alert at Kiryat Arba, Dimona, Hevron Jewis...   Red Alert
# 5629  Red Alert at Yehud - Monoson, Modi'in-Maccabim...   Red Alert
# 5630  Red Alert at Yehud - Monoson, Modi'in-Maccabim...   Red Alert
# 5631  Red Alert at Rishon LeZion, Ramat Gan, Ramat H...   Red Alert
# 5632  Red Alert at Be'er Sheva, Or Akiva, umm al-Fah...   Red Alert
# 5633  || Major cities: Be'er Sheva, Or Akiva, umm al...        None
# 5634  Red Alert at Dimona, Golan, HaGalil HaTahton, ...   Red Alert
# 5635  Red Alert at Be'er Sheva, Beit Shemesh, Beitar...   Red Alert
#
#                                                  region  \
# 5625  Be'er Sheva, Kiryat Arba, Arad, Yeruham, Dimon...
# 5626  Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bne...
# 5627  Kiryat Arba, Dimona, Hevron Jewish Settlement,...
# 5628  Kiryat Arba, Dimona, Hevron Jewish Settlement,...
# 5629  Yehud - Monoson, Modi'in-Maccabim-Re'ut, Shoha...
# 5630  Yehud - Monoson, Modi'in-Maccabim-Re'ut, Shoha...
# 5631  Rishon LeZion, Ramat Gan, Ramat HaSharon, Ra'a...
# 5632  Be'er Sheva, Or Akiva, umm al-Fahm, Pardes Han...
# 5633                                               None
# 5634  Dimona, Golan, HaGalil HaTahton, Misgav, Emek ...
# 5635  Be'er Sheva, Beit Shemesh, Beitar Illit, Jerus...
#
#                                            major_cities regional_councils
# 5625  Be'er Sheva, Kiryat Arba, Arad, Yeruham, Dimon...              None
# 5626                                               None              None
# 5627                                               None              None
# 5628                                               None              None
# 5629                                               None              None
# 5630                                               None              None
# 5631                                               None              None
# 5632                                               None              None
# 5633  Be'er Sheva, Or Akiva, umm al-Fahm, Pardes Han...              None
# 5634                                             Dimona              None
# 5635                                               None              None

# %%
# Check problematic srting
raw_df.loc[5626, 'text']
# Out:
# 'Red Alert at Gdera, Yavne, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Herzeliya, Holon, Yehud - Monoson, Kfar Shmaryahu, Modi\'in-Maccabim-Re\'ut, Mikveh Israel, Ariel, Rishon LeZion, Ramat Gan, Or Akiva, Be\'er Yacov, Pardes Hanna - Karkur, Ramla, Hadera, Ramat HaSharon, Kfar Saba, Lod, Hod HaSharon, Rosh HaAyin, Ness Ziona, Elad, Netanya, Kfar Kassem, Petach Tikva, Tira, Qalansawe, Rehovot, Caesarea, Shoham, Kiryat Ono, Karnei Shomron, Ra\'anana, Savyon, bqa al-Gharbiyye, Kadima-Zoran, Tayibe, Ashdod, Kiryat Gat, Gan Yavne, Kiryat Malachi, Jerusalem, Beit Shemesh, Beitar Illit, Mevasseret Zion, Ashkelon, Ofakim, Be\'er Sheva, Sderot, Yeruham, Netivot, Arad, Hevel Yavne, R.C. Be\'er Tuvia, Gederot, Brenner, Nahal Sorek, Gan Raveh, Yoav, Emek Hefer, Drom HaSharon, Hevel Modi\'in, Mateh Binyamin, Gezer, Hof HaSharon, Sdot Dan, Shomron, Lev HaSharon, Menashe, Hof HaCarmel, Mateh Yehuda, Lakhish, Shafir, Hof Ashkelon, Gush Etzion, Sha\'ar HaNegev, Merhavim, Bnei Shimon, Ramat Negev, Neve Midbar, Har Hevron, Sdot Negev, Eshkol [19:32]:01/10/2024 19:32:54: • Lachish - Givat Washington, Neveh Mivtach, Kfar Aviv, Bnaya, Maon Tzofia, Ben Zakai, Gan HaDarom, Hafetz Haim, Asseret, Kfar HaNagid, Bnei Ayish, Meishar, Bnei Darom Compound, Kfar Mordechai, Kannot, Kerem BeYavne, Kannot Industrial Zone, Beit Elazari, Bitzaron, Revadim Industrial Zone, Kidron, Gdera, Misgav Dov, Yavne, Hatzav, Ganei Tal, Shdema, Beit Hilkia, Yad Binyamin, Gedera Industrial Area, Agrigada Factory, Kvutzat Yavne, Beit Gamliel, Nir Galim, Bnei Darom, Ashdod - Northen Industrial Zone • HaShfela - Ge\'alya01/10/2024 19:32:57: • Dan - Tel Aviv - South and Jaffa, Tel Aviv - East, Tel Aviv - City Center, Tel Aviv - Across the Yarkon, Or Yehuda, Azor, Bnei Brak, Bat-Yam, Givat HaShlosha, Givat Shmuel, Givatayim, Gat Rimon, Herzliya - West, Herzeliya - Center and Glil Yam, Holon, Yehud - Monoson, Kfar Sirkin, Kfar Shmaryahu, Maas, Mikveh Israel • Sharon - Avihail, Givat Hen • HaShfela - Gibton, Gan Shlomo • Yarkon - Gimzo, Hashmonaim, Kfar Daniel, Kfar Rut, Lapid, Mevo Horon, Mevo Modi\'im, Modi\'in - Ligad Center, Modi\'in Maccabim Re\'ut, Modi\'in Illit, Matityahu, Noff Ayalon01/10/2024 19:32:59: • Shomron - Ariel, Ariel Industrial Park, Havat Gil\'ad, Neria, Brukhin, Yakir, Havat Yair, Nofim, Nili, Halamish, Avnei Hefetz, Ofarim, Beit Arie, Kdumim, Paduel, Elei Zahav, Na\'aleh, Barkan, Einav, Kiryat Netafim, Karnei Shomron, Bar On Industrial Zone, Barkan Industrial Park, Nachliel, Immanuel, Revava • Lachish - Kedma, Ad Halom Industrial Zone, Menucha, Merkaz Shapira, Masuot Itzhak, Nachla, Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Givati, Gat, Aluma, Shafir, Zrahia, Ezer, Nir Banim, Uzza, Emunim, Azrikam, Even Shmuel, Kommemiut, Ashdod - Gimmel, Vav, Zain, Sdeh Moshe, Ashdod - Alef, Bet, Dalet, Heh, Ein Tzurim, Vardon, Shalva, Kiryat Gat - Industrial Zone, Sgula, Sdeh Uziahu, Beit Ezra, Ahuzam, Revacha, Noam, Zavdiel, Shtulim, Ashdod-11,12,15,17,Marine,City, Kiryat Gat , Karmei Gat, Eitan • West Lachish - Nitzanim Beach, Nitzan, Nitzanim01/10/2024 19:33:36: • Lachish - Timorim, Orot, Re\'em Industrial Park, Timorimg Industrial Zone, Kiryat Mal\'akhi-Yoav train station, Arugot, Revadim, Al Azi, Be\'er Tuvia, Be\'er Tuvia Industrial Zone, Yinon, Talmei Yehiel, Kfar HaRif and Re\'em Junction, Gan Yavne, Lakhish, Kiryat Malachi, Avigdor, Hatzor, Achva, Kfar Warburg, Bnei Re\'em, Kfar Achim • Shfelat Yehuda - Galon, Beit Nir, Kfar Menachem, Beit Guvrin, Kfar Zoharim, Sdot Micha, Nehusha, Tzafririm, Zekharia, Srigim-Li On, Tirosh, Ha\'Ela Junction, Luzit, Geffen, Agur, Givat Ishayahu, Mata, Aviezer, Kfar Uriah, Kiryat Yearim, Sha’ar HaGai, Yad HaShmona, Tzur Hadassa, Kiryat Ye\'arim Youth Village, Aderet, Ksalon, Tzora, Mevo Beitar, Ein Naqquba, Givat Yearim, Bar Giora, Ma\'aleh HaHamisha, Kiryat Anavim, Zanoah, Ein Rafa, Nataf, Neveh Michael (Rogalit), Netiv HaLamed-Heh, Giv\'ot Eden, Mesillat Zion, Shoeva, Har Tuv - Tzora Industri ...

# %% [markdown]
# Now these strings are OK.

# %%
# Merge rows where 'text' starts with '||' into the previous row
for idx in sorted(
    raw_df[raw_df['text'].str.startswith('||', na=False)].index, 
    reverse=True
):
    if idx - 1 in raw_df.index:
        raw_df.loc[idx - 1, 'major_cities'] = (
            f"{raw_df.loc[idx - 1, 'major_cities']} {raw_df.loc[idx, 'major_cities']}".strip()
        )
        raw_df.loc[idx - 1, 'regional_councils'] = (
            f"{raw_df.loc[idx - 1, 'regional_councils']} {raw_df.loc[idx, 'regional_councils']}".strip()
        )
        raw_df.drop(index=idx, inplace=True)


# Reset the index after modifications
raw_df.reset_index(drop=True, inplace=True)

# Display the updated DataFrame
raw_df
# Out:
#                           date  \
# 0    2018-12-26 11:05:08+03:00
# 1    2019-01-02 11:05:05+03:00
# 2    2019-01-07 04:18:52+03:00
# 3    2019-01-12 21:59:18+03:00
# 4    2019-02-06 11:05:01+03:00
# ...                        ...
# 7441 2025-10-01 14:00:45+03:00
# 7442 2025-10-01 20:49:07+03:00
# 7443 2025-10-05 04:59:22+03:00
# 7444 2025-10-05 18:34:40+03:00
# 7445 2025-10-05 18:35:50+03:00
#
#                                                    text  \
# 0     Red Alert at Dan (155,156,157,158,159,160,161,...
# 1     Red Alert at Eilat 311, Arabah 310 [10:05]: 02...
# 2     Red Alert at Lakhish 246 [03:18]: 07/01/2019 0...
# 3     Red Alert at Gaza Containment Zone (224,225) [...
# 4     Red Alert at Jerusalem 194, Maale Adumim 200, ...
# ...                                                 ...
# 7441  Red Alert at Sha'ar HaNegev, Sdot Negev [14:00...
# 7442  Red Alert at Ashdod, Hof Ashkelon [20:48]:01/1...
# 7443  Red Alert at Beit Shemesh, Lod, Ness Ziona, Mo...
# 7444  Red Alert at Eilat [18:34]:05/10/2025 18:34:40...
# 7445  Unrecognized Aircraft at Eilat [18:32]:05/10/2...
#
#                 threat_type  \
# 0                 Red Alert
# 1                 Red Alert
# 2                 Red Alert
# 3                 Red Alert
# 4                 Red Alert
# ...                     ...
# 7441              Red Alert
# 7442              Red Alert
# 7443              Red Alert
# 7444              Red Alert
# 7445  Unrecognized Aircraft
#
#                                                  region  \
# 0     Dan (155,156,157,158,159,160,161,162,165), Sha...
# 1                                 Eilat 311, Arabah 310
# 2                                           Lakhish 246
# 3                       Gaza Containment Zone (224,225)
# 4          Jerusalem 194, Maale Adumim 200, Samaria 127
# ...                                                 ...
# 7441                         Sha'ar HaNegev, Sdot Negev
# 7442                               Ashdod, Hof Ashkelon
# 7443  Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabi...
# 7444                                              Eilat
# 7445                                              Eilat
#
#                                            major_cities  \
# 0     Tel Aviv, Holon, Herzliya, Ramat Gan, Bnei Bra...
# 1                                                 Eilat
# 2                                              Ashkelon
# 3                                                  None
# 4                              Jerusalem, Ma'ale Adumim
# ...                                                 ...
# 7441                                               None
# 7442                                             Ashdod
# 7443  Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabi...
# 7444                                              Eilat
# 7445                                              Eilat
#
#                           regional_councils
# 0                           Southern Sharon
# 1     Hevel Eilot, Tamar, HaArava HaTichona
# 2                              Hof Ashkelon
# 3                Sdot Negev, Sha'ar HaNegev
# 4               Gush Etzion, Mateh Binyamin
# ...                                     ...
# 7441                                   None
# 7442                                   None
# 7443                                   None
# 7444                                   None
# 7445                                   None
#
# [7446 rows x 6 columns]

# %% [markdown]
# Everything is fine now

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7446 entries, 0 to 7445
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               7446 non-null   datetime64[ns, UTC+03:00]
#  1   text               7446 non-null   object
#  2   threat_type        7445 non-null   object
#  3   region             7445 non-null   object
#  4   major_cities       2977 non-null   object
#  5   regional_councils  510 non-null    object
# dtypes: datetime64[ns, UTC+03:00](1), object(5)
# memory usage: 349.2+ KB

# %%
# Checking how useful the "major_cities" column is
print('Number of major cities:', raw_df['major_cities'].nunique())
raw_df['major_cities'].unique()
# Out:
# Number of major cities: 664
# array(['Tel Aviv, Holon, Herzliya, Ramat Gan, Bnei Brak, Or Yehuda, Yehud, Kiryat Ono, Bat Yam, Hod HaSharon, Kfar Saba',
#        'Eilat', 'Ashkelon', None, "Jerusalem, Ma'ale Adumim",
#        'Bat Yam, Tel Aviv, Holon, Ramat Gan, Bnei Brak',
#        'Tel Aviv, Holon, Ramat Gan, Bnei Brak', 'Sderot', 'Kfar Saba',
#        'Netivot', 'Sderot, Netivot, Ashkelon', 'Sderot, Ashkelon',
#        'Gedera, Ashkelon, Ashdod, Sderot', 'Kiryat Gat', 'Ashdod',
#        'Ofakim', "Ashkelon, Be'er Sheva", "Be'er Sheva",
#        'Ofakim, Gedera, Ashdod',
#        "None Be'er Sheva, Ashkelon, Ashdod, Rehovot, Yavne, Ofakim, Arad",
#        'Ashdod, Ashkelon', 'Ashkelon, Ashdod',
#        'Atlit, Or Akiva, bqa al-Gharbiyye, Binyamina, Zichron Yacov, Caesarea, umm al-Fahm, Harish',
#        'Or Akiva, bqa al-Gharbiyye, Binyamina, Zichron Yacov, Caesarea, umm al-Fahm, Harish',
#        'Hadera', 'Ashdod, Gdera',
#        'Ashkelon, Sderot, Holon, Rishon LeZion', 'Gdera, Gan Yavne',
#        'Tel Aviv - Jaffa, Bat Yam, Holon, Rishon LeZion',
#        'Ashdod, Yavne, Gan Yavne', 'Ashdod, Gan Yavne, Ashkelon',
#        'Holon, Bat Yam, Rishon LeZion, Ashkelon', 'Netivot, Sderot',
#        'Sderot, Gan Yavne', 'Ashdod, Gan Yavne', 'Majdal Shams',
#        'Ashkelon, Sderot', 'Mevasseret Zion', 'Jerusalem, Beit Shemesh',
#        'Gan Yavne', 'Ashkelon, Gan Yavne, Ashdod',
#        "Tel Aviv - Jaffa, Bat Yam, Holon, Rishon LeZion, Ashdod, Kadima-Zoran, Or Yehuda, Yavne, Ness Ziona, Bnei Brak, Givatayim, Givat Shmuel, Herzeliya, Yehud-Monosson, Kfar Shmaryahu, Netanya, Savyon, Kiryat Ono, Rehovot, Ramat Gan, Elad, Be'er Yacov, Gdera, Mikveh Israel, Petach Tikva, Ramat HaSharon, Hod HaSharon, Tayibe, Kiryat Malachi",
#        "Tel Aviv - Jaffa, Bat Yam, Holon, Rishon LeZion, Ashdod, Kadima-Zoran, Or Yehuda, Yavne, Ness Ziona, Bnei Brak, Givatayim, Givat Shmuel, Herzeliya, Yehud-Monosson, Kfar Shmaryahu, Netanya, Savyon, Kiryat Ono, Rehovot, Ramat Gan, Elad, Be'er Yacov, Gdera, Mikveh Israel, Petach Tikva, Ramat HaSharon, Hod HaSharon, Tayibe, Kiryat Malachi, Ra'anana, Kfar Saba",
#        "Rishon LeZion, Yavne, Ness Ziona, Gdera, Holon, Ashkelon, Be'er Yacov, Herzeliya, Netanya, Tel Aviv - Jaffa, Bat Yam, Ashdod, Mikveh Israel, Rehovot, Kadima-Zoran, Gan Yavne, Or Yehuda, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Kiryat Ono, Ramat Gan",
#        'Rishon LeZion, Ness Ziona',
#        'Ashdod, Gan Yavne, Kiryat Ono, Ramat Gan, Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Ramat HaSharon, Or Yehuda, Yehud-Monosson, Savyon, Kiryat Malachi, Bat Yam, Holon, Mikveh Israel, Rishon LeZion',
#        "Ashdod, Ashkelon, Rishon LeZion, Or Yehuda, Yehud-Monosson, Savyon, Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Herzeliya, Kfar Shmaryahu, Petach Tikva, Kiryat Ono, Ramat Gan, Ramat HaSharon, Ra'anana, Hod HaSharon, Bat Yam, Holon, Mikveh Israel",
#        "Ashdod, Bat Yam, Rishon LeZion, Tel Aviv - Jaffa, Herzeliya, Kfar Shmaryahu, Ramat HaSharon, Ra'anana",
#        'Ramat Gan',
#        "Holon, Rishon LeZion, Ramat HaSharon, Hod HaSharon, Shoham, Herzeliya, Ra'anana, Kfar Saba, Be'er Yacov, Lod, Ramla, Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Kiryat Ono, Ramat Gan",
#        "Elad, Lod, Be'er Yacov, Ramla",
#        "Be'er Sheva, Ofakim, Yehud-Monosson, Lod, Holon, Rishon LeZion, Herzeliya, Ramat HaSharon, Ra'anana, Hod HaSharon, Kfar Saba, Rehovot, Yavne, Ness Ziona, Dimona, Shoham, Arad",
#        "Tel Aviv - Jaffa, Bat Yam, Holon, Mikveh Israel, Rishon LeZion, Netivot, Be'er Sheva, Rehovot, Ashdod, Givatayim, Ramat Gan, Be'er Yacov, Gdera, Ness Ziona, Ramla, Yavne, Lod, Shoham, Bnei Brak, Givat Shmuel, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Ramat HaSharon, Ra'anana, Hod HaSharon, Kfar Saba, Kadima-Zoran",
#        "Tel Aviv - Jaffa, Ramat Gan, Yavne, Ness Ziona, Rishon LeZion, Holon, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Kiryat Ono, Lod, Or Yehuda, Yehud-Monosson, Savyon, Bat Yam, Ashkelon, Gdera, Elad, Be'er Yacov, Be'er Sheva, Ramla",
#        "Tel Aviv - Jaffa, Ramat Gan, Yavne, Ness Ziona, Rishon LeZion, Holon, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Kiryat Ono, Lod, Or Yehuda, Yehud-Monosson, Savyon, Bat Yam, Ashkelon, Gdera, Elad, Be'er Yacov, Be'er Sheva, Ramla, Shoham",
#        "Lod, Ramla, Or Yehuda, Holon, Rishon LeZion, Rehovot, Shoham, Ramat Gan, Be'er Sheva, Be'er Yacov, Gdera, Ness Ziona",
#        "Ashkelon, Be'er Yacov, Yavne, Tel Aviv - Jaffa, Bat Yam, Givatayim, Holon, Mikveh Israel, Rishon LeZion, Ramat Gan, Lod, Rehovot, Ness Ziona, Ramla",
#        'Tel Aviv - Jaffa, Bat Yam, Holon, Mikveh Israel, Rishon LeZion',
#        'Bat Yam, Holon, Rishon LeZion', "Be'er Yacov, Lod, Ramla",
#        "Rehovot, Be'er Yacov, Ramla, Gdera, Ashdod, Yavne, Gan Yavne",
#        "Holon, Rishon LeZion, Rehovot, Be'er Yacov, Ness Ziona, Ashdod, Gan Yavne",
#        'Ashkelon, Sderot, Ashdod, Gan Yavne', 'Elad, Shoham',
#        'Gdera, Ashdod, Gan Yavne, Ashkelon', 'Gan Yavne, Ashdod',
#        "Ashkelon, Ashdod, Gan Yavne, Be'er Sheva, Ofakim",
#        'Netivot, Sderot, Ashkelon', 'Sderot, Netivot, Ofakim',
#        'Or Yehuda, Yehud-Monosson, Savyon, Rishon LeZion',
#        "Be'er Yacov, Ness Ziona",
#        "bqa al-Gharbiyye, umm al-Fahm, Harish, Tel Aviv - Jaffa, Bnei Brak, Bat Yam, Givatayim, Herzeliya, Holon, Mikveh Israel, Petach Tikva, Rishon LeZion, Ramat Gan, Ramat HaSharon, Ra'anana, Hod HaSharon, Tira, Kfar Saba, Givat Shmuel, Kiryat Ono, Rehovot, Be'er Yacov, Ness Ziona, Ramla, Or Yehuda, Yehud-Monosson, Savyon, Lod, Kadima-Zoran, Ashkelon, Yavne None",
#        "Modi'in-Maccabim-Re'ut",
#        'Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Ramat Gan, Or Yehuda, Yehud-Monosson, Savyon, Kiryat Ono, Ashkelon, Bat Yam, Holon, Mikveh Israel, Ashdod, Gan Yavne',
#        "Be'er Sheva, Ashkelon, Or Yehuda, Givat Shmuel, Savyon, Petach Tikva, Kiryat Ono, Rishon LeZion, Ramat Gan, Tel Aviv - Jaffa, Givatayim, Herzeliya, Holon, Ramat HaSharon, Bnei Brak, Hod HaSharon, Bat Yam, Ness Ziona, Mikveh Israel",
#        'Ashdod, Ashkelon, Yavne, Gdera, Kiryat Malachi',
#        'Ashdod, Ashkelon, Yavne, Gdera, Kiryat Malachi, Gan Yavne',
#        "Lod, Ramla, Modi'in-Maccabim-Re'ut, Be'er Yacov, Gan Yavne, Ashdod, Ashkelon",
#        "Ofakim, Be'er Sheva", 'Ashdod, Gan Yavne, Netivot',
#        'Ashdod, Ashkelon, Gan Yavne, Yavne', 'Netivot, Ashkelon, Gdera',
#        'Ashkelon, Gan Yavne, Ashdod, Yavne',
#        'Ashkelon, Ashdod, Gan Yavne', 'Kiryat Malachi',
#        'Ashdod, Ashkelon, Gan Yavne', "Be'er Sheva, Ofakim",
#        'Ashkelon, Ashdod, Gan Yavne, Gdera',
#        'Ashkelon, Ashdod, Gan Yavne, Yavne, Gdera, Kiryat Malachi',
#        "Rishon LeZion, Rehovot, Be'er Yacov, Ness Ziona, Tel Aviv - Jaffa, Bat Yam, Holon, Mikveh Israel, Yavne, Lod, Shoham, Yehud-Monosson, Elad, Ramla, Ashdod, Or Yehuda, Bnei Brak, Givat Shmuel, Givatayim, Petach Tikva, Kiryat Ono, Ramat Gan, Savyon, Ramat HaSharon",
#        "Rishon LeZion, Ness Ziona, Be'er Yacov, Mikveh Israel, Holon, Yehud-Monosson, Tel Aviv - Jaffa, Bat Yam, Ashdod",
#        'Or Yehuda, Givat Shmuel, Holon, Petach Tikva, Kiryat Ono, Rishon LeZion, Ramat Gan, Ness Ziona, Bnei Brak, Hod HaSharon, Tel Aviv - Jaffa, Givatayim, Tayibe, Yavne, Bat Yam, Rosh HaAyin, Savyon',
#        'Gan Yavne, Ashdod, Ashkelon, Yavne',
#        'Netivot, Ashdod, Gan Yavne, Ashkelon, Sderot',
#        'Ashkelon, Netivot',
#        "Ashkelon, Tel Aviv - Jaffa, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Holon, Ashdod, Rehovot, Be'er Yacov, Bat Yam",
#        "Ashkelon, Tel Aviv - Jaffa, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Holon, Ashdod, Rehovot, Be'er Yacov, Bat Yam, Herzeliya, Gan Yavne, Rishon LeZion",
#        "Ashkelon, Tel Aviv - Jaffa, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Holon, Ashdod, Rehovot, Be'er Yacov, Bat Yam, Herzeliya, Gan Yavne, Rishon LeZion, Mikveh Israel",
#        "Ashkelon, Tel Aviv - Jaffa, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Holon, Ashdod, Rehovot, Be'er Yacov, Bat Yam, Herzeliya, Gan Yavne, Rishon LeZion, Mikveh Israel, Elad, Ness Ziona",
#        'Yehud-Monosson, Savyon, Yavne, Or Yehuda, Ashdod',
#        'Bnei Brak, Givat Shmuel, Petach Tikva, Kiryat Ono',
#        "Tel Aviv - Jaffa, Holon, Mikveh Israel, Rishon LeZion, Be'er Yacov, Ramla, Gan Yavne, Ashdod",
#        "Rehovot, Elad, Be'er Yacov, Lod, Rosh HaAyin, Ramla, Shoham, Rishon LeZion, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kfar Kassem, Ness Ziona, Tel Aviv - Jaffa, Bat Yam, Givatayim, Holon, Mikveh Israel, Bnei Brak, Givat Shmuel, Kiryat Ono, Ramat Gan",
#        "Rehovot, Elad, Be'er Yacov, Lod, Rosh HaAyin, Ramla, Shoham, Rishon LeZion, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kfar Kassem, Ness Ziona, Tel Aviv - Jaffa, Bat Yam, Givatayim, Holon, Mikveh Israel",
#        'Ashkelon, Kiryat Malachi, Gan Yavne, Ashdod',
#        "Sderot, Ashkelon, Gan Yavne, Kiryat Malachi, Be'er Sheva, Ashdod",
#        'Gan Yavne, Ashkelon, Ashdod', 'Ofakim, Netivot',
#        "Ashkelon, Ashdod, Be'er Sheva, Ofakim",
#        "Ashkelon, Ashdod, Gan Yavne, Be'er Sheva",
#        "Be'er Sheva, Ofakim, Ashdod, Ashkelon",
#        "Be'er Sheva, Ofakim, Dimona",
#        'Yavne, Rehovot, Ness Ziona, Ashdod', 'Yavne, Ashdod, Gan Yavne',
#        "Ashkelon, Ashdod, Rehovot, Gan Yavne, Yavne, Be'er Sheva",
#        'Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Acre',
#        'Netivot, Ashdod', 'Sderot, Netivot, Ashkelon, Ashdod', 'Shlomi',
#        'Tel Hai', 'Kiryat Atta, Kiryat Yam',
#        'Karmiel, Acre, Kiryat Biyalik, Shfaram',
#        'Ashkelon, Jerusalem, Ramat Gan, Hadera',
#        'Ashkelon, Jerusalem, Herzeliya, Rishon LeZion, Hadera',
#        'Jerusalem, Rishon LeZion, Hadera',
#        'Jerusalem, Herzeliya, Netanya', 'umm al-Fahm', 'Rosh Pinna',
#        'Gan Yavne, Yavne, Ashdod, Sderot',
#        'Gan Yavne, Rishon LeZion, Bat Yam',
#        "Sderot, Modi'in-Maccabim-Re'ut",
#        'Ashkelon, Sderot, Bat Yam, Holon, Mikveh Israel, Rishon LeZion, Tel Aviv - Jaffa, Yavne',
#        "Be'er Sheva, Ness Ziona, Rishon LeZion", 'Yavne, Ashkelon',
#        "Lod, Be'er Yacov, Holon, Bat Yam, Tel Aviv - Jaffa",
#        'Ramla, Rishon LeZion, Netivot', 'Beitar Illit',
#        'Ashkelon, Sderot, Gan Yavne, Ashdod, Netivot',
#        'Givatayim, Tel Aviv - Jaffa, Ramat Gan',
#        'Sderot, Bat Yam, Holon, Tel Aviv - Jaffa, Mikveh Israel, Ashkelon',
#        'Rishon LeZion, Yavne', 'Holon, Rishon LeZion, Netivot, Bat Yam',
#        "Sderot, Ashkelon, Be'er Sheva, Netivot",
#        'Ashkelon, Givat Shmuel, Ramat Gan, Tel Aviv - Jaffa, Givatayim, Or Yehuda',
#        'Mikveh Israel, Holon, Rishon LeZion, Sderot',
#        "Rehovot, Ramla, Be'er Yacov",
#        'Holon, Mikveh Israel, Rishon LeZion',
#        'Beit Shemesh, Beitar Illit', 'Sderot, Netivot',
#        'Rishon LeZion, Holon', 'None None',
#        'Bat Yam, Rishon LeZion, Sderot, Kiryat Gat, Gan Yavne, Gdera, Ashdod',
#        'Netivot, Arad, Sderot, Kiryat Gat, Yavne, Rehovot',
#        'Sderot, Ness Ziona, Holon, Rishon LeZion, Yavne, Rehovot, Ashkelon',
#        'Sderot, Ashkelon, Holon, Rishon LeZion, Bat Yam, Gdera, Ofakim, Lod, Kiryat Gat',
#        "Sderot, Ofakim, Be'er Sheva", 'Sderot, Dimona',
#        "Ofakim, Be'er Sheva, Rehovot", "Be'er Sheva, Gdera",
#        "Rehovot, Be'er Yacov, Be'er Sheva",
#        "Be'er Sheva, Gdera, Be'er Yacov, Lod, Ramla, Gan Yavne",
#        'Ashdod, Gan Yavne, Gdera, Rehovot',
#        "Lod, Ramla, Gan Yavne, Be'er Yacov", 'Gdera',
#        'Lod, Ramla, Rehovot, Yeruham, Gan Yavne, Ofakim, Ashkelon',
#        "Ashkelon, Kiryat Malachi, Be'er Sheva, Kiryat Gat",
#        "Gdera, Be'er Sheva, Rehovot",
#        "Ness Ziona, Rishon LeZion, Yavne, Be'er Yacov, Rehovot, Ramla",
#        "Rehovot, Ness Ziona, Rishon LeZion, Yavne, Ramla, Be'er Yacov, Lod, Tel Aviv - Jaffa, Givatayim, Ramat Gan, Gdera, Gan Yavne, Or Yehuda, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono",
#        "Holon, Ashdod, Be'er Sheva", "Be'er Sheva, Ashdod",
#        'Gan Yavne, Ashkelon, Gdera',
#        "Gan Yavne, Gdera, Kiryat Malachi, Be'er Sheva",
#        'Gan Yavne, Yavne, Gdera, Kiryat Malachi',
#        'Kiryat Malachi, Gdera, Rehovot, Ness Ziona, Rishon LeZion, Yavne',
#        'Yavne, Kiryat Gat', 'Ness Ziona, Rehovot, Ofakim, Yavne, Ramla',
#        'Gdera, Sderot, Kiryat Malachi', 'Rehovot, Kiryat Malachi',
#        'Jerusalem, Beitar Illit, Yavne, Gdera, Ashdod, Gan Yavne',
#        'Rehovot, Ness Ziona, Yavne, Gdera, Ramla, Kiryat Malachi',
#        "Be'er Sheva, Yavne, Ashdod, Be'er Yacov, Netivot, Sderot, Rishon LeZion",
#        'Rehovot, Netivot, Ness Ziona, Ofakim',
#        'Ashkelon, Netivot, Yavne, Ashdod',
#        'Kiryat Malachi, Ashkelon, Netivot',
#        "Ofakim, Ashkelon, Ness Ziona, Rishon LeZion, Rehovot, Be'er Yacov, Be'er Sheva",
#        "Ashkelon, Be'er Sheva, Kiryat Malachi, Lod, bqa al-Gharbiyye, Rehovot, Ramla, Be'er Yacov, Jerusalem, Mevasseret Zion",
#        'Beitar Illit, Kiryat Malachi, Beit Shemesh, Mevasseret Zion, Ashkelon, Jerusalem',
#        'Kiryat Malachi, Beit Shemesh, Ashkelon, Givat Shmuel, Ramat Gan, Givatayim, Tel Aviv - Jaffa, Bnei Brak, Ashdod, Gan Yavne, Gdera, Jerusalem, Beitar Illit, Mevasseret Zion',
#        "Sderot, Ashkelon, Kiryat Malachi, Be'er Sheva, Ramla, Lod, Ashdod",
#        'Netivot, Or Yehuda, Rishon LeZion, Holon',
#        "Rehovot, Ness Ziona, Yavne, Ashkelon, Be'er Sheva, Sderot",
#        "Be'er Sheva, Gan Yavne, Ashdod, Ashkelon",
#        "Ashdod, Netivot, Be'er Sheva, Ashkelon, Sderot, Kiryat Malachi, Ofakim",
#        'Sderot, Ashkelon, Mevasseret Zion, Jerusalem',
#        "Ashkelon, Ashdod, Be'er Sheva",
#        "Ashkelon, Kiryat Malachi, Sderot, Be'er Sheva, Ashdod",
#        "Be'er Sheva, Ashkelon, Kiryat Malachi, Yavne",
#        'Ashkelon, Beitar Illit, Kiryat Gat, Ashdod',
#        "Ashkelon, Be'er Sheva, Sderot, Gdera, Kiryat Malachi, Ofakim",
#        "Sderot, Ashkelon, Be'er Sheva",
#        "Netivot, Kiryat Gat, Be'er Sheva, Ashkelon",
#        'Ashkelon, Netivot, Ashdod, Ofakim',
#        'Ashkelon, Kiryat Gat, Yavne, Gdera, Gan Yavne, Kiryat Malachi, Netivot',
#        "Ashkelon, Kiryat Gat, Netivot, Be'er Sheva, Jerusalem, Yavne, Beitar Illit",
#        'Kiryat Gat, Jerusalem, Ashkelon, Netivot, Yavne, Beit Shemesh, Beitar Illit',
#        'Ashkelon, Jerusalem, Beit Shemesh, Yavne, Beitar Illit',
#        "Be'er Sheva, Holon, Rishon LeZion, Bat Yam, Tel Aviv - Jaffa, bqa al-Gharbiyye, Ashdod, Yavne, Ness Ziona",
#        'Jerusalem, Mevasseret Zion, Sderot, Beitar Illit, Kiryat Gat, Kiryat Malachi',
#        "Beit Shemesh, Modi'in-Maccabim-Re'ut, Yavne",
#        "Jerusalem, Ma'aleh Edomim, Yavne, Beit Shemesh, Ashkelon, Mevasseret Zion, Gan Yavne, Ashdod, Beitar Illit",
#        'Ariel', 'Kiryat Malachi, bqa al-Gharbiyye',
#        "Tel Aviv - Jaffa, Yavne, Rishon LeZion, Holon, Bat Yam, Mikveh Israel, Ness Ziona, Gan Yavne, Givatayim, Ramat Gan, Be'er Yacov, Ashdod",
#        "Holon, Rishon LeZion, Or Yehuda, Yavne, Ramla, Rehovot, Ness Ziona, Be'er Yacov, Bat Yam",
#        "Rehovot, Shoham, Ramat Gan, Bnei Brak, Givat Shmuel, Petach Tikva, Kiryat Ono, Gdera, Or Yehuda, Tel Aviv - Jaffa, Givatayim, Ramla, Be'er Yacov, Kfar Kassem, Rosh HaAyin, Yavne, Rishon LeZion, Savyon, Bat Yam, Yehud-Monosson, Holon, Mikveh Israel",
#        "Ramla, Be'er Yacov, Rishon LeZion, Ness Ziona, Rehovot, Shoham, Yavne",
#        "Ness Ziona, Rehovot, Rishon LeZion, Be'er Yacov, Gdera, Yavne",
#        "Yehud-Monosson, Or Yehuda, Savyon, Rishon LeZion, Ness Ziona, Sderot, Mevasseret Zion, Jerusalem, Herzeliya, Ra'anana, Yavne, bqa al-Gharbiyye, Kfar Shmaryahu, Petach Tikva, Ramat HaSharon, Givat Shmuel, Ramat Gan, Tel Aviv - Jaffa, Hod HaSharon, Bnei Brak",
#        'Ashkelon, Gan Yavne, Ashdod, Rishon LeZion, Holon, Sderot, Yavne',
#        'Holon, Rishon LeZion', 'Mevasseret Zion, Beitar Illit, Jerusalem',
#        'Rishon LeZion, Tel Aviv - Jaffa, Bat Yam, Holon, Mikveh Israel, Ashdod, Yavne, Bnei Brak, Givat Shmuel, Petach Tikva, Ramat Gan',
#        'Rishon LeZion',
#        'Kfar Shmaryahu, Ramat HaSharon, Herzeliya, Tel Aviv - Jaffa',
#        'Tel Aviv - Jaffa', 'Tel Aviv - Jaffa, Herzeliya, Kfar Shmaryahu',
#        'bqa al-Gharbiyye', 'Ashkelon, Shlomi',
#        "Rishon LeZion, Holon, Ramla, Rehovot, Lod, Be'er Yacov, Ness Ziona",
#        "Ashkelon, Ashdod, Netivot, Be'er Sheva",
#        "None Nazareth, Afula, Migdal HaEmek, Nof HaGalil (Nazareth Illit), Katzrin, Deir al-Asad, Tiberias, Tirat Carmel, Majdal Shams, Metulla, Ma'a lot Tarshicha, Nahariya, Acre, Safed, Kiryat Shmona, Sakhnin, Kiryat Motzkin, Nesher, Beit Jann, Yarka, Rosh Pinna, Shfaram, Tel Hai",
#        "Ma'a lot Tarshicha",
#        "Rehovot, Be'er Yacov, Ness Ziona, Rishon LeZion",
#        'Tayibe, Ariel, Kadima-Zoran', 'Beit Shemesh', 'Metulla',
#        'Kiryat Shmona, Tel Hai', 'Gan Yavne, Gdera', 'Safed, Shfaram',
#        'Bat Yam, Holon, Rishon LeZion, Rehovot, Ramla, Tel Aviv - Jaffa',
#        'Holon, Rishon LeZion, Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Ramat Gan, Herzeliya, Ashdod',
#        'Shfaram',
#        'Ashkelon, Bat Yam, Rishon LeZion, Tel Aviv - Jaffa, Or Yehuda, Ramat Gan, Holon, Ness Ziona',
#        "Be'er Sheva, Ashkelon",
#        'Yehud-Monosson, Savyon, Petach Tikva, Ashkelon, Ashdod, Or Yehuda',
#        'Tel Aviv - Jaffa, Bat Yam, Holon, Rishon LeZion, Bnei Brak, Ramat Gan, Ramat HaSharon, Lod, Ramla, Petach Tikva, Kfar Kassem, Rosh HaAyin, Givatayim, Mikveh Israel, Elad',
#        'Ramat HaSharon, Herzeliya, Tel Aviv - Jaffa', 'Nahariya, Shlomi',
#        'Yehud-Monosson, Savyon, Ramat Gan, Kiryat Ono, Or Yehuda, Givat Shmuel, Tel Aviv - Jaffa, Bnei Brak, Givatayim, Bat Yam, Holon, Rishon LeZion',
#        'Rishon LeZion, Mikveh Israel', 'Ramla, Rehovot',
#        'Gan Yavne, Ashdod, Ashkelon',
#        'Savyon, Petach Tikva, Kiryat Ono, Tel Aviv - Jaffa, Givatayim, Holon, Mikveh Israel, Bnei Brak, Ramat Gan, Beit Shemesh, Jerusalem, Or Yehuda, Bat Yam, Rishon LeZion',
#        'Tel Aviv - Jaffa, Givatayim, Holon, Mikveh Israel, Ramat Gan',
#        'Bat Yam, Rishon LeZion', 'Tel Aviv - Jaffa, Givatayim, Ramat Gan',
#        'Bat Yam, Holon, Mikveh Israel', 'Sderot, Gan Yavne, Ashdod',
#        'Rishon LeZion, Holon, Mikveh Israel, Bat Yam, Tel Aviv - Jaffa, Givatayim, Ramat Gan, Or Yehuda, Ness Ziona',
#        'Kiryat Shmona', 'Sderot, Gan Yavne, Kiryat Malachi, Ashdod',
#        "Rishon LeZion, Holon, Bat Yam, Yehud-Monosson, Or Yehuda, Bnei Brak, Givat Shmuel, Petach Tikva, Kiryat Ono, Ramat Gan, Be'er Yacov, Ness Ziona",
#        'Rishon LeZion, Holon, Ness Ziona, Tel Aviv - Jaffa, Givatayim, Mikveh Israel, Ramat Gan, Bat Yam, Rehovot',
#        'Kiryat Ono, Yehud-Monosson, Savyon, Or Yehuda, Tel Aviv - Jaffa, Givatayim, Holon, Rishon LeZion, Ramat Gan, Givat Shmuel, Petach Tikva, Hod HaSharon, Elad, Rosh HaAyin, Bnei Brak, Lod, Mikveh Israel, Ashkelon',
#        'Yavne, Yehud-Monosson, Savyon', 'Hod HaSharon, Petach Tikva',
#        'Tel Aviv - Jaffa, Bat Yam, Holon',
#        'Ramat Gan, Kiryat Ono, Or Yehuda, Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel',
#        'Holon, Rishon LeZion, Mikveh Israel', 'Nahariya',
#        "Be'er Sheva, Kiryat Shmona",
#        'Rishon LeZion, Holon, Bat Yam, Yavne', 'Ashkelon, Sderot, Ashdod',
#        'Rishon LeZion, Ness Ziona, Yehud-Monosson, Or Yehuda', 'Yavne',
#        'Rishon LeZion, Ness Ziona, Tel Aviv - Jaffa, Ashdod, Yavne, Bat Yam',
#        'Beit Shemesh, Kiryat Gat',
#        "Yehud-Monosson, Be'er Yacov, Lod, Ramla, Ness Ziona, Rehovot, Elad, Rosh HaAyin",
#        "Be'er Sheva, Or Yehuda, Yehud-Monosson, Elad, Rosh HaAyin, Yavne",
#        'Daliyat al-Karmel',
#        'Holon, Rishon LeZion, Bat Yam, Elad, Petach Tikva, Rosh HaAyin',
#        "Be'er Yacov, Rishon LeZion, Ness Ziona, Tel Aviv - Jaffa, Bat Yam, Holon, Mikveh Israel, Or Yehuda, Bnei Brak, Givat Shmuel, Givatayim, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Rehovot, Ramat Gan, Hod HaSharon",
#        'Ashkelon, Netivot, Ashdod',
#        'Tel Aviv - Jaffa, Bat Yam, Givatayim, Herzeliya, Holon, Mikveh Israel, Rishon LeZion, Ramat Gan, Ramat HaSharon, Kiryat Ono, Savyon, Or Yehuda, Yehud-Monosson',
#        'Shoham, Rehovot, Ramla, Holon, Or Yehuda, Rishon LeZion, Tel Aviv - Jaffa, Givatayim, Bnei Brak, Ramat Gan, Givat Shmuel, Petach Tikva, Kiryat Ono, Lod, Mikveh Israel',
#        'Tel Aviv - Jaffa, Givatayim, Ramat Gan, Holon, Rishon LeZion, Bnei Brak, Bat Yam, Mikveh Israel',
#        'Rishon LeZion, Rehovot, Ness Ziona, Tel Aviv - Jaffa, Petach Tikva, Kiryat Ono, Givat Shmuel, Savyon, Ramat Gan, Holon, Or Yehuda',
#        "Ramat Gan, Or Yehuda, Yehud-Monosson, Modi'in-Maccabim-Re'ut, Rishon LeZion, Holon, Ashdod, Savyon, Kiryat Ono, Ashkelon",
#        'Tel Aviv - Jaffa, Bat Yam',
#        'Ashkelon, Ramat Gan, Rishon LeZion, Or Yehuda, Tel Aviv - Jaffa, Givatayim, Mikveh Israel, Holon, Yehud-Monosson, Savyon, Petach Tikva, Kiryat Ono, Kfar Kassem, Rosh HaAyin, Bnei Brak, Givat Shmuel, Elad, Bat Yam, Ness Ziona',
#        "Rishon LeZion, Rehovot, Be'er Yacov, Ness Ziona, Or Yehuda, Yehud-Monosson, Holon",
#        'Ness Ziona, Rehovot, Yavne, Ashkelon',
#        "Hod HaSharon, Kfar Saba, Ra'anana, Herzeliya",
#        'Rishon LeZion, Holon, Ramat HaSharon, Tel Aviv - Jaffa',
#        'Jerusalem', 'Rishon LeZion, Lod, Ness Ziona',
#        'Rishon LeZion, Holon, Or Yehuda, Ramat Gan', 'Ness Ziona',
#        "Herzeliya, Ra'anana, Kfar Saba, Tel Aviv - Jaffa, Petach Tikva, Bnei Brak, Ramat Gan, Ramat HaSharon",
#        'Kfar Saba, Hod HaSharon', 'Petach Tikva',
#        'Tel Aviv - Jaffa, Bnei Brak, Givatayim, Ramat Gan, Holon, Mikveh Israel, Rishon LeZion, Bat Yam',
#        'Ashkelon, Tel Aviv - Jaffa, Givatayim, Ramat Gan, Bnei Brak, Petach Tikva, Ramat HaSharon',
#        'Bat Yam, Holon, Rishon LeZion, Tel Aviv - Jaffa, Givatayim, Ramat Gan, Mikveh Israel, Ness Ziona',
#        'Safed',
#        "Or Yehuda, Savyon, Yehud-Monosson, Kfar Kassem, Rosh HaAyin, Elad, Lod, Be'er Yacov, Rishon LeZion, Ramla",
#        'Bat Yam, Rishon LeZion, Holon, Tel Aviv - Jaffa, Lod', 'Ramla',
#        "Ness Ziona, Rishon LeZion, Holon, Bat Yam, Rehovot, Be'er Yacov, Lod, Ramla",
#        'Kiryat Shmona, Tel Hai, Metulla, Netivot',
#        'Rishon LeZion, Holon, Tel Aviv - Jaffa, Bnei Brak, Ramat Gan, Ramat HaSharon, Hod HaSharon, Petach Tikva, Kfar Kassem, Rosh HaAyin, Ness Ziona, Givatayim, Mikveh Israel, Givat Shmuel',
#        "Ramat Gan, Holon, Mikveh Israel, Tel Aviv - Jaffa, Or Yehuda, Yehud-Monosson, Savyon, Kiryat Ono, Rishon LeZion, Be'er Yacov, Ashdod, Bat Yam, Rehovot, Ness Ziona, Ramla, Givatayim",
#        'Nahariya, Shlomi, Kiryat Yam, Kiryat Biyalik, Acre',
#        "Kfar Kassem, Rosh HaAyin, Herzeliya, Kfar Shmaryahu, Ramat HaSharon, Ra'anana",
#        "Kfar Kassem, Rosh HaAyin, Herzeliya, Kfar Shmaryahu, Ramat HaSharon, Ra'anana, Tel Aviv - Jaffa, Petach Tikva, Elad",
#        'Bat Yam, Tel Aviv - Jaffa, Rishon LeZion, Petach Tikva, Savyon, Yehud-Monosson, Or Yehuda, Ness Ziona',
#        'Givat Shmuel, Petach Tikva, Kiryat Ono, Ramat Gan, Or Yehuda, Holon, Tel Aviv - Jaffa, Bnei Brak, Ramat HaSharon, Herzeliya, Ashdod, Rishon LeZion, Mikveh Israel, Givatayim',
#        'Kiryat Shmona, Metulla, Tel Hai', 'Shlomi, Acre, Kiryat Biyalik',
#        'Safed, Acre, Kiryat Biyalik',
#        "Rishon LeZion, Bat Yam, Holon, Lod, Be'er Yacov, Ramla, Rehovot, Ness Ziona, Or Yehuda",
#        "Rishon LeZion, Bat Yam, Holon, Lod, Be'er Yacov, Ramla, Rehovot, Ness Ziona, Or Yehuda, Tel Aviv - Jaffa, Ramat Gan",
#        'Bat Yam, Tel Aviv - Jaffa, Holon',
#        "Be'er Yacov, Rehovot, Rishon LeZion, Ness Ziona, Tel Aviv - Jaffa, Shoham, Givat Shmuel, Savyon, Petach Tikva, Kiryat Ono, Ramat Gan, Herzeliya, Hod HaSharon, Ramat HaSharon, Or Yehuda, Holon, Bnei Brak",
#        'Rehovot, Ness Ziona, Ramla, Lod, Yavne',
#        "Tel Aviv - Jaffa, Ramat Gan, Yavne, Holon, Givatayim, Gdera, Shoham, Herzeliya, Ramla, Petach Tikva, Ness Ziona, Yehud-Monosson, Kiryat Ono, Rishon LeZion, Bat Yam, Ramat HaSharon, Elad, Savyon, Be'er Yacov, Kfar Shmaryahu, Bnei Brak, Givat Shmuel, Rehovot, Rosh HaAyin, Or Yehuda, Ra'anana, Lod, Hod HaSharon, Mikveh Israel",
#        "Be'er Yacov, Ness Ziona, Rishon LeZion", 'Rehovot',
#        "Rishon LeZion, Lod, Ramla, Be'er Yacov, Ness Ziona, Or Yehuda, Holon, Ashdod, Rehovot, Yavne",
#        'Gan Yavne, Ness Ziona, Rishon LeZion, Yavne, Rehovot, Ashdod',
#        'Rehovot, Ashdod, Gdera',
#        'Afula, Nof HaGalil (Nazareth Illit), Migdal HaEmek, Nazareth',
#        "Tel Aviv - Jaffa, Givatayim, Holon, Mikveh Israel, Shoham, Bnei Brak, Ramat Gan, Or Yehuda, Kiryat Ono, Yehud-Monosson, Savyon, Modi'in-Maccabim-Re'ut, Ramla, Be'er Yacov, Lod, Bat Yam, Rishon LeZion, Rehovot, Ness Ziona",
#        'Petach Tikva, Kiryat Ono, Or Yehuda, Yehud-Monosson, Ramat Gan, Savyon',
#        'Tel Hai, Kiryat Shmona',
#        'Tel Aviv - Jaffa, Givatayim, Or Yehuda, Givat Shmuel, Kiryat Ono, Ramat Gan, Yehud-Monosson, Savyon, Holon, Bnei Brak, Petach Tikva, Yavne, Bat Yam, Mikveh Israel, Rishon LeZion',
#        'Tel Hai, Metulla, Kiryat Shmona',
#        "Ness Ziona, Be'er Yacov, Rishon LeZion, Or Yehuda, Savyon, Givat Shmuel, Petach Tikva, Kiryat Ono, Ramat Gan, Bnei Brak, Givatayim, Tel Aviv - Jaffa, Rehovot, Yavne, Mikveh Israel, Holon, Yehud-Monosson, Bat Yam",
#        'Tel Aviv - Jaffa, Holon, Mikveh Israel, Rishon LeZion, Bat Yam, Or Yehuda',
#        'Acre', 'Jerusalem, Beit Shemesh, Mevasseret Zion',
#        'Rishon LeZion, Tel Aviv - Jaffa, Bat Yam',
#        "Yavne, Kiryat Ono, Rehovot, Ramat Gan, Be'er Yacov, Lod, Ness Ziona, Ramla, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Givat Shmuel, Givatayim, Holon, Yehud-Monosson, Mikveh Israel, Savyon",
#        'Ashkelon, Ashdod, Gdera, Gan Yavne, Yavne, Ness Ziona, Rishon LeZion, Kiryat Malachi',
#        "Rishon LeZion, Tel Aviv - Jaffa, Bat Yam, Holon, Or Yehuda, Givatayim, Bnei Brak, Givat Shmuel, Petach Tikva, Kiryat Ono, Ramat Gan, Herzeliya, Ramat HaSharon, Hod HaSharon, Ra'anana, Kfar Saba, Kfar Shmaryahu, Ashkelon, Ness Ziona, Mikveh Israel",
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam', 'Katzrin',
#        "Sderot, Rehovot, Ness Ziona, Be'er Yacov, Rishon LeZion, Ramla, Lod, Holon, Bat Yam, Mikveh Israel, Modi'in-Maccabim-Re'ut, Gdera",
#        "Deir al-Asad, Karmiel, Safed, Rosh Pinna, Ma'a lot Tarshicha, Beit Jann",
#        'Tel Hai, Metulla, Kiryat Shmona, Majdal Shams',
#        "Rehovot, Be'er Yacov, Ramla, Ness Ziona, Lod, Rishon LeZion, Holon, Gan Yavne",
#        'Metulla, Kiryat Shmona, Tel Hai', 'Yavne, Ashdod', 'Haifa',
#        "Rishon LeZion, Holon, Lod, Tel Aviv - Jaffa, Bat Yam, Mikveh Israel, Or Yehuda, Yehud-Monosson, Be'er Yacov, Ramla, Ness Ziona",
#        'Beit Jann', 'Yarka', 'Kiryat Shmona, Tel Hai, Metulla',
#        'Tel Hai, Kiryat Shmona, Metulla', 'Eilat, Tel Hai, Kiryat Shmona',
#        'Hebron', 'Metulla, Kiryat Shmona',
#        "Dimona, Arad, Be'er Sheva, Jerusalem, Beitar Illit, Majdal Shams",
#        "Kiryat Arba, Hebron, Be'er Sheva, Dimona, Majdal Shams, Arad",
#        "Arad, Hebron, Be'er Sheva", "Arad, Dimona, Be'er Sheva",
#        'Acre, Kiryat Motzkin, Kiryat Biyalik, Kiryat Yam',
#        'Metulla, Tel Hai, Kiryat Shmona',
#        'Majdal Shams, Tel Hai, Kiryat Shmona, Metulla',
#        "Kfar Saba, Herzeliya, Ra'anana, Hod HaSharon",
#        'Herzeliya, Kfar Shmaryahu, Ramat HaSharon, Tel Aviv - Jaffa, Petach Tikva',
#        'Metulla, Tel Hai, Kiryat Shmona, Katzrin', 'Nahariya, Acre',
#        'Shlomi, Nahariya', 'Nof HaGalil (Nazareth Illit)',
#        'Kiryat Biyalik', 'Tiberias, Safed, Rosh Pinna',
#        'Safed, Rosh Pinna', 'Safed, Katzrin, Majdal Shams',
#        'Katzrin, Safed', 'Majdal Shams, Katzrin',
#        'Shlomi, Metulla, Kiryat Shmona, Tel Hai',
#        'Metulla, Kiryat Shmona, Tel Hai, Katzrin',
#        'Acre, Kiryat Shmona, Tel Hai', "Katzrin, Ma'a lot Tarshicha",
#        "Or Yehuda, Kiryat Ono, Elad, Rehovot, Savyon, Rishon LeZion, Shoham, Lod, Modi'in-Maccabim-Re'ut, Ness Ziona, Ramla, Be'er Yacov, Yehud-Monosson, Ramat Gan, Holon",
#        'Tiberias', 'Rosh Pinna, Safed', 'Kiryat Shmona, Tel Hai, Safed',
#        'Yokneam Illit, Daliyat al-Karmel, Isfiya, Migdal HaEmek, Nof HaGalil (Nazareth Illit), Nazareth, Afula',
#        'Migdal HaEmek', 'Shfaram, Nof HaGalil (Nazareth Illit), Nazareth',
#        'Kiryat Motzkin, Kiryat Biyalik, Migdal HaEmek, Shfaram, Yarka',
#        'Acre, Nazareth, Kiryat Yam, Kiryat Motzkin, Shlomi',
#        'Kiryat Yam, Kiryat Biyalik, Kiryat Motzkin, Acre', "Beit She'an",
#        'Yokneam Illit, Daliyat al-Karmel, Isfiya',
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Acre',
#        'Karnei Shomron, Ariel',
#        'Isfiya, Haifa, Kiryat Atta, Nesher, Daliyat al-Karmel, Shfaram',
#        'Yokneam Illit', 'Sakhnin, umm al-Fahm, Karmiel, Migdal HaEmek',
#        'Kiryat Yam, Kiryat Biyalik, Acre, Kiryat Motzkin',
#        'Tirat Carmel, Haifa, Nesher, Isfiya, Kiryat Atta, Kiryat Biyalik',
#        'Nazareth, Afula, Nof HaGalil (Nazareth Illit), Migdal HaEmek',
#        'Afula, Migdal HaEmek, Nazareth, Nof HaGalil (Nazareth Illit)',
#        'Shfaram, Kiryat Biyalik, Kiryat Atta, Yarka',
#        'Nazareth, Migdal HaEmek, Afula, Nof HaGalil (Nazareth Illit)',
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Acre, Yarka',
#        'Sakhnin', 'Atlit', 'Tel Aviv - Jaffa, Ramat Gan',
#        'Kadima-Zoran, Netanya',
#        'Zichron Yacov, Yokneam Illit, Daliyat al-Karmel',
#        'Shfaram, Yarka', 'Beit Jann, Safed',
#        "Tel Aviv - Jaffa, Or Yehuda, Shoham, Ramat Gan, Lod, Givat Shmuel, Savyon, Be'er Yacov, Kiryat Ono, Yehud - Monoson, Petach Tikva, Bnei Brak, Givatayim, Mikveh Israel, Ramla, Holon, Rishon LeZion, Ness Ziona, Elad, Rehovot, Bat-Yam, Yavne, Modi'in-Maccabim-Re'ut",
#        'Kiryat Atta, Haifa, Nesher, Kiryat Yam, Kiryat Motzkin, Kiryat Biyalik, Tirat Carmel',
#        'Karmiel, Sakhnin, Deir al-Asad',
#        'Sakhnin, Shfaram, Karmiel, Yarka',
#        "Karmiel, Beit Jann, Deir al-Asad, Yarka, Ma'a lot Tarshicha",
#        'umm al-Fahm, Afula, Yokneam Illit, Nazareth, Nof HaGalil (Nazareth Illit), Isfiya, Shfaram, Migdal HaEmek, Daliyat al-Karmel',
#        'Yokneam Illit, Harish, umm al-Fahm',
#        'Shfaram, Kiryat Atta, Migdal HaEmek',
#        "Shfaram, Kiryat Atta, Nof HaGalil (Nazareth Illit), Sakhnin, Karmiel, Safed, Beit Jann, Ma'a lot Tarshicha, Deir al-Asad",
#        "Yarka, Acre, Karmiel, Deir al-Asad, Nahariya, Shlomi, Ma'a lot Tarshicha, Beit Jann, Sakhnin",
#        "Shoham, Lod, Be'er Yacov, Modi'in-Maccabim-Re'ut, Ramla, Tel Aviv - Jaffa, Or Yehuda, Bat-Yam, Givat Shmuel, Kiryat Ono, Elad, Rehovot, Rishon LeZion, Ness Ziona, Bnei Brak, Givatayim, Mikveh Israel, Holon, Ramat Gan, Savyon, Yehud - Monoson, Petach Tikva",
#        "Ma'aleh Edomim",
#        'Nof HaGalil (Nazareth Illit), Afula, Migdal HaEmek, Nazareth',
#        'Atlit, Haifa, Tirat Carmel, Acre, Nahariya, Yarka, Kiryat Motzkin, Kiryat Atta, Kiryat Biyalik, Kiryat Yam, Shfaram',
#        'Kiryat Atta, Shfaram',
#        "Herzeliya, Ra'anana, Ramat HaSharon, Tel Aviv - Jaffa, Hod HaSharon, Kfar Saba, Rosh HaAyin, Kfar Kassem, Petach Tikva, Kfar Shmaryahu, Bnei Brak, Ramat Gan",
#        "Kiryat Atta, Kiryat Yam, Kiryat Biyalik, Kiryat Motzkin, Shfaram, Acre, Nahariya, Yarka, Shlomi, Ma'a lot Tarshicha, Deir al-Asad",
#        'Kfar Kassem, Tira, Hod HaSharon, Rosh HaAyin, Elad, Tayibe, Kfar Saba, Qalansawe, Kadima-Zoran, Karnei Shomron',
#        "Be'er Sheva, Kiryat Arba, Arad, Yeruham, Dimona, Hevron Jewish Settlement",
#        "None Be'er Sheva, Or Akiva, umm al-Fahm, Pardes Hanna - Karkur, Binyamina, Hadera, Caesarea, Harish, bqa al-Gharbiyye, Jerusalem, Ness Ziona, Modi'in-Maccabim-Re'ut, Rehovot, Tel Aviv - Jaffa, Mevasseret Zion, Be'er Yacov, Beitar Illit, Beit Shemesh, Mikveh Israel, Holon, Ramla, Lod, Rishon LeZion, Bat-Yam, Ma'aleh Edomim, Ramat Gan, Kadima-Zoran, Herzeliya, Yehud - Monoson, Kfar Saba, Or Yehuda, Rosh HaAyin, Savyon, Shoham, Netanya, Givatayim, Bnei Brak, Kiryat Ono, Kfar Kassem, Givat Shmuel, Tira, Ra'anana, Ramat HaSharon, Tayibe, Hod HaSharon, Ariel, Qalansawe, Elad, Petach Tikva, Kfar Shmaryahu, Karnei Shomron, Beit She'an, Yavne, Gdera, Yeruham, Kiryat Malachi, Ashdod, Ashkelon, Kiryat Gat, Gan Yavne, Zichron Yacov, Sderot, Hevron Jewish Settlement, Kiryat Arba, Netivot, Afula, Ofakim, Yokneam Illit, Migdal HaEmek, Arad, Sakhnin, Katzrin, Safed, Nof HaGalil (Nazareth Illit), Nazareth, Tiberias, Rosh Pinna",
#        'Dimona', 'Kiryat Biyalik, Kiryat Motzkin, Shlomi, Kiryat Yam',
#        'Nahariya, Acre, Shlomi', 'Bat-Yam', 'Sakhnin, Karmiel',
#        'Kiryat Biyalik, Kiryat Atta, Kiryat Yam, Shfaram, Kiryat Motzkin, Yarka',
#        'Haifa, Kiryat Yam, Kiryat Motzkin, Kiryat Biyalik, Kiryat Atta',
#        'Acre, Nahariya, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam',
#        'Caesarea, Zichron Yacov',
#        'Yokneam Illit, Nesher, Tirat Carmel, Atlit, Haifa, Daliyat al-Karmel, Isfiya',
#        'Karmiel, Deir al-Asad', 'Migdal HaEmek, Nazareth',
#        'Nesher, Haifa, Isfiya, Tirat Carmel, Kiryat Biyalik, Kiryat Atta, Kiryat Motzkin, Kiryat Yam',
#        'Sakhnin, Deir al-Asad, Karmiel, Yarka',
#        'Zichron Yacov, Hadera, Or Akiva, Caesarea, Binyamina, Atlit, Daliyat al-Karmel, Tirat Carmel, Haifa',
#        'Haifa, Tirat Carmel', "Ma'a lot Tarshicha, Karmiel",
#        'Holon, Rishon LeZion, Tel Aviv - Jaffa, Mikveh Israel, Bat-Yam, Gdera',
#        "Ma'a lot Tarshicha, Deir al-Asad, Karmiel",
#        'Nahariya, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Haifa, Acre',
#        'Ramla, Lod', 'Metulla, Tel Hai',
#        "Herzeliya, Ramat HaSharon, Tel Aviv - Jaffa, Kfar Saba, Rosh HaAyin, Petach Tikva, Hod HaSharon, Kfar Kassem, Ra'anana, Kfar Shmaryahu, Tira",
#        'Haifa, Kiryat Yam, Kiryat Motzkin, Kiryat Biyalik, Kiryat Atta, Nesher, Shfaram, Acre',
#        'Haifa, Kiryat Biyalik, Kiryat Atta, Kiryat Yam, Kiryat Motzkin',
#        'Kiryat Atta, Kiryat Biyalik, Haifa, Kiryat Motzkin, Yarka, Nesher, Kiryat Yam',
#        'Caesarea, Zichron Yacov, Tirat Carmel, Atlit',
#        'Kiryat Biyalik, Kiryat Atta, Kiryat Motzkin, Haifa, Kiryat Yam',
#        'Rosh Pinna, Katzrin, Safed', 'Acre, Nahariya',
#        'Kiryat Motzkin, Kiryat Yam, Kiryat Biyalik, Acre',
#        'Kiryat Atta, Nof HaGalil (Nazareth Illit), Shfaram, Deir al-Asad',
#        'Shfaram, Kiryat Atta, Yarka, Sakhnin, Acre, Deir al-Asad, Shlomi',
#        'Herzeliya, Kfar Shmaryahu, Ramat HaSharon, Hod HaSharon',
#        'Nesher, Atlit, Haifa, Tirat Carmel, Kiryat Atta',
#        'Acre, Kiryat Motzkin, Kiryat Yam, Kiryat Biyalik',
#        "Ma'a lot Tarshicha, Beit Jann",
#        'Haifa, Nesher, Tirat Carmel, Kiryat Atta, Kiryat Yam',
#        'Nahariya, Acre, Yarka, Kiryat Biyalik, Kiryat Motzkin',
#        'Deir al-Asad, Yarka, Karmiel, Sakhnin',
#        "Ma'a lot Tarshicha, Yarka",
#        'Haifa, Tirat Carmel, Nesher, Kiryat Yam',
#        'Netanya, Kadima-Zoran, Qalansawe, Harish, bqa al-Gharbiyye',
#        'Sakhnin, Karmiel, Deir al-Asad', 'Atlit, Tirat Carmel',
#        'Netanya, Hadera, Kadima-Zoran, Qalansawe, Tira',
#        'Zichron Yacov, Daliyat al-Karmel, Atlit',
#        'Atlit, Daliyat al-Karmel, Yokneam Illit, Or Akiva, Binyamina, Pardes Hanna - Karkur, Caesarea, Tirat Carmel, Haifa, Kiryat Atta, Kiryat Yam, Kiryat Biyalik, Isfiya, Nesher, Kiryat Motzkin',
#        'Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Haifa, Kiryat Atta',
#        "Karmiel, Ma'a lot Tarshicha, Deir al-Asad, Yarka",
#        'Nof HaGalil (Nazareth Illit), Nazareth, Shfaram, Sakhnin',
#        "Deir al-Asad, Yarka, Ma'a lot Tarshicha, Karmiel, Beit Jann",
#        "Haifa, Kiryat Biyalik, Kiryat Atta, Kiryat Yam, Shfaram, Kiryat Motzkin, Acre, Ma'a lot Tarshicha",
#        'Yokneam Illit, Daliyat al-Karmel, Migdal HaEmek, Kiryat Atta, Shfaram, Isfiya, Nesher',
#        'Kiryat Biyalik, Acre',
#        'Kiryat Motzkin, Kiryat Yam, Kiryat Biyalik, Kiryat Atta',
#        'Yokneam Illit, Tirat Carmel, Haifa',
#        'Kiryat Biyalik, Kiryat Atta, Kiryat Motzkin, Kiryat Yam, Haifa, Shfaram, Nesher',
#        'Daliyat al-Karmel, Tirat Carmel, Haifa, Atlit, Nesher, Isfiya, Kiryat Atta, Kiryat Yam, Kiryat Biyalik, Kiryat Motzkin',
#        'Shlomi, Nahariya, Acre',
#        'Haifa, Tirat Carmel, Daliyat al-Karmel, Isfiya, Nesher, Kiryat Atta, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Acre, Nahariya, Yarka',
#        'Haifa, Kiryat Yam', "Ma'a lot Tarshicha, Sakhnin, Karmiel",
#        'Daliyat al-Karmel, Kiryat Atta, Isfiya, Nesher',
#        'Acre, Karmiel, Deir al-Asad, Yarka, Kiryat Yam, Kiryat Biyalik, Haifa, Kiryat Motzkin, Shfaram, Sakhnin',
#        'Deir al-Asad, Karmiel',
#        "Tiberias, Nof HaGalil (Nazareth Illit), Beit She'an",
#        'Yokneam Illit, Isfiya, Daliyat al-Karmel, Nesher, Haifa, Tirat Carmel, Kiryat Atta, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Shfaram',
#        'Zichron Yacov, Herzeliya, Kfar Shmaryahu, Caesarea, Tel Aviv - Jaffa, Or Akiva, Binyamina, Bat-Yam, Ramat Gan, Kiryat Ono, Holon, Bnei Brak, Mikveh Israel, Givatayim, Or Yehuda, Rishon LeZion, Kiryat Shmona, Ramat HaSharon',
#        'Nahariya, Yarka',
#        'Acre, Kiryat Yam, Haifa, Kiryat Biyalik, Kiryat Motzkin, Kiryat Atta',
#        'Haifa, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Isfiya, Daliyat al-Karmel, Yokneam Illit',
#        'Zichron Yacov, Harish',
#        "Tel Aviv - Jaffa, Ramat HaSharon, Bnei Brak, Givatayim, Ramat Gan, Givat Shmuel, Petach Tikva, Kiryat Ono, Migdal HaEmek, Nazareth, Herzeliya, Ra'anana, Kfar Shmaryahu",
#        "Beit She'an, Afula, Tiberias",
#        "Petach Tikva, Tel Aviv - Jaffa, Ra'anana, Givatayim, Hod HaSharon, Ramat HaSharon, Herzeliya, Ramat Gan, Or Yehuda, Kiryat Ono, Savyon, Bnei Brak, Givat Shmuel, Kfar Saba, Rosh HaAyin, Kfar Kassem, Netanya, Kfar Shmaryahu",
#        'Zichron Yacov, Or Akiva, Binyamina, Pardes Hanna - Karkur, Caesarea, umm al-Fahm',
#        'Haifa, Kiryat Motzkin, Kiryat Biyalik, Kiryat Yam, Kiryat Atta, Nesher',
#        'Karmiel, Deir al-Asad, Yarka', 'Kiryat Shmona, Metulla',
#        'Kiryat Biyalik, Haifa, Kiryat Motzkin, Kiryat Yam',
#        'Hadera, Netanya, Karmiel',
#        'Sakhnin, Kiryat Atta, Haifa, Isfiya, Nesher',
#        'Acre, Shlomi, Yarka',
#        'Shlomi, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Nahariya, Haifa, Kiryat Atta',
#        'Nahariya, Nesher, Haifa, Acre, Yokneam Illit',
#        "Sakhnin, Ma'a lot Tarshicha, Karmiel, Deir al-Asad",
#        'Shfaram, Kiryat Atta, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Haifa',
#        'Yarka, Deir al-Asad, Karmiel', 'Kiryat Biyalik, Kiryat Atta',
#        "Sakhnin, Deir al-Asad, Karmiel, Ma'a lot Tarshicha",
#        "Tira, Kfar Saba, Ra'anana, Hod HaSharon, Herzeliya",
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Shlomi, Shfaram, Nahariya',
#        "Ma'a lot Tarshicha, Acre, Kiryat Yam, Kiryat Motzkin, Haifa, Kiryat Biyalik",
#        'Kiryat Motzkin, Kiryat Atta, Haifa, Kiryat Biyalik',
#        'Kiryat Atta, Shfaram, Yarka, Deir al-Asad',
#        'Kiryat Atta, Shfaram, Kiryat Biyalik, Nahariya, Acre, Kiryat Yam, Kiryat Motzkin, Yarka',
#        'Acre, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Haifa, Kiryat Atta, Nesher, Yokneam Illit',
#        'Zichron Yacov, Binyamina', 'Atlit, Shlomi',
#        'Nahariya, Shlomi, Katzrin',
#        'Kiryat Motzkin, Kiryat Yam, Kiryat Biyalik, Haifa, Kiryat Atta',
#        'Nahariya, Shlomi, Acre',
#        'Haifa, Kiryat Atta, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Nesher, Daliyat al-Karmel, Tirat Carmel, Isfiya, Atlit',
#        "None Netanya, Kadima-Zoran, Qalansawe, Tira, Tayibe, Yarka, Ramat Gan, Kiryat Ono, Petach Tikva, Givat Shmuel, Savyon, Nahariya, Yehud - Monoson, Be'er Yacov, Lod, Or Yehuda, Bnei Brak, Ramat HaSharon, Tel Aviv - Jaffa, Hod HaSharon, Ra'anana, Kfar Saba, Herzeliya, Kfar Kassem, Rosh HaAyin, Ness Ziona, Rishon LeZion, Elad, Ramla, Holon",
#        'Yehud - Monoson, Kiryat Ono, Petach Tikva, Savyon, Or Yehuda, Ramat Gan, Bnei Brak, Givat Shmuel, Elad, Shoham, Lod',
#        'Kiryat Biyalik, Kiryat Motzkin, Acre',
#        'Kiryat Motzkin, Kiryat Biyalik, Kiryat Yam, Nahariya, Acre, Shlomi, Haifa',
#        'Nesher, Atlit, Haifa, Tirat Carmel',
#        'Yarka, Kiryat Motzkin, Kiryat Yam, Haifa, Kiryat Biyalik',
#        'Nahariya, Shlomi, Yarka',
#        'Haifa, Kiryat Yam, Nazareth, Migdal HaEmek, Kiryat Motzkin, Kiryat Biyalik, Kiryat Atta, Acre',
#        'Kiryat Yam, Acre',
#        'Yokneam Illit, Petach Tikva, Kiryat Atta, Yarka, Shfaram, Hod HaSharon, Kfar Saba',
#        'Shlomi, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin',
#        'Tel Aviv - Jaffa, Bat-Yam, Rishon LeZion',
#        'Beit Shemesh, Kiryat Arba, Hevron Jewish Settlement',
#        "Ma'a lot Tarshicha, Karmiel, Deir al-Asad, Sakhnin, Yarka",
#        'Nahariya, Shlomi, Kiryat Atta, Kiryat Biyalik, Kiryat Motzkin, Yarka, Kiryat Yam, Haifa, Shfaram, Acre',
#        'Kiryat Biyalik, Kiryat Motzkin',
#        'Acre, Kiryat Biyalik, Kiryat Motzkin, Haifa, Kiryat Atta, Kiryat Yam',
#        'Tel Hai, Metulla', 'Haifa, Tirat Carmel, Acre',
#        "Tel Aviv - Jaffa, Bnei Brak, Givat Shmuel, Givatayim, Herzeliya, Savyon, Petach Tikva, Kiryat Ono, Ramat Gan, Ramat HaSharon, Hod HaSharon, Yehud - Monoson, Lod, Kfar Saba, Ra'anana",
#        'Mitzpeh Ramon',
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Nahariya',
#        "Hadera, Binyamina, Netanya, Pardes Hanna - Karkur, Daliyat al-Karmel, Atlit, Herzeliya, Ra'anana, Hod HaSharon, Kfar Shmaryahu, Kfar Saba",
#        'Kadima-Zoran', 'Qalansawe, Tayibe, Tira',
#        'Haifa, Nesher, Kiryat Yam, Kiryat Motzkin, Kiryat Atta, Kiryat Biyalik',
#        'Acre, Kiryat Biyalik, Kiryat Motzkin, Kiryat Atta, Haifa, Nesher, Isfiya, Daliyat al-Karmel',
#        'Yokneam Illit, Zichron Yacov, Caesarea, Or Akiva',
#        'Kiryat Yam, Haifa, Kiryat Motzkin, Kiryat Biyalik, Acre, Yarka',
#        'Kiryat Atta, Kiryat Biyalik, Haifa, Kiryat Motzkin',
#        'Kiryat Biyalik, Kiryat Motzkin, Shfaram',
#        'Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam, Haifa, Acre',
#        'Haifa, Tirat Carmel, Nesher, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam',
#        'Yavne, Ness Ziona',
#        "Ramat Gan, Bnei Brak, Mikveh Israel, Givatayim, Kiryat Ono, Or Yehuda, Bat-Yam, Petach Tikva, Givat Shmuel, Holon, Tel Aviv - Jaffa, Tayibe, Rosh HaAyin, Kadima-Zoran, Herzeliya, Netanya, Savyon, Kfar Saba, Tira, Ra'anana, Qalansawe, Hod HaSharon, Kfar Kassem, Ramat HaSharon, Kfar Shmaryahu",
#        'Nesher',
#        "Kadima-Zoran, Herzeliya, Kfar Saba, Ra'anana, Hadera, Netanya",
#        "Sakhnin, Karmiel, Ma'a lot Tarshicha, Deir al-Asad",
#        'Metulla, Kiryat Shmona, Safed, Rosh Pinna',
#        'Metulla, Kiryat Shmona, Tel Hai, Rosh Pinna',
#        'Acre, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Kiryat Atta, Haifa, Isfiya, Daliyat al-Karmel',
#        'Shlomi, Acre, Nahariya',
#        'Haifa, Nesher, Kiryat Atta, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin',
#        'Shfaram, Kiryat Biyalik',
#        "Tirat Carmel, Haifa, Ma'a lot Tarshicha",
#        'Acre, Kiryat Biyalik, Kiryat Motzkin, Kiryat Atta, Nahariya',
#        'Haifa, Kiryat Atta, Kiryat Biyalik, Nesher, Kiryat Motzkin, Isfiya, Kiryat Yam',
#        "Hadera, Pardes Hanna - Karkur, Netanya, Ra'anana, Kfar Shmaryahu, Herzeliya, Kadima-Zoran",
#        "Petach Tikva, Rosh HaAyin, Yehud - Monoson, Savyon, Hod HaSharon, Ramat Gan, Bnei Brak, Kiryat Ono, Tel Aviv - Jaffa, Givat Shmuel, Elad, Kfar Saba, Kfar Kassem, Ramat HaSharon, Ra'anana, Herzeliya",
#        'Nahariya, Shlomi, Haifa, Tirat Carmel, Yarka, Nesher',
#        'Kiryat Shmona, Majdal Shams',
#        'Shfaram, Kiryat Atta, Qalansawe, Tayibe, Daliyat al-Karmel, Isfiya, Nesher, Haifa, Kiryat Motzkin, Kiryat Yam, Kiryat Biyalik',
#        'Kfar Kassem, Petach Tikva, Hod HaSharon, Rosh HaAyin, Kfar Saba',
#        'Hadera, Qalansawe',
#        'Haifa, Nesher, Kiryat Atta, Kiryat Biyalik, Kiryat Motzkin, Kiryat Yam',
#        'Acre, Shfaram, Kiryat Atta',
#        'Acre, Kiryat Biyalik, Kiryat Yam, Kiryat Motzkin, Haifa, Nesher',
#        'Pardes Hanna - Karkur, Hadera, Harish, bqa al-Gharbiyye, Shlomi, Binyamina, Daliyat al-Karmel, Yokneam Illit, umm al-Fahm, Zichron Yacov, Or Akiva, Atlit, Isfiya',
#        "Lod, Modi'in-Maccabim-Re'ut, Beit Shemesh, Be'er Yacov, Ramla, Rehovot, Shoham",
#        "Mikveh Israel, Savyon, Petach Tikva, Kiryat Ono, Rishon LeZion, Ramat Gan, Ramat HaSharon, Elad, Be'er Yacov, Hod HaSharon, Kfar Kassem, Lod, Bnei Brak, Yehud - Monoson, Bat-Yam, Tel Aviv - Jaffa, Herzeliya, Ramla, Holon, Givatayim, Rosh HaAyin, Shoham, Or Yehuda, Givat Shmuel, Ra'anana, Kfar Shmaryahu, Kfar Saba",
#        "Rosh HaAyin, Ramla, Shoham, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Lod, Ramat Gan, Mikveh Israel, Ramat HaSharon, Yehud - Monoson, Hod HaSharon, Elad, Savyon, Herzeliya, Holon, Be'er Yacov, Rishon LeZion, Ness Ziona, Petach Tikva, Kiryat Ono",
#        "Lod, Rehovot, Modi'in-Maccabim-Re'ut, Rishon LeZion, Be'er Yacov, Ness Ziona, Ramla, Or Yehuda, Holon, Yehud - Monoson, Mikveh Israel, Shoham, Gdera, Yavne, Kiryat Ono, Tel Aviv - Jaffa, Savyon, Bat-Yam, Bnei Brak, Ramat Gan, Givat Shmuel, Petach Tikva, Givatayim",
#        "Lod, Ness Ziona, Ramla, Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Herzeliya, Holon, Yehud - Monoson, Mikveh Israel, Savyon, Petach Tikva, Kiryat Ono, Rishon LeZion, Rehovot, Ramat Gan, Be'er Yacov, Ashdod, Gdera, Yavne, Gan Yavne, Kiryat Malachi",
#        'Arad',
#        'Kiryat Arba, Arad, Hevron Jewish Settlement, Beitar Illit, Jerusalem, Beit Shemesh',
#        'Beitar Illit, Beit Shemesh', "Yeruham, Be'er Sheva",
#        "None Savyon, Petach Tikva, Kiryat Ono, Rishon LeZion, Rehovot, Ramat Gan, Ramat HaSharon, Ra'anana, Elad, Be'er Yacov, Beitar Illit, Kfar Kassem, Mikveh Israel, Rosh HaAyin, Bnei Brak, Yehud - Monoson, Modi'in-Maccabim-Re'ut, Kfar Saba, Tel Aviv - Jaffa, Or Yehuda, Lod, Bat-Yam, Mevasseret Zion, Ramla, Givatayim, Beit Shemesh, Hod HaSharon, Ness Ziona, Herzeliya, Holon, Kfar Shmaryahu, Shoham, Givat Shmuel",
#        'Ramat Gan, Or Yehuda, Tel Aviv - Jaffa, Rishon LeZion, Holon',
#        "None Hevron Jewish Settlement, Kiryat Arba, Beitar Illit, Jerusalem, Modi'in-Maccabim-Re'ut, Mevasseret Zion, Ma'aleh Edomim, Beit Shemesh",
#        'Gan Yavne, Ashdod, Yavne, Ashkelon',
#        'Kiryat Biyalik, Kiryat Motzkin, Haifa, Kiryat Atta, Kiryat Yam, Nahariya, Yarka, Acre',
#        'Jerusalem, Beitar Illit, Mevasseret Zion, Beit Shemesh, Arad, Hevron Jewish Settlement, Kiryat Arba',
#        "Jerusalem, Mevasseret Zion, Modi'in-Maccabim-Re'ut, Beitar Illit, Ma'aleh Edomim",
#        "Rishon LeZion, Be'er Yacov, Ramla, Lod, Bat-Yam, Givat Shmuel, Givatayim, Holon, Yehud - Monoson, Mikveh Israel, Savyon, Petach Tikva, Kiryat Ono, Rehovot, Ramat Gan, Elad, Bnei Brak, Or Yehuda, Tel Aviv - Jaffa, Ness Ziona, Shoham, Modi'in-Maccabim-Re'ut, Herzeliya, Kfar Shmaryahu, Netanya, Ramat HaSharon, Ra'anana",
#        "Tel Aviv - Jaffa, Or Yehuda, Bnei Brak, Bat-Yam, Givat Shmuel, Givatayim, Holon, Yehud - Monoson, Mikveh Israel, Savyon, Petach Tikva, Kiryat Ono, Rishon LeZion, Rehovot, Ramat Gan, Ramat HaSharon, Elad, Ramla, Shoham, Rosh HaAyin, Lod, Hod HaSharon, Be'er Yacov, Ness Ziona, Modi'in-Maccabim-Re'ut",
#        'Hevron Jewish Settlement, Kiryat Arba, Mevasseret Zion, Beit Shemesh, Jerusalem, Beitar Illit',
#        "Be'er Yacov, Lod, Ness Ziona, Rosh HaAyin, Ramla, Bnei Brak, Mikveh Israel, Or Yehuda, Yehud - Monoson, Tel Aviv - Jaffa, Rehovot, Holon, Ramat Gan, Petach Tikva, Givat Shmuel, Rishon LeZion, Shoham, Elad, Savyon, Bat-Yam, Kiryat Ono, Givatayim",
#        'Jerusalem, Beitar Illit, Beit Shemesh, Mevasseret Zion, Kiryat Arba, Hevron Jewish Settlement, Arad',
#        "Hevron Jewish Settlement, Kiryat Arba, Jerusalem, Modi'in-Maccabim-Re'ut, Beitar Illit, Beit Shemesh, Mevasseret Zion",
#        'Beitar Illit, Jerusalem, Beit Shemesh, Kiryat Arba, Hevron Jewish Settlement',
#        "None Nazareth, Karmiel, Yarka, Sakhnin, Shfaram, Ma'a lot Tarshicha, Nof HaGalil (Nazareth Illit), Kiryat Atta, Deir al-Asad, Beit Jann, Safed, Rosh Pinna, Tiberias",
#        'Jerusalem, Nazareth, Karmiel, Yarka, Sakhnin, Shfaram, Nof HaGalil (Nazareth Illit), Kiryat Atta, Deir al-Asad',
#        "Elad, Kfar Kassem, Lod, Rosh HaAyin, Ramla, Holon, Ramat Gan, Tel Aviv - Jaffa, Bnei Brak, Bat-Yam, Givatayim, Mikveh Israel, Rishon LeZion, Be'er Yacov, Kadima-Zoran, Qalansawe, Beit Shemesh, Givat Shmuel, Rehovot, Gdera, Kiryat Malachi None",
#        "Afula, Nof HaGalil (Nazareth Illit), Beit She'an, Tiberias",
#        'Yeruham, Shlomi', 'Kiryat Arba, Hevron Jewish Settlement',
#        "None Be'er Yacov, Elad, Yehud - Monoson, Ness Ziona, Hod HaSharon, Tel Aviv - Jaffa, Givat Shmuel, Ramat Gan, Givatayim, Rosh HaAyin, Rishon LeZion, Ramla, Herzeliya, Kfar Shmaryahu, Lod, Or Yehuda, Kiryat Ono, Bat-Yam, Holon, Shoham, Mikveh Israel, Bnei Brak, Petach Tikva, Kfar Saba, Savyon, Ramat HaSharon, Ra'anana, Rehovot, Tira",
#        "None Yavne, Gdera, Modi'in-Maccabim-Re'ut, Gan Yavne, Ashdod, Kiryat Malachi, Beit Shemesh, Ariel, Karnei Shomron, Mevasseret Zion, Tayibe, Netanya, Kadima-Zoran, Ramla, Shoham, Be'er Yacov, Bnei Brak, Tel Aviv - Jaffa, Yehud - Monoson, Givat Shmuel, Ramat Gan, Rishon LeZion, Savyon, Mikveh Israel, Or Yehuda, Bat-Yam, Holon, Givatayim, Lod, Elad, Hod HaSharon, Ramat HaSharon, Petach Tikva, Kiryat Ono, Rosh HaAyin, Rehovot, Ness Ziona",
#        'Kfar Saba, Kfar Kassem, Qalansawe, Tira',
#        "Be'er Yacov, Elad, Ness Ziona, Rehovot, Givat Shmuel, Ramat Gan, Rosh HaAyin, Rishon LeZion, Or Yehuda, Kiryat Ono, Shoham, Savyon, Modi'in-Maccabim-Re'ut, Yehud - Monoson, Tel Aviv - Jaffa, Givatayim, Ramla, Lod, Bat-Yam, Holon, Mikveh Israel, Bnei Brak, Petach Tikva, Kfar Kassem",
#        'bqa al-Gharbiyye, Harish, umm al-Fahm',
#        'Harish, bqa al-Gharbiyye', 'Nazareth',
#        'Nazareth, Nof HaGalil (Nazareth Illit), Migdal HaEmek',
#        "Migdal HaEmek, Modi'in-Maccabim-Re'ut, Jerusalem, Mevasseret Zion, Ashdod",
#        "Herzeliya, Rishon LeZion, Bat-Yam, Be'er Yacov, Tel Aviv - Jaffa, Holon, Givatayim, Kfar Shmaryahu, Hod HaSharon, Ramat HaSharon, Ra'anana, Mikveh Israel, Shoham, Or Yehuda, Bnei Brak, Givat Shmuel, Elad, Tira, Yehud - Monoson, Petach Tikva, Kfar Saba, Ramat Gan, Lod, Kiryat Ono, Savyon, Rosh HaAyin, Kfar Kassem",
#        "Ofakim, Be'er Sheva, Arad, Dimona, Yeruham",
#        'Harish, Pardes Hanna - Karkur',
#        'Binyamina, Or Akiva, Caesarea, Hadera',
#        "None Ofakim, Be'er Sheva, Yavne, Givat Shmuel, Bat-Yam, Mikveh Israel, Ness Ziona, Petach Tikva, Ramla, Kfar Kassem, Tel Aviv - Jaffa, Or Yehuda, Givatayim, Rosh HaAyin, Kfar Shmaryahu, Herzeliya, Kiryat Ono, Savyon, Lod, Yehud - Monoson, Rishon LeZion, Be'er Yacov, Elad, Ramat HaSharon, Holon, Rehovot, Ra'anana, Bnei Brak, Ramat Gan, Shoham, Hod HaSharon, Kfar Saba",
#        "Dimona, Arad, Be'er Sheva, Yeruham, Ofakim",
#        'Safed, Rosh Pinna, Beit Jann',
#        "Givat Shmuel, Bat-Yam, Mikveh Israel, Petach Tikva, Tel Aviv - Jaffa, Or Yehuda, Givatayim, Kfar Shmaryahu, Herzeliya, Kiryat Ono, Savyon, Yehud - Monoson, Rishon LeZion, Ramat HaSharon, Holon, Ra'anana, Bnei Brak, Ramat Gan, Hod HaSharon, Kfar Saba, Be'er Yacov, Kfar Kassem, Elad, Lod, Rosh HaAyin, Shoham, Qalansawe, Tira, Karnei Shomron, Kadima-Zoran, Tayibe",
#        'Afula, Nof HaGalil (Nazareth Illit), Nazareth',
#        "None Tel Hai, Metulla, Kiryat Shmona, Tel Aviv - Jaffa, Kfar Shmaryahu, Ramat Gan, Ramat HaSharon, Kiryat Ono, Petach Tikva, Rishon LeZion, Herzeliya, Lod, Savyon, Be'er Yacov, Or Yehuda, Givat Shmuel, Mikveh Israel, Yehud - Monoson, Hod HaSharon, Bnei Brak, Givatayim, Holon, Ra'anana, Haifa, Nesher",
#        'Rosh Pinna, Safed, Katzrin Afula, Zichron Yacov, Binyamina, Kiryat Atta, Yokneam Illit, Haifa, Tirat Carmel, Isfiya, Kiryat Motzkin, Daliyat al-Karmel, Kiryat Biyalik, Nesher, Shfaram, Kiryat Yam, Acre',
#        "None Yavne, Bat-Yam, Rishon LeZion, Rehovot, Be'er Yacov, Lod, Ness Ziona, Ramla, Givat Shmuel, Mikveh Israel, Petach Tikva, Kfar Kassem, Tel Aviv - Jaffa, Or Yehuda, Givatayim, Rosh HaAyin, Kfar Shmaryahu, Herzeliya, Tira, Kiryat Ono, Savyon, Yehud - Monoson, Elad, Netanya, Ramat HaSharon, Holon, Ra'anana, Bnei Brak, Ramat Gan, Hod HaSharon, Kadima-Zoran, Kfar Saba, Shoham, Ariel, Karnei Shomron, Qalansawe, Tayibe, Modi'in-Maccabim-Re'ut",
#        "Ma'aleh Edomim, Gan Yavne, Ashdod, Lod, Kiryat Ono, Karnei Shomron, Ariel",
#        "None Givat Shmuel, Petach Tikva, Kfar Kassem, Tel Aviv - Jaffa, Savyon, Yehud - Monoson, Rishon LeZion, Elad, Holon, Ra'anana, Shoham, Ramat Gan, Hod HaSharon, Herzeliya, Bat-Yam, Mikveh Israel, Ness Ziona, Ramla, Or Yehuda, Givatayim, Rosh HaAyin, Kfar Shmaryahu, Kiryat Ono, Lod, Be'er Yacov, Ramat HaSharon, Bnei Brak, Kfar Saba, Tira, Tayibe, Karnei Shomron",
#        "Shlomi, Ma'a lot Tarshicha, Tel Hai, Kiryat Shmona, Metulla",
#        'Safed, Rosh Pinna, Katzrin, Beit Jann',
#        "None Kfar Saba, Herzeliya, Tel Aviv - Jaffa, Netanya, Tira, Ra'anana, Elad, Kadima-Zoran, Givatayim, Karnei Shomron, Ramat HaSharon, Kiryat Ono, Rosh HaAyin, Ramat Gan, Petach Tikva, Savyon, Givat Shmuel, Kfar Kassem, Yehud - Monoson, Bnei Brak, Kfar Shmaryahu, Qalansawe, Tayibe, Hod HaSharon, Bat-Yam, Mikveh Israel, Or Yehuda, Holon, Hadera, bqa al-Gharbiyye, Ness Ziona, Be'er Yacov, Ramla, Rehovot, Shoham, Rishon LeZion, Lod, Yavne, Or Akiva, Binyamina, Pardes Hanna - Karkur, Caesarea, umm al-Fahm, Harish, Ariel",
#        'Shfaram, Nazareth, Afula, Kiryat Atta, Nesher, Haifa, Migdal HaEmek, Nof HaGalil (Nazareth Illit)',
#        "Dimona, Arad, Be'er Sheva",
#        'Beitar Illit, Kiryat Arba, Hevron Jewish Settlement',
#        'Arad, Hevron Jewish Settlement, Kiryat Arba',
#        "Modi'in-Maccabim-Re'ut, Beit Shemesh",
#        "Hevron Jewish Settlement, Kiryat Arba, Ma'aleh Edomim, Jerusalem, Beit Shemesh, Mevasseret Zion, Beitar Illit",
#        'Beitar Illit, Kiryat Arba, Hevron Jewish Settlement, Arad',
#        'Jerusalem, Beitar Illit, Mevasseret Zion, Beit Shemesh, Hevron Jewish Settlement, Kiryat Arba',
#        "Hod HaSharon, Lod, Ness Ziona, Rosh HaAyin, Ramla, Ramat Gan, Herzeliya, Tel Aviv - Jaffa, Be'er Yacov, Bnei Brak, Ramat HaSharon, Petach Tikva, Kfar Shmaryahu, Savyon, Shoham, Elad, Yehud - Monoson, Rehovot, Rishon LeZion, Bat-Yam, Givatayim, Holon, Or Yehuda, Givat Shmuel, Mikveh Israel, Kiryat Ono",
#        "Kiryat Arba, Hevron Jewish Settlement, Be'er Yacov, Kiryat Ono, Petach Tikva, Givat Shmuel, Mikveh Israel, Elad, Tel Aviv - Jaffa, Ramat Gan, Givatayim, Or Yehuda, Savyon, Ness Ziona, Bnei Brak, Rishon LeZion, Ramat HaSharon, Bat-Yam, Ramla, Shoham, Rehovot, Modi'in-Maccabim-Re'ut, Yehud - Monoson, Holon, Lod",
#        "Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabim-Re'ut, Rishon LeZion, Rehovot, Shoham, Be'er Yacov, Ramla"],
#       dtype=object)

# %%
raw_df['major_cities'].value_counts().to_frame()
# Out:
#                                                     count
# major_cities
# Sderot                                                434
# Ashkelon                                              266
# Kiryat Shmona                                         197
# Shlomi                                                179
# Metulla                                               172
# ...                                                   ...
# Sderot, Gan Yavne, Ashdod                               1
# Rishon LeZion, Holon, Mikveh Israel, Bat Yam, T...      1
# Sderot, Gan Yavne, Kiryat Malachi, Ashdod               1
# Rishon LeZion, Holon, Bat Yam, Yehud-Monosson, ...      1
# Beit Shemesh, Lod, Ness Ziona, Modi'in-Maccabim...      1
#
# [664 rows x 1 columns]

# %% [markdown]
# Let's see how useful the 'major_cities' and 'regional_councils' columns are.

# %%
# Count the number of values that are either "None" (as a string) or missing (NaN, None)
none_count = raw_df['major_cities'].apply(lambda x: x == "None" or pd.isna(x)).sum()
none_count_rc = raw_df['regional_councils'].apply(lambda x: x == "None" or pd.isna(x)).sum()

print(f"Number of rows with 'None' or missing values in major_cities: {none_count}")
print(f"Number of rows with 'None' or missing values in regional_councils: {none_count_rc}")
# Out:
# Number of rows with 'None' or missing values in major_cities: 4469
# Number of rows with 'None' or missing values in regional_councils: 6936

# %% [markdown]
# There are too many rows with missing values, meaning the columns are not very useful. I will not use it in the future.

# %% [markdown]
# **Raw_df Processing Summary**
#
# - **Extracted** data from **Telegram messages**.
# - **Removed** irrelevant rows (NaT dates, update messages).
# - **Fixed truncated messages** caused by split `div class="text"` blocks.
# - **Merged fragmented rows** (e.g., those starting with "•") into previous messages.
# - **Analyzed missing values**:
#   - `major_cities`: **4250 missing**
#   - `regional_councils`: **6613 missing**
#   - **Decided to exclude these columns** due to high data loss.
#
# The dataset is now cleaned, structured, and ready for further analysis.

# %% [markdown]
# ## Creating a dataset with an indication of detailed localities

# %%
def extract_alerts(text):
    alerts = []
    
    # Regex pattern for datetime in the format "DD/MM/YYYY HH:MM:SS:"
    date_pattern = re.compile(r'(\d{2}/\d{2}/\d{4} \d{2}:\d{2}:\d{2}):')
    
    # Find the first date occurrence and remove content before it
    first_date_match = date_pattern.search(text)
    if not first_date_match:
        return alerts  # If no date found, return an empty list
    text = text[first_date_match.start():]
    
    # Remove any content after the first occurrence of "||"
    if "||" in text:
        text = text.split("||")[0]
    
    # Regex to split the text into blocks (each block starts with a datetime)
    block_pattern = re.compile(
        r'(\d{2}/\d{2}/\d{4} \d{2}:\d{2}:\d{2}):'
        r'(.*?)(?=(\d{2}/\d{2}/\d{4} \d{2}:\d{2}:\d{2}:)|$)',
        re.DOTALL
    )
    
    # Iterate over each alert block
    for block_match in block_pattern.finditer(text):
        dt = block_match.group(1).strip()         # Extracted datetime
        block_text = block_match.group(2).strip()   # Text following the datetime
        
        # Split block text using bullet (•)
        bullet_parts = [
            part.strip() for part in re.split(r'\u2022', block_text)
            if part.strip()
        ]
        
        for part in bullet_parts:
            # Remove unwanted phrases such as "Click here to open an interactive map"
            # and "Sent by @CumtaAlertsEnglishChannel"
            part = re.sub(
                r'(Click here to open an interactive map|Sent by @CumtaAlertsEnglishChannel).*$', 
                '', part
            ).strip()
            
            # Determine if we use a dash (-) or a colon (:) as the separator
            dash_pos = part.find('-')
            colon_pos = part.find(':')
            
            if dash_pos != -1 and (colon_pos == -1 or dash_pos < colon_pos):
                # Case 1: "Region - locality1, locality2, ..."
                region_part, localities_part = part.split('-', 1)
            elif colon_pos != -1:
                # Case 2: "Region: locality1, locality2, ..."
                region_part, localities_part = part.split(':', 1)
            else:
                continue  # If neither separator exists, skip this entry
            
            # Clean up the extracted region name
            region = region_part.strip()
            region = re.sub(
                r'(Click here to open an interactive map|Sent by @CumtaAlertsEnglishChannel).*$', 
                '', region
            ).strip()
            region = region.rstrip(':- ').strip()
            
            # Clean localities
            localities_part = re.sub(
                r'(Click here to open an interactive map|Sent by @CumtaAlertsEnglishChannel).*$', 
                '', localities_part
            ).strip()
            localities = [loc.strip() for loc in localities_part.split(',') if loc.strip()]
            
            # If a region name is too generic, treat it as part of the locality
            generic_regions = {"Dan Area", "Lachish Area", "HaSharon Region", "Negev Region"}
            if region in generic_regions:
                for loc in localities:
                    alerts.append({
                        'datetime': dt,
                        'region': loc,
                        'locality': region
                    })  # Swap region/locality
            else:
                for loc in localities:
                    alerts.append({
                        'datetime': dt,
                        'region': region,
                        'locality': loc
                    })  # Normal case
    
    return alerts

# Process each row in raw_df to extract alerts
all_rows = []
for _, row in raw_df.iterrows():
    text = row['text']
    threat_type = row['threat_type']
    alerts = extract_alerts(text)
    for alert in alerts:
        alert['threat_type'] = threat_type
        all_rows.append(alert)

# Create a new DataFrame with detailed alerts
detailed_df = pd.DataFrame(all_rows)

# %%
detailed_df
# Out:
#                    datetime   region                 locality  \
# 0       26/12/2018 10:05:01  Dan 158    Tel Aviv (South West)
# 1       26/12/2018 10:05:01  Dan 156         Tel Aviv (North)
# 2       26/12/2018 10:05:01  Dan 157       Tel Aviv (Central)
# 3       26/12/2018 10:05:01  Dan 159    Tel Aviv (South East)
# 4       26/12/2018 10:05:01  Dan 162                     Azur
# ...                     ...      ...                      ...
# 129091  05/10/2025 04:59:22   Yarkon  Modi'in - Ishpro Center
# 129092  05/10/2025 18:34:40    Eilat                    Eilat
# 129093  05/10/2025 18:32:20    Eilat                    Eilat
# 129094  05/10/2025 18:33:24    Eilat                    Eilat
# 129095  05/10/2025 18:35:50    Eilat                    Eilat
#
#                   threat_type
# 0                   Red Alert
# 1                   Red Alert
# 2                   Red Alert
# 3                   Red Alert
# 4                   Red Alert
# ...                       ...
# 129091              Red Alert
# 129092              Red Alert
# 129093  Unrecognized Aircraft
# 129094  Unrecognized Aircraft
# 129095  Unrecognized Aircraft
#
# [129096 rows x 4 columns]

# %%
# looking at the lines with the date of October 1, 2024 from 19 to 20 (the Iranian attack)
detailed_df[
    (detailed_df['datetime'] >= '01/10/2024 19:50:00') &
    (detailed_df['datetime'] < '01/10/2024 20:00:00')
].tail(20)
# Out:
#                   datetime          region        locality threat_type
# 68516  01/10/2024 19:58:36      West Negev      Bror Hayil   Red Alert
# 68517  01/10/2024 19:58:36      West Negev     Talmei Bilu   Red Alert
# 68518  01/10/2024 19:58:36          Yehuda            Neta   Red Alert
# 68519  01/10/2024 19:58:36          Yehuda         Shomria   Red Alert
# 68520  01/10/2024 19:58:36   Gaza Envelope          Gvaram   Red Alert
# 68521  01/10/2024 19:58:52  Shfelat Yehuda        Zekharia   Red Alert
# 68522  01/10/2024 19:58:52  Shfelat Yehuda    Kfar Zoharim   Red Alert
# 68523  01/10/2024 19:58:52  Shfelat Yehuda           Luzit   Red Alert
# 68524  01/10/2024 19:58:52      West Negev           Zru'a   Red Alert
# 68525  01/10/2024 19:58:52      West Negev   Havat Shikmim   Red Alert
# 68526  01/10/2024 19:58:52      West Negev         Mabu'im   Red Alert
# 68527  01/10/2024 19:58:52         Lachish          Zrahia   Red Alert
# 68528  01/10/2024 19:58:52         Lachish       Yad Natan   Red Alert
# 68529  01/10/2024 19:58:52         Lachish         Menucha   Red Alert
# 68530  01/10/2024 19:58:52         Lachish  Merkaz Shapira   Red Alert
# 68531  01/10/2024 19:58:52         Lachish   Masuot Itzhak   Red Alert
# 68532  01/10/2024 19:58:52         Lachish           Negba   Red Alert
# 68533  01/10/2024 19:58:52         Lachish          Nehora   Red Alert
# 68534  01/10/2024 19:58:52    West Lachish          Heletz   Red Alert
# 68535  01/10/2024 19:58:52    West Lachish  Kokhav Michael   Red Alert

# %%
detailed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129096 entries, 0 to 129095
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   datetime     129096 non-null  object
#  1   region       129096 non-null  object
#  2   locality     129096 non-null  object
#  3   threat_type  129096 non-null  object
# dtypes: object(4)
# memory usage: 3.9+ MB

# %%
detailed_df['datetime'] = pd.to_datetime(detailed_df['datetime'], dayfirst=True, errors='coerce')

# %%
# Let's check what the contents of the first row of the column 'text' look like.
raw_df.loc[0, 'text']
# Out:
# 'Red Alert at Dan (155,156,157,158,159,160,161,162,165), Sharon (140,141,143) [10:05]: 26/12/2018 10:05:01: • Dan 158 - Tel Aviv (South West) • Dan 156 - Tel Aviv (North) • Dan 157 - Tel Aviv (Central) • Dan 159 - Tel Aviv (South East) • Dan 162 - Azur, Holon, Mikveh Israel • Dan 155 - Galil Yam, Hakfar Hayarok, Herzliya, Kfar Shmariyahu, Ramat Hasharon • Dan 160 - Bnei Brak, Givatiim, Havat Shalem, Ramat Gan • Sharon 140 - Givat He\'\'n, Raanana, Givat He""n • Dan 161 - Ganei Tikvah, Givat Shmuel, Kfar Azar, Kiriyat Ono, Naveh Efal, Neve Efraim Monosson, Or Yehuda, Ramat Efal, Ramat Pinkas, Savion, Yahud Monoson, Ramat Gan - Bar Ilan University, Ramat Gan - Ramat Ef\'al & Tel Hashomer • Dan 165 - Bat Yam • Sharon 143 - Adanim, Elishama, Ganei Am, Hagor, Hod Hsharon, Horashim, Jaljulia, Kfar Bara, Kfar Kasem, Kfar Mal\'\'al, Matan, Matan, Naveh Yarak, Nirit, Oranit, Oranit, Ramot Hshavim, Sdei Hemed, Yarhiv, Yarkona, Kfar Mal""al • Sharon 141 - Beit Berl, Gan Chaim, Kfar Saba, Naveh Yamin, Nir Eliyahu, Sade Verburg|| Major Cities: Tel Aviv, Holon, Herzliya, Ramat Gan, Bnei Brak, Or Yehuda, Yehud, Kiryat Ono, Bat Yam, Hod HaSharon, Kfar Saba |||| Regional Councils: Southern Sharon ||Click here to open an interactive map'

# %%
# Check
detailed_df.head(20)
# Out:
#               datetime      region               locality threat_type
# 0  2018-12-26 10:05:01     Dan 158  Tel Aviv (South West)   Red Alert
# 1  2018-12-26 10:05:01     Dan 156       Tel Aviv (North)   Red Alert
# 2  2018-12-26 10:05:01     Dan 157     Tel Aviv (Central)   Red Alert
# 3  2018-12-26 10:05:01     Dan 159  Tel Aviv (South East)   Red Alert
# 4  2018-12-26 10:05:01     Dan 162                   Azur   Red Alert
# 5  2018-12-26 10:05:01     Dan 162                  Holon   Red Alert
# 6  2018-12-26 10:05:01     Dan 162          Mikveh Israel   Red Alert
# 7  2018-12-26 10:05:01     Dan 155              Galil Yam   Red Alert
# 8  2018-12-26 10:05:01     Dan 155         Hakfar Hayarok   Red Alert
# 9  2018-12-26 10:05:01     Dan 155               Herzliya   Red Alert
# 10 2018-12-26 10:05:01     Dan 155        Kfar Shmariyahu   Red Alert
# 11 2018-12-26 10:05:01     Dan 155         Ramat Hasharon   Red Alert
# 12 2018-12-26 10:05:01     Dan 160              Bnei Brak   Red Alert
# 13 2018-12-26 10:05:01     Dan 160               Givatiim   Red Alert
# 14 2018-12-26 10:05:01     Dan 160           Havat Shalem   Red Alert
# 15 2018-12-26 10:05:01     Dan 160              Ramat Gan   Red Alert
# 16 2018-12-26 10:05:01  Sharon 140            Givat He''n   Red Alert
# 17 2018-12-26 10:05:01  Sharon 140                Raanana   Red Alert
# 18 2018-12-26 10:05:01  Sharon 140            Givat He""n   Red Alert
# 19 2018-12-26 10:05:01     Dan 161           Ganei Tikvah   Red Alert

# %% [markdown]
# ### ⚠ Checking the distribution of data by year

# %%
# Convert the 'time' column to datetime format
detailed_df['datetime'] = pd.to_datetime(detailed_df['datetime'], 
                                         errors='coerce', format='%d/%m/%Y %H:%M:%S')

# Extract the year from the datetime column
detailed_df['year'] = detailed_df['datetime'].dt.year

# Count the number of warnings per year
warnings_by_year = detailed_df['year'].value_counts().sort_index()

# Calculate the percentage each year represents
percentages = (warnings_by_year / warnings_by_year.sum()) * 100

# Combine counts and percentages into a DataFrame
result_df = pd.DataFrame({
    'Count': warnings_by_year,
    'Percentage': percentages.round(2).astype(str) + '%'
})

# Display the result
print('Distribution of data by year in detailed_df:')
result_df
# Out:
# Distribution of data by year in detailed_df:
#       Count Percentage
# year
# 2018     60      0.05%
# 2019   4425      3.43%
# 2020    324      0.25%
# 2021  29368     22.75%
# 2022   1032       0.8%
# 2023  14786     11.45%
# 2024  32722     25.35%
# 2025  46379     35.93%

# %%
# Use the existing 'date' column which already contains datetime values
raw_df['year'] = raw_df['date'].dt.year

# Count the number of alerts per year
warnings_by_year = raw_df['year'].value_counts().sort_index()

# Calculate the percentage each year represents
percentages = (warnings_by_year / warnings_by_year.sum()) * 100

# Combine counts and percentages into a DataFrame
raw_result_df = pd.DataFrame({
    'Count': warnings_by_year,
    'Percentage': percentages.round(2).astype(str) + '%'  # Append '%' to the rounded percentages
})

# Display the result
print('Distribution of data by year in raw_df:')
raw_result_df
# Out:
# Distribution of data by year in raw_df:
#       Count Percentage
# year
# 2018      1      0.01%
# 2019    405      5.44%
# 2020     75      1.01%
# 2021    999     13.42%
# 2022    240      3.22%
# 2023   1926     25.87%
# 2024   3421     45.94%
# 2025    379      5.09%

# %% [markdown]
# ⚠ WARNING ⚠ Issue Identified:
#
# There is a noticeable discrepancy in the data distribution by year between the two datasets, `detailed_df` and `raw_df`.
#
# - In **`detailed_df`**, the year **2021** accounts for **35.09%** of the dataset.
# - In **`raw_df`**, the year **2021** represents only **14.06%** of the dataset.
#
# Also, all our information initially consists of 15 files. The alarm lines for 2021 take up slightly less than 2 files out of 15, that is, about 13-14%
#
#
# There is also a significant difference in 2025 (5.05% in **`raw_df`** compared to 34.75% in **`detailed_df`**), but this is explained by the change in the nature of the conflict - in 2025, the coverage area of each alert was much larger.

# %% [markdown]
# ### Checking threat types

# %%
print('Number of threat types:', detailed_df['threat_type'].nunique())
detailed_df['threat_type'].unique()
# Out:
# Number of threat types: 5
# array(['Red Alert', 'Unrecognized Aircraft', 'Terrorist Infiltration',
#        'Interception pieces', 'Earthquake'], dtype=object)

# %% [markdown]
# ### Checking the 'region' and 'locality' columns

# %%
print('Number of regions:', detailed_df['region'].nunique())
detailed_df['region'].unique()
# Out:
# Number of regions: 185
# array(['Dan 158', 'Dan 156', 'Dan 157', 'Dan 159', 'Dan 162', 'Dan 155',
#        'Dan 160', 'Sharon 140', 'Dan 161', 'Dan 165', 'Sharon 143',
#        'Sharon 141', 'Eilat 311', 'Arabah 310', 'Lakhish 246',
#        'Gaza Containment Zone 225', 'Gaza Containment Zone 224',
#        'Jerusalem 194', 'Maale Adumim 200', 'Samaria 127',
#        'Gaza Containment Zone 236',
#        'Central Negev / Gaza Containment Zone 238',
#        'Gaza Containment Zone 237', 'Gaza Containment Zone 230',
#        'Gaza Containment Zone 220', 'Gaza Containment Zone 219',
#        'Gaza Containment Zone 221', 'Hefer 139',
#        'Gaza Containment Zone 218', 'Central Negev 254',
#        'Central Negev 255', 'Central Negev / Gaza Containment Zone 216',
#        'Gaza Containment Zone 223', 'Gaza Containment Zone 233',
#        'Gaza Containment Zone 232', 'Gaza Containment Zone 231',
#        'Gaza Containment Zone 228', 'Gaza Containment Zone 222',
#        'Gaza Containment Zone 217', 'Lakhish 247', 'Gaza containment 224',
#        'Gaza containment 220', 'Gaza containment 219',
#        'Gaza containment 221', 'Central Negev 252',
#        'Gaza containment 225', 'Central Negev', 'Gaza containment 223',
#        'Gaza containment 222', 'Gaza containment 230',
#        'Gaza containment 218', 'Gaza containment 217', 'Lakhish 250',
#        'Lakhish 249', 'Lakhish 248', 'Central Negev 253',
#        'Gaza containment 227', 'Gaza containment 231', 'Lakhish 245',
#        'Southern Shfela 268', 'Shfela', 'Southern Shfela 187',
#        'Lakhish 276', 'Lakhish 275', 'Lakhish 273', 'Lakhish 272',
#        'Lakhish 271', 'Gaza containment 236', 'Gaza containment 233',
#        'Gaza containment 232', 'Gaza containment 237', 'Lakhish 281',
#        'Beit Shemesh', 'Lakhish 282', 'Lakhish 278', 'Central Negev 288',
#        'Central Negev 256', 'Central Negev 289', 'Central Negev 291',
#        'Central Negev 287', 'Central Negev 292', 'Southern Negev 297',
#        'Southern Negev 296', 'Central Negev 286', 'Lakhish 280',
#        'Southern Shfela 266', 'Southern Shfela 267', 'Central Negev 300',
#        'Southern Negev 299', 'נירים', 'Lakhish', 'Confrontation line',
#        'Gaza Containment Zone', "Ye'arut HaCarmel (Carmel Forest)",
#        'Haifa', 'Hof HaCarmel', 'Menashe', 'Wadi Ara', 'כרכור',
#        'פרדס חנה', 'מטווח ניר עם', 'Lakhish Area',
#        'Gaza Containment Zone Area', 'Southern Shfela Area',
#        'Central Negev Area', 'Holon', 'Shfela (Lowlands) Area',
#        'מבטחים עמיעוז ישע Area', 'Tel Aviv - South and Jaffa',
#        'Tel Aviv - City Center', 'Bat Yam', 'Western Lakhish Area',
#        'Western Negev Area', 'Yarkon Area', 'Samaria Area',
#        'Beit Shemesh Area', 'Confrontation line Area', 'Golan Area',
#        'Southern Negev Area', 'Western Lakhish', 'Jerusalem',
#        'Western Negev', 'Southern Shfela', 'Dan', 'Shfela (Lowlands)',
#        'Hefer', 'Sharon', 'Yarkon', 'Samaria',
#        'Drom HaSharon Regional Council', 'Southern Negev', 'כוחלה מכחול',
#        'Judea', 'Tavor', 'Lower Galilee', 'Hakrayot', 'Upper Galilee',
#        'קריית שמונה', 'Golan', 'שדרות, איבים, ניר עם', 'Gaza Envelope',
#        'West Lachish', 'HaMifratz', 'Center Galilee', 'Center Negev',
#        'South Golan', 'Confrontation Line', 'HaShfela', 'Shomron',
#        'Yehuda', 'Lachish', 'West Negev', 'אשדוד', 'Shfelat Yehuda',
#        "Bika'a", 'South Negev', 'HaCarmel', "Beit She'an Valley",
#        'North Golan', 'HaAmakim', 'Kfar Yehoshua Train Station', 'Eilat',
#        'Arava', 'Dead Sea', 'לב החולה', 'צפת', 'חניון הנתיב מהיר',
#        'מודיעין מכבים רעות', 'אזור תעשייה רגמ', 'מיני ישראל',
#        'נאות קדומים', 'יהוד מונוסון', 'שוהם', 'נילי', 'איירפורט סיטי',
#        'מצוק עורבים', 'רמת טראמפ', 'רפטינג נהר הירדן', 'כפר נחום', 'טבחה',
#        'חוות אירוח גורן', 'איזור תעשייה מילואות צפון', 'מלון אחוזת ירדן',
#        'Milouot Industrial\xa0Zone\xa0North', 'ברחבי הארץ'], dtype=object)

# %%
print('Number of localities:', detailed_df['locality'].nunique())
print(detailed_df['locality'].unique())
# Out:
# Number of localities: 1730
# ['Tel Aviv (South West)' 'Tel Aviv (North)' 'Tel Aviv (Central)' ...
#  'Ardanel Ranch' 'ברחבי הארץ' 'Azuz']

# %%
# --- Hidden because of the large size ---
# Check how the localities were divided to fix the function, if necessary.
#detailed_df['locality'].to_string()

# %% [markdown]
# ### Checking localities and regions in Hebrew

# %%
# Checking if there are names of localities in Hebrew.
detailed_df[detailed_df['locality'].str.contains(r'[\u0590-\u05FF]', na=False)]
# Out:
#                   datetime      region         locality  \
# 2911   2019-06-13 00:14:56       נירים            נירים
# 3007   2019-07-31 10:05:05       כרכור            כרכור
# 3008   2019-07-31 10:05:05    פרדס חנה         פרדס חנה
# 3063   2019-07-31 10:06:12       כרכור            כרכור
# 3064   2019-07-31 10:06:12    פרדס חנה         פרדס חנה
# ...                    ...         ...              ...
# 59602  2024-09-21 14:00:37         צפת  עיר - צפת - עיר
# 59631  2024-09-21 17:47:51    לב החולה         לב החולה
# 97409  2025-06-14 01:12:14  ברחבי הארץ       ברחבי הארץ
# 97734  2025-06-14 01:12:14  ברחבי הארץ       ברחבי הארץ
# 114105 2025-06-20 15:44:15  ברחבי הארץ       ברחבי הארץ
#
#                   threat_type  year
# 2911                Red Alert  2019
# 3007                Red Alert  2019
# 3008                Red Alert  2019
# 3063                Red Alert  2019
# 3064                Red Alert  2019
# ...                       ...   ...
# 59602               Red Alert  2024
# 59631   Unrecognized Aircraft  2024
# 97409               Red Alert  2025
# 97734               Red Alert  2025
# 114105              Red Alert  2025
#
# [128 rows x 5 columns]

# %%
# Display all the localities in Hebrew with the number of times
detailed_df[detailed_df['locality'].str.contains(r'[\u0590-\u05FF]', 
                                                 na=False)].value_counts().to_frame()
# Out:
#                                                                                       count
# datetime            region      locality                  threat_type           year
# 2021-05-12 02:50:12 כוחלה מכחול כוחלה מכחול               Red Alert             2021     20
# 2021-05-12 02:51:10 כוחלה מכחול כוחלה מכחול               Red Alert             2021     19
# 2025-06-14 01:12:14 ברחבי הארץ  ברחבי הארץ                Red Alert             2025      2
# 2022-08-07 15:23:32 אשדוד       מרינה                     Red Alert             2022      2
#                                 יז                        Red Alert             2022      2
# ...                                                                                     ...
# 2024-09-13 13:03:59 צפת         נוף כנרת - צפת - נוף כנרת Unrecognized Aircraft 2024      1
# 2024-09-13 01:12:05 צפת         עכברה - צפת - עכברה       Red Alert             2024      1
#                                 עיר - צפת - עיר           Red Alert             2024      1
# 2024-09-13 01:11:33 צפת         עיר - צפת - עיר           Red Alert             2024      1
# 2025-06-20 15:44:15 ברחבי הארץ  ברחבי הארץ                Red Alert             2025      1
#
# [82 rows x 1 columns]

# %%
translation_dict = {
    "צפת": "Safed",
    "נירים": "Nirim",
    "אשדוד": "Ashdod",
    "איבים": "Ibim",
    "שדרות": "Sderot",
    "קריית שמונה": "Kiryat Shmona",
    "ניר עם": "Nir Am",
    "לב החולה": "Lev Ha-Hula",
    "פרדס חנה": "Pardes Hanna - Karkur",
    "כוחלה מכחול": "Kokhav Michael",
    "שוהם": "Shoham",
    "כרכור": "Karkur",
    "כפר נחום": "Kfar Naḥum",
    "מצוק עורבים": "Orevim Cliff",
    "איירפורט סיטי": "Airport City",
    "אזור תעשייה רמת גן": "Ramat Gan Industrial Zone",
    "רמת טראמפ": "Ramat Trump",
    "רכסים נהר הירדן": "Jordan River Terraces",
    "אזור תעשייה תעשייה רמת גן": "Ramat Gan Industrial Area",
    "חוות אירוח גורן": "Goren Guest Farm",
    "תחנה": "Station",
    "מוזיאון כוכבים רעים": "Bad Stars Museum",
    "מלון אחוזת ירדן": "Jordan Estate Hotel",
    "מיני ישראל": "Mini Israel",
    "נאות קדומים": "Neot Kedumim",
    "חניון הנגב מהר": "Negev Fast Parking Lot",
    "מלון מונזון": "Monzon Hotel",
    "יהוד מונוסון": "Yehud Monoson",
    "גני יהודה": "Ganei Yehuda",
    "רמת טראמפ": "Ramat Trump",
    "צוק עורבים": "Ravens' Cliff",
    "מכון תבנית מהר": "Fast Template Institute",
    "מבטחים עמיעוז ישע": "Mivtachim Ami'oz Yesha",
    "רפטינג נהר הירדן": "Jordan River Rafting",
    "אזור תעשייה רגמ": "Regem Industrial Zone",
    "חניון הנתיב מהיר": "Fast Lane Parking Lot",
    "מודיעין מכבים רעות": "Modiin Maccabim Reut",
    "נילי": "Nili",
    "טבחה": "Tabgha",
    "איזור תעשייה מילואות צפון": "Miluot North Industrial Zone"
}



# Function to replace entire string if it contains a Hebrew name
def replace_entire_entry(text, translation_dict):
    if pd.isna(text):  # Handle NaN values safely
        return text
    for hebrew, english in translation_dict.items():
        if hebrew in text:  # If any Hebrew name appears in the text
            return english  # Replace the entire text with the English name
    return text  # Otherwise, keep the original value

# Apply the function to 'locality' and 'region' columns
detailed_df['locality'] = (
    detailed_df['locality']
    .astype(str)
    .str.strip()
    .apply(lambda x: replace_entire_entry(x, translation_dict))
)

detailed_df['region'] = (
    detailed_df['region']
    .astype(str)
    .str.strip()
    .apply(lambda x: replace_entire_entry(x, translation_dict))
)

# %%
# Display all the localities in Hebrew with the number of times
detailed_df[detailed_df['locality'].str.contains(r'[\u0590-\u05FF]', 
                                                 na=False)].value_counts().to_frame()
# Out:
#                                                             count
# datetime            region     locality   threat_type year
# 2022-08-06 12:01:18 Ashdod     טו         Red Alert   2022      2
#                                יב         Red Alert   2022      2
#                                יז         Red Alert   2022      2
#                                מרינה      Red Alert   2022      2
# 2022-08-07 15:23:32 Ashdod     טו         Red Alert   2022      2
#                                יב         Red Alert   2022      2
#                                יז         Red Alert   2022      2
#                                מרינה      Red Alert   2022      2
# 2025-06-14 01:12:14 ברחבי הארץ ברחבי הארץ Red Alert   2025      2
# 2022-08-06 12:01:18 Ashdod     יא         Red Alert   2022      1
#                                סיט        Red Alert   2022      1
# 2022-08-07 15:23:32 Ashdod     יא         Red Alert   2022      1
#                                סיט        Red Alert   2022      1
# 2025-06-20 15:44:15 ברחבי הארץ ברחבי הארץ Red Alert   2025      1

# %%
# List of Hebrew words to be removed from the 'locality' column
words_to_remove = ["טו", "יב", "יז", "מרינה", "יא", "סיט"]

# Filter the DataFrame to exclude rows where 'locality' contains any of the specified words
detailed_df = detailed_df[~detailed_df['locality'].isin(words_to_remove)]

# Display all the localities in Hebrew with the number of times
detailed_df[detailed_df['locality'].str.contains(r'[\u0590-\u05FF]', 
                                                 na=False)].value_counts().to_frame()
# Out:
#                                                             count
# datetime            region     locality   threat_type year
# 2025-06-14 01:12:14 ברחבי הארץ ברחבי הארץ Red Alert   2025      2
# 2025-06-20 15:44:15 ברחבי הארץ ברחבי הארץ Red Alert   2025      1

# %% [markdown]
# I have translated all the Hebrew names into their English versions.

# %%
# Check again
detailed_df['region'].unique()
# Out:
# array(['Dan 158', 'Dan 156', 'Dan 157', 'Dan 159', 'Dan 162', 'Dan 155',
#        'Dan 160', 'Sharon 140', 'Dan 161', 'Dan 165', 'Sharon 143',
#        'Sharon 141', 'Eilat 311', 'Arabah 310', 'Lakhish 246',
#        'Gaza Containment Zone 225', 'Gaza Containment Zone 224',
#        'Jerusalem 194', 'Maale Adumim 200', 'Samaria 127',
#        'Gaza Containment Zone 236',
#        'Central Negev / Gaza Containment Zone 238',
#        'Gaza Containment Zone 237', 'Gaza Containment Zone 230',
#        'Gaza Containment Zone 220', 'Gaza Containment Zone 219',
#        'Gaza Containment Zone 221', 'Hefer 139',
#        'Gaza Containment Zone 218', 'Central Negev 254',
#        'Central Negev 255', 'Central Negev / Gaza Containment Zone 216',
#        'Gaza Containment Zone 223', 'Gaza Containment Zone 233',
#        'Gaza Containment Zone 232', 'Gaza Containment Zone 231',
#        'Gaza Containment Zone 228', 'Gaza Containment Zone 222',
#        'Gaza Containment Zone 217', 'Lakhish 247', 'Gaza containment 224',
#        'Gaza containment 220', 'Gaza containment 219',
#        'Gaza containment 221', 'Central Negev 252',
#        'Gaza containment 225', 'Central Negev', 'Gaza containment 223',
#        'Gaza containment 222', 'Gaza containment 230',
#        'Gaza containment 218', 'Gaza containment 217', 'Lakhish 250',
#        'Lakhish 249', 'Lakhish 248', 'Central Negev 253',
#        'Gaza containment 227', 'Gaza containment 231', 'Lakhish 245',
#        'Southern Shfela 268', 'Shfela', 'Southern Shfela 187',
#        'Lakhish 276', 'Lakhish 275', 'Lakhish 273', 'Lakhish 272',
#        'Lakhish 271', 'Gaza containment 236', 'Gaza containment 233',
#        'Gaza containment 232', 'Gaza containment 237', 'Lakhish 281',
#        'Beit Shemesh', 'Lakhish 282', 'Lakhish 278', 'Central Negev 288',
#        'Central Negev 256', 'Central Negev 289', 'Central Negev 291',
#        'Central Negev 287', 'Central Negev 292', 'Southern Negev 297',
#        'Southern Negev 296', 'Central Negev 286', 'Lakhish 280',
#        'Southern Shfela 266', 'Southern Shfela 267', 'Central Negev 300',
#        'Southern Negev 299', 'Nirim', 'Lakhish', 'Confrontation line',
#        'Gaza Containment Zone', "Ye'arut HaCarmel (Carmel Forest)",
#        'Haifa', 'Hof HaCarmel', 'Menashe', 'Wadi Ara', 'Karkur',
#        'Pardes Hanna - Karkur', 'Nir Am', 'Lakhish Area',
#        'Gaza Containment Zone Area', 'Southern Shfela Area',
#        'Central Negev Area', 'Holon', 'Shfela (Lowlands) Area',
#        "Mivtachim Ami'oz Yesha", 'Tel Aviv - South and Jaffa',
#        'Tel Aviv - City Center', 'Bat Yam', 'Western Lakhish Area',
#        'Western Negev Area', 'Yarkon Area', 'Samaria Area',
#        'Beit Shemesh Area', 'Confrontation line Area', 'Golan Area',
#        'Southern Negev Area', 'Western Lakhish', 'Jerusalem',
#        'Western Negev', 'Southern Shfela', 'Dan', 'Shfela (Lowlands)',
#        'Hefer', 'Sharon', 'Yarkon', 'Samaria',
#        'Drom HaSharon Regional Council', 'Southern Negev',
#        'Kokhav Michael', 'Judea', 'Tavor', 'Lower Galilee', 'Hakrayot',
#        'Upper Galilee', 'Kiryat Shmona', 'Golan', 'Ibim', 'Gaza Envelope',
#        'West Lachish', 'HaMifratz', 'Center Galilee', 'Center Negev',
#        'South Golan', 'Confrontation Line', 'HaShfela', 'Shomron',
#        'Yehuda', 'Lachish', 'West Negev', 'Ashdod', 'Shfelat Yehuda',
#        "Bika'a", 'South Negev', 'HaCarmel', "Beit She'an Valley",
#        'North Golan', 'HaAmakim', 'Kfar Yehoshua Train Station', 'Eilat',
#        'Arava', 'Dead Sea', 'Lev Ha-Hula', 'Safed',
#        'Fast Lane Parking Lot', 'Modiin Maccabim Reut',
#        'Regem Industrial Zone', 'Mini Israel', 'Neot Kedumim',
#        'Yehud Monoson', 'Shoham', 'Nili', 'Airport City', 'Orevim Cliff',
#        'Ramat Trump', 'Jordan River Rafting', 'Kfar Naḥum', 'Tabgha',
#        'Goren Guest Farm', 'Miluot North Industrial Zone',
#        'Jordan Estate Hotel', 'Milouot Industrial\xa0Zone\xa0North',
#        'ברחבי הארץ'], dtype=object)

# %% [markdown]
# ### Checking the number of types of city names
#
# We have relatively large cities that are divided into zones. Let's check how many such zones there are

# %%
# List of major cities
major_cities = [
    "Eilat", "Modi'in", "Hadera", "Caesarea", "Ramat Gan", "Haifa", "Bat Yam"
    "Beer Sheva", "Netanya", "Rishon LeZion", "Tel Aviv", "Ashdod", "Herzeliya", "Jerusalem", 
    "Beit Shemesh", "Ashkelon", "Rehovot", "Lod", "Ramla", "Holon", "Bat Yam", "Kfar Saba", 
    "Petach Tikva", "Tiberias", "Nahariya", "Safed", "Kiryat Shmona", "Acre",
    "Ma'ale Adumim", "Ariel", "Nazareth", "Atlit", "Sderot", "Ofakim", 
    "Dimona", "Yavne", "Kiryat Gat", "Kiryat Malakhi", "Migdal HaEmek", "Or Akiva",
    "Be'er Ya'akov", "Givatayim", "Yokneam Illit", "Tirat Carmel", "Karmiel", "Arad",
    "Ma'alot-Tarshiha", "Kiryat Ata", "Kiryat Bialik", "Kiryat Yam", "Kiryat Motzkin",
    "Nesher", "Afula", "Bnei Brak", "Kiryat Ono", "Or Yehuda", "Ramat HaSharon", 
    "El'ad", "Ganei Tikva", "Giv'at Shmuel", "Hod Hasharon", "Kafr Qasim", "Kfar Yona", 
    "Ness Ziona", "Qalansawe", "Ra'anana", "Rosh HaAyin", "Tayibe", "Tira", 
    "Yehud-Monosson", "Pardes Hanna-Karkur"
]

def get_localities_by_city(df, major_cities, column='locality'):
    """
    Function to retrieve unique localities for each major city.
    
    :param df: DataFrame containing the data.
    :param major_cities: List of major cities to check.
    :param column: Name of the column to search for localities (default is 'locality').
    :return: Dictionary where the key is the city and the value is a list of unique localities.
    """
    city_localities = {}
    for city in major_cities:
        # Filter the DataFrame and extract unique localities for the current city
        localities = df[df[column].str.contains(city, case=False, na=False)][column].unique()
        city_localities[city] = localities.tolist()  # Convert to a list for easier handling
        print(f"City: {city}, Localities: {city_localities[city]}")  # Debug output
        print("=" * 40)  # Separator line
    return city_localities

# Call the function
localities_by_city = get_localities_by_city(detailed_df, major_cities)
# Out:
# City: Eilat, Localities: ['Eilat']
# ========================================
# City: Modi'in, Localities: ["Modi'in", "Modi'in - Ishpro Center", "Modi'in - Ligad Center", "Hevel Modi'in Industrial Zone", "Modi'in Illit", "Regional Council Hevel Modi'in Industrial Park", "Modi'in Maccabim Re'ut"]
# ========================================
# City: Hadera, Localities: ['Hadera - East', 'Hadera - Center', 'Hadera - Neveh Haim', 'Hadera - West']
# ========================================
# City: Caesarea, Localities: ['Caesarea Industrial Zone', 'Caesarea', 'Caesarea Marine Center']
# ========================================
# City: Ramat Gan, Localities: ['Ramat Gan', 'Ramat Gan - Bar Ilan University', "Ramat Gan - Ramat Ef'al & Tel Hashomer", 'Ramat Gan - East', 'Ramat Gan - West']
# ========================================
# City: Haifa, Localities: ['Haifa - Carmel and Lower City', 'Haifa - West', "Haifa - Ramot HaCarmel and Neveh Sha'anan", 'Haifa - Kiryat Haim & Kiryat Shmuel', 'Haifa Bay', 'Haifa - Bay', 'Haifa - Carmel']
# ========================================
# City: Bat YamBeer Sheva, Localities: []
# ========================================
# City: Netanya, Localities: ['Netanya - East', 'Netanya - West']
# ========================================
# City: Rishon LeZion, Localities: ['Rishon LeZion - West', 'Rishon LeZion - East']
# ========================================
# City: Tel Aviv, Localities: ['Tel Aviv (South West)', 'Tel Aviv (North)', 'Tel Aviv (Central)', 'Tel Aviv (South East)', 'Tel Aviv - South and Jaffa', 'Tel Aviv - East', 'Tel Aviv - Across the Yarkon', 'Tel Aviv - City Center']
# ========================================
# City: Ashdod, Localities: ['Hatzor Ashdod', 'Ashdod', 'Ashdod - Yod Alef', 'Ashdod - Northern Industrial Zone and port', 'Ashdod - Alef', 'Ashdod - Gimmel', 'Ashdod - Het', 'Ashdod - Northen Industrial Zone', 'Ashdod-11', 'Ashdod Yacov Ichud']
# ========================================
# City: Herzeliya, Localities: ['Herzeliya - Pituach', 'Herzeliya - Center and Glil Yam']
# ========================================
# City: Jerusalem, Localities: ['Jerusalem', 'Jerusalem - East', 'Jerusalem - North and Alonim', 'Jerusalem - North', 'Jerusalem - Atarot Industrial Zone', 'Jerusalem - South', "Jerusalem - Qafr 'Aqab", 'Jerusalem - Center', 'Jerusalem - West']
# ========================================
# City: Beit Shemesh, Localities: ['Beit Shemesh']
# ========================================
# City: Ashkelon, Localities: ['Ashkelon', 'Ashkelon Industrial Area', 'Ashkelon Northern Industrial Zone', 'Ashkelon Southern Industrial Zone', 'Ashkelon - North', 'Ashkelon - South']
# ========================================
# City: Rehovot, Localities: ['Rehovot', 'Rehovot Science Park']
# ========================================
# City: Lod, Localities: ['Lod']
# ========================================
# City: Ramla, Localities: ['Nesher Industrial Zone (Ramla)', 'Ramla']
# ========================================
# City: Holon, Localities: ['Holon']
# ========================================
# City: Bat Yam, Localities: ['Bat Yam']
# ========================================
# City: Kfar Saba, Localities: ['Kfar Saba']
# ========================================
# City: Petach Tikva, Localities: ['Petach Tikva']
# ========================================
# City: Tiberias, Localities: ['Tiberias']
# ========================================
# City: Nahariya, Localities: ['Nahariya', 'Nahariya Cemetery']
# ========================================
# City: Safed, Localities: ['Safed', "Safed - 'Akbara", 'Safed - City', 'Safed - Nof ha-Kinneret']
# ========================================
# City: Kiryat Shmona, Localities: ['Kiryat Shmona']
# ========================================
# City: Acre, Localities: ['Acre']
# ========================================
# City: Ma'ale Adumim, Localities: []
# ========================================
# City: Ariel, Localities: ['Ariel', 'Ariel Industrial Park']
# ========================================
# City: Nazareth, Localities: ['Nazareth']
# ========================================
# City: Atlit, Localities: ['Atlit']
# ========================================
# City: Sderot, Localities: ['Sderot']
# ========================================
# City: Ofakim, Localities: ['Ofakim']
# ========================================
# City: Dimona, Localities: ['Dimona Industrial Zone', 'Dimona']
# ========================================
# City: Yavne, Localities: ['Gan Yavne', 'Yavne Region Industries', 'Yavne', 'Yavne Industrial Zone', 'Kvutzat Yavne', 'Kerem Yavneh', 'Kerem BeYavne', "Yavne'el", 'Sheni LeYavne']
# ========================================
# City: Kiryat Gat, Localities: ['Kiryat Gat', 'Kiryat Gat - Industrial Zone']
# ========================================
# City: Kiryat Malakhi, Localities: []
# ========================================
# City: Migdal HaEmek, Localities: ['Migdal HaEmek']
# ========================================
# City: Or Akiva, Localities: ['Or Akiva']
# ========================================
# City: Be'er Ya'akov, Localities: []
# ========================================
# City: Givatayim, Localities: ['Givatayim']
# ========================================
# City: Yokneam Illit, Localities: ['Yokneam Illit Industrial Zone', 'Yokneam Illit']
# ========================================
# City: Tirat Carmel, Localities: ['Tirat Carmel']
# ========================================
# City: Karmiel, Localities: ['Karmiel']
# ========================================
# City: Arad, Localities: ['Tel Arad and El Pura', 'Arad', 'Tel Arad']
# ========================================
# City: Ma'alot-Tarshiha, Localities: []
# ========================================
# City: Kiryat Ata, Localities: []
# ========================================
# City: Kiryat Bialik, Localities: ['Kiryat Bialik Industrial Zone']
# ========================================
# City: Kiryat Yam, Localities: ['Kiryat Yam']
# ========================================
# City: Kiryat Motzkin, Localities: ['Kiryat Motzkin']
# ========================================
# City: Nesher, Localities: ['Nesher Industrial Zone (Ramla)', 'Nesher']
# ========================================
# City: Afula, Localities: ['Afula']
# ========================================
# City: Bnei Brak, Localities: ['Bnei Brak']
# ========================================
# City: Kiryat Ono, Localities: ['Kiryat Ono']
# ========================================
# City: Or Yehuda, Localities: ['Or Yehuda']
# ========================================
# City: Ramat HaSharon, Localities: ['Ramat Hasharon', 'Ramat HaSharon']
# ========================================
# City: El'ad, Localities: []
# ========================================
# City: Ganei Tikva, Localities: ['Ganei Tikvah', 'Ganei Tikva']
# ========================================
# City: Giv'at Shmuel, Localities: []
# ========================================
# City: Hod Hasharon, Localities: ['Hod HaSharon']
# ========================================
# City: Kafr Qasim, Localities: []
# ========================================
# City: Kfar Yona, Localities: ['Kfar Yona', 'Kfar Yona Industrial Zone']
# ========================================
# City: Ness Ziona, Localities: ['Ness Ziona']
# ========================================
# City: Qalansawe, Localities: ['Qalansawe']
# ========================================
# City: Ra'anana, Localities: ["Ra'anana"]
# ========================================
# City: Rosh HaAyin, Localities: ['Rosh HaAyin']
# ========================================
# City: Tayibe, Localities: ['Tayibe']
# ========================================
# City: Tira, Localities: ['Tirah', 'Tirabin al-Sana and the Bedouin Diaspora', 'Tira Industrial Area', 'Tira', 'Tirat Yehuda', 'Tirabin', 'Tirat Carmel', 'Tirat Zvi', 'Tamra Industiral Park']
# ========================================
# City: Yehud-Monosson, Localities: ['Yehud-Monosson']
# ========================================
# City: Pardes Hanna-Karkur, Localities: []
# ========================================

# %% [markdown]
# Let's create a function that retrieves unique localities for a given city from a DataFrame. This function will filter the data based on the city name, extract distinct localities from the specified column, and return them as a list. Additionally, it will display the results in a structured format for better readability. This can be useful for analyzing geographic data and understanding the distribution of localities within a city.

# %%
def get_localities_by_city(df, city, column='locality'):
    """
    Function to retrieve unique localities for a specific city.

    :param df: DataFrame containing the data.
    :param city: The city to check (as a string).
    :param column: Name of the column to search for localities (default is 'locality').
    :return: List of unique localities for the specified city.
    """
    # Filter the DataFrame and extract unique localities for the city
    localities = df[df[column].str.contains(city, case=False, na=False)][column].unique()
    
    # Convert to list for easier handling
    localities_list = localities.tolist()
    
    # Print result for the city
    print(f"City: {city}")
    print("=" * 40)  # Separator line
    print("Localities:")
    if localities_list:
        print(", ".join(localities_list))
    else:
        print("No localities found")
    print("=" * 40)  # Separator line

    return localities_list

# %% [markdown]
# ⚠ The following check of the city zones was done using the ChatGPT to speed up and may contain errors. ⚠

# %%
get_localities_by_city(detailed_df, "Tel Aviv")
# Out:
# City: Tel Aviv
# ========================================
# Localities:
# Tel Aviv (South West), Tel Aviv (North), Tel Aviv (Central), Tel Aviv (South East), Tel Aviv - South and Jaffa, Tel Aviv - East, Tel Aviv - Across the Yarkon, Tel Aviv - City Center
# ========================================
# ['Tel Aviv (South West)',
#  'Tel Aviv (North)',
#  'Tel Aviv (Central)',
#  'Tel Aviv (South East)',
#  'Tel Aviv - South and Jaffa',
#  'Tel Aviv - East',
#  'Tel Aviv - Across the Yarkon',
#  'Tel Aviv - City Center']

# %% [markdown]
# The following entries are most likely part of Tel Aviv city in its classic sense: 'Tel Aviv (South West)',  'Tel Aviv (North)'
#  'Tel Aviv (Central)
#  'Tel Aviv (South East ',
#  'Tel Aviv - City Ce.
# te**Jaffa (Yafo)** is a distinct historic area often treated separately due to its unique cultural and historical significance. But let's classify this area as Tel Aviv, since it is officially part of the Tel Aviv-Yafo municipality.
# r']

# %%
get_localities_by_city(detailed_df, "Jerusalem")
# Out:
# City: Jerusalem
# ========================================
# Localities:
# Jerusalem, Jerusalem - East, Jerusalem - North and Alonim, Jerusalem - North, Jerusalem - Atarot Industrial Zone, Jerusalem - South, Jerusalem - Qafr 'Aqab, Jerusalem - Center, Jerusalem - West
# ========================================
# ['Jerusalem',
#  'Jerusalem - East',
#  'Jerusalem - North and Alonim',
#  'Jerusalem - North',
#  'Jerusalem - Atarot Industrial Zone',
#  'Jerusalem - South',
#  "Jerusalem - Qafr 'Aqab",
#  'Jerusalem - Center',
#  'Jerusalem - West']

# %% [markdown]
# Almost all entries from the list are officially part of Jerusalem, except 'Jerusalem - North and Alonim', which is potentially ambiguous, because "Alonim" may refer to areas adjacent to Jerusalem or informal names not officially within its boundaries. However, it should be included in Jerusalem for consistency, as such entries are often culturally or geographically associated with the city, ensuring unified classification and avoiding fragmentation in the dataset.

# %%
get_localities_by_city(detailed_df, "Ashdod")
# Out:
# City: Ashdod
# ========================================
# Localities:
# Hatzor Ashdod, Ashdod, Ashdod - Yod Alef, Ashdod - Northern Industrial Zone and port, Ashdod - Alef, Ashdod - Gimmel, Ashdod - Het, Ashdod - Northen Industrial Zone, Ashdod-11, Ashdod Yacov Ichud
# ========================================
# ['Hatzor Ashdod',
#  'Ashdod',
#  'Ashdod - Yod Alef',
#  'Ashdod - Northern Industrial Zone and port',
#  'Ashdod - Alef',
#  'Ashdod - Gimmel',
#  'Ashdod - Het',
#  'Ashdod - Northen Industrial Zone',
#  'Ashdod-11',
#  'Ashdod Yacov Ichud']

# %% [markdown]
# **'Hatzor Ashdod'** is not a part of Ashdod proper. The rest of the zones are officially part of it.

# %%
get_localities_by_city(detailed_df, "Ashkelon")
# Out:
# City: Ashkelon
# ========================================
# Localities:
# Ashkelon, Ashkelon Industrial Area, Ashkelon Northern Industrial Zone, Ashkelon Southern Industrial Zone, Ashkelon - North, Ashkelon - South
# ========================================
# ['Ashkelon',
#  'Ashkelon Industrial Area',
#  'Ashkelon Northern Industrial Zone',
#  'Ashkelon Southern Industrial Zone',
#  'Ashkelon - North',
#  'Ashkelon - South']

# %% [markdown]
# ⚠There are differing opinions in various sources regarding whether the industrial zones are officially part of Ashkelon. However, given their close proximity to residential areas, I assume their inclusion within the city for the purpose of analysis.⚠

# %%
get_localities_by_city(detailed_df, "Modi'in")
# Out:
# City: Modi'in
# ========================================
# Localities:
# Modi'in, Modi'in - Ishpro Center, Modi'in - Ligad Center, Hevel Modi'in Industrial Zone, Modi'in Illit, Regional Council Hevel Modi'in Industrial Park, Modi'in Maccabim Re'ut
# ========================================
# ["Modi'in",
#  "Modi'in - Ishpro Center",
#  "Modi'in - Ligad Center",
#  "Hevel Modi'in Industrial Zone",
#  "Modi'in Illit",
#  "Regional Council Hevel Modi'in Industrial Park",
#  "Modi'in Maccabim Re'ut"]

# %% [markdown]
# The following zones are officially part of Modi'in-Maccabim-Re'ut (the city): **Modi'in - Ishpro Center**, **Modi'in - Ligad Center**, **Modi'in-Maccabim-Re'ut**, **Modi'in Maccabim Re'ut**.
# The remaining entries, such as **Hevel Modi'in**, **Modi'in Illit**, and **industrial zones**, refer to nearby regional councils or separate municipalities and are not officially part of the city.

# %%
get_localities_by_city(detailed_df, "Ramat Gan")
# Out:
# City: Ramat Gan
# ========================================
# Localities:
# Ramat Gan, Ramat Gan - Bar Ilan University, Ramat Gan - Ramat Ef'al & Tel Hashomer, Ramat Gan - East, Ramat Gan - West
# ========================================
# ['Ramat Gan',
#  'Ramat Gan - Bar Ilan University',
#  "Ramat Gan - Ramat Ef'al & Tel Hashomer",
#  'Ramat Gan - East',
#  'Ramat Gan - West']

# %% [markdown]
# The entry "Ramat Gan - Ramat Ef'al & Tel Hashomer" partially refers to areas outside the city (e.g., Tel Hashomer, which belongs to Kiryat Ono).  The rest of the zones are officially part of the city.

# %%
get_localities_by_city(detailed_df, "Haifa")
# Out:
# City: Haifa
# ========================================
# Localities:
# Haifa - Carmel and Lower City, Haifa - West, Haifa - Ramot HaCarmel and Neveh Sha'anan, Haifa - Kiryat Haim & Kiryat Shmuel, Haifa Bay, Haifa - Bay, Haifa - Carmel
# ========================================
# ['Haifa - Carmel and Lower City',
#  'Haifa - West',
#  "Haifa - Ramot HaCarmel and Neveh Sha'anan",
#  'Haifa - Kiryat Haim & Kiryat Shmuel',
#  'Haifa Bay',
#  'Haifa - Bay',
#  'Haifa - Carmel']

# %% [markdown]
# The entry **"Haifa - Kiryat Haim & Kiryat Shmuel"** refers to neighborhoods that are administratively part of Haifa but are often considered distinct communities within the city. Other zones are officially part of Haifa.
#
# There are such inscriptions in the dataset in the areas of Haifa
# • Menashe - Haifa - Ramot HaCarmel and Neveh Sha'anan, Haifa - Carmel, Hadar and Downtown Lower City.
#
# That is, we have 'Hadar and Downtown Lower City'
# We should divide them into 'Haifa - Hadar' and 'Haifa - Downtown Lower City'
#
# ⚠ Also, there is a special case with the name Carmel ⚠

# %%
get_localities_by_city(detailed_df, "Carmel")
# Out:
# City: Carmel
# ========================================
# Localities:
# Yearot HaCarmel, Geva Carmel, Ein Carmel, Carmel, Haifa - Carmel and Lower City, Haifa - Ramot HaCarmel and Neveh Sha'anan, Tirat Carmel, Carmel Forest Spa Resort, Mevo Carmel Industrial Zone, Haifa - Carmel
# ========================================
# ['Yearot HaCarmel',
#  'Geva Carmel',
#  'Ein Carmel',
#  'Carmel',
#  'Haifa - Carmel and Lower City',
#  "Haifa - Ramot HaCarmel and Neveh Sha'anan",
#  'Tirat Carmel',
#  'Carmel Forest Spa Resort',
#  'Mevo Carmel Industrial Zone',
#  'Haifa - Carmel']

# %% [markdown]
# df[df['locality'] == 'Ashdod']Issue Explanation:⚠
#
# There is a **naming conflict** with the term **"Carmel"** in your dataset. **Carmel** can refer to multiple localities, and it’s important to differentiate between them to avoid misclassification.
#
#
# The following **localities are officially neighborhoods or areas within Haifa**:
#
# 1. **Haifa - Carmel and Lower City**
# 2. **Haifa - Ramot HaCarmel and Neveh Sha'anan**
# 3. **Haifa - Carmel**
#
# These names represent **recognized neighborhoods** in Haifa, situated on **Mount Carmel**, which is a central geographical feature of the city.
#
#
#
# These localities are **close to Haifa** and associated with the **Carmel region** but are **not administratively part of the city**:
#
# 1. **Tirat Carmel** – A separate city located just south of Haifa.
# 2. **Carmel Forest Spa Resort** – A famous resort located in the Carmel mountain range near Haifa.
# 3. **Mevo Carmel Industrial Zone** – An industrial area near the Carmel region but not within Haifa’s official boundaries.
# 4. **Hof HaCarmel** – Refers to the **Carmel Coast Regional Council**, which is a separate administrative region near Haifa.
#
#
# Some localities contain the name "Carmel" but are **not related to Haifa**:
#
# 1. **Yehuda - Carmel**  This is an **independent locality** located in the **Har Hevron (Mount Hebron) Regional Council** in the southern part of Israel, far from Haifa.
#
# 2. **Yearot HaCarmel, Geva Carmel, Ein Carmel**  These are **villages or settlements** in the broader Carmel region but **not part of Haifa's municipal jurisdiction**.

# %%
get_localities_by_city(detailed_df, 'Bat Yam')
# Out:
# City: Bat Yam
# ========================================
# Localities:
# Bat Yam
# ========================================
# ['Bat Yam']

# %% [markdown]
# Also 'Bat-Yam'

# %%
# Replace 'Bat-Yam' with 'Bat Yam' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Bat-Yam', 'Bat Yam', case=False, regex=True)

# %%
get_localities_by_city(detailed_df, 'Acre')
# Out:
# City: Acre
# ========================================
# Localities:
# Acre
# ========================================
# ['Acre']

# %% [markdown]
# Acre, but there are also 'Akko', 'Acco'

# %%
# Filter rows where 'locality' contains 'Akko' or 'Acco'
akko_variants = detailed_df[detailed_df['locality'].str.contains(r'Akko|Acco', case=False, na=False)]

# Display unique values
unique_akko_variants = akko_variants['locality'].unique()

# Print results
print("Unique locality values containing 'Akko' or 'Acco':")
for variant in unique_akko_variants:
    print(variant)
# Out:
# Unique locality values containing 'Akko' or 'Acco':
# Acco - Industrial Zone
# Akko New Cemetery

# %%
# Replace 'Acco' and 'Akko' with 'Acre' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Acco|Akko', 'Acre', case=False, regex=True)

# %%
get_localities_by_city(detailed_df, "Hadera")
# Out:
# City: Hadera
# ========================================
# Localities:
# Hadera - East, Hadera - Center, Hadera - Neveh Haim, Hadera - West
# ========================================
# ['Hadera - East', 'Hadera - Center', 'Hadera - Neveh Haim', 'Hadera - West']

# %% [markdown]
# All the listed zones are officially part of Hadera

# %%
get_localities_by_city(detailed_df, "Petach Tikva")
# Out:
# City: Petach Tikva
# ========================================
# Localities:
# Petach Tikva
# ========================================
# ['Petach Tikva']

# %% [markdown]
# Also 'Petah Tikva'

# %%
# Replace 'Petach Tikva' with 'Petah Tikva' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Petach Tikva', 'Petah Tikva', case=False, regex=True)

# %%
get_localities_by_city(detailed_df, "Caesarea")
# Out:
# City: Caesarea
# ========================================
# Localities:
# Caesarea Industrial Zone, Caesarea, Caesarea Marine Center
# ========================================
# ['Caesarea Industrial Zone', 'Caesarea', 'Caesarea Marine Center']

# %% [markdown]
# The following zones are officially part of Caesarea: Caesarea, Caesarea Marine Center
# The Caesarea Industrial Zone is a nearby industrial area but is not part of the residential or municipal core of Caesarea. But we will designate it as a part of the city, because we have done the same for the industrial zones of other cities.

# %%
get_localities_by_city(detailed_df, "Herzeliya")
# Out:
# City: Herzeliya
# ========================================
# Localities:
# Herzeliya - Pituach, Herzeliya - Center and Glil Yam
# ========================================
# ['Herzeliya - Pituach', 'Herzeliya - Center and Glil Yam']

# %% [markdown]
# All the listed zones are officially part of Herzeliya.
#
# There is also 'Herzliya'

# %%
get_localities_by_city(detailed_df, "Herzliya")
# Out:
# City: Herzliya
# ========================================
# Localities:
# Herzliya, Herzliya - West
# ========================================
# ['Herzliya', 'Herzliya - West']

# %%
# Replace 'Herzliya' with 'Herzeliya' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Herzliya', 'Herzeliya', case=False, regex=True)

# %%
get_localities_by_city(detailed_df, "Rehovot")
# Out:
# City: Rehovot
# ========================================
# Localities:
# Rehovot, Rehovot Science Park
# ========================================
# ['Rehovot', 'Rehovot Science Park']

# %% [markdown]
# All the listed zones are officially part of Rehovot

# %%
get_localities_by_city(detailed_df, "Ramla")
# Out:
# City: Ramla
# ========================================
# Localities:
# Nesher Industrial Zone (Ramla), Ramla
# ========================================
# ['Nesher Industrial Zone (Ramla)', 'Ramla']

# %% [markdown]
# Both of the mentioned localities are part of the city of Ramla:
#
# **Ramla** – This is the city itself, located in the central district of Israel.
#
# **Nesher Industrial Zone (Ramla)** – This is an industrial zone located within Ramla. It is named after Nesher, one of Israel’s leading cement manufacturers, and is situated within the city limits.

# %%
get_localities_by_city(detailed_df, "Nahariya")
# Out:
# City: Nahariya
# ========================================
# Localities:
# Nahariya, Nahariya Cemetery
# ========================================
# ['Nahariya', 'Nahariya Cemetery']

# %% [markdown]
# Both Nahariya and Nahariya Cemetery are part of the city:
#
# **Nahariya** – This is the city itself, located in the Northern District of Israel.
#
# **Nahariya Cemetery** – This is the city's cemetery, situated within the boundaries of Nahariya

# %%
get_localities_by_city(detailed_df, "Safed")
# Out:
# City: Safed
# ========================================
# Localities:
# Safed, Safed - 'Akbara, Safed - City, Safed - Nof ha-Kinneret
# ========================================
# ['Safed', "Safed - 'Akbara", 'Safed - City', 'Safed - Nof ha-Kinneret']

# %% [markdown]
# Belongs to the city:
# - **Safed** – Refers to the city itself, located in the Northern District of Israel.
# - **Safed - City** – Specifically refers to the central urban area of Safed.
# - **Safed - Nof ha-Kinneret** – A neighborhood or area within the municipal boundaries of Safed.
# - **Safed - 'Akbara** – Officially part of the city of Safed since 1977. 'Akbara is administered as a neighborhood within the city's municipal boundaries.
#
# So, **all** the listed localities belong to **Safed**.

# %%
get_localities_by_city(detailed_df, "Nazareth")
# Out:
# City: Nazareth
# ========================================
# Localities:
# Nazareth
# ========================================
# ['Nazareth']

# %% [markdown]
# Belongs to the city:
# - **Nazareth** – This is the city itself, located in the Northern District of Israel. It is the largest Arab city in the country and has its own independent municipality.
#
# Does **not** officially belong to the city:
# - **Nof HaGalil (Nazareth Illit)** – This is a separate city with its own municipality. Although it was originally established as a Jewish suburb of Nazareth, it became an independent city and officially changed its name from *Nazareth Illit* to *Nof HaGalil* in 2019.

# %%
get_localities_by_city(detailed_df, "Dimona")
# Out:
# City: Dimona
# ========================================
# Localities:
# Dimona Industrial Zone, Dimona
# ========================================
# ['Dimona Industrial Zone', 'Dimona']

# %% [markdown]
# **Both Dimona and Dimona Industrial Zone officially belong to the city of Dimona.**
#
# - **Dimona**
# This is the city itself, located in the Southern District of Israel. It has its own municipality and administrative boundaries.
#
# - **Dimona Industrial Zone**
# This industrial area is officially part of Dimona’s municipal jurisdiction. It serves as the city’s hub for industrial and economic activities but is distinct from the residential areas.

# %%
get_localities_by_city(detailed_df, "Yavne")
# Out:
# City: Yavne
# ========================================
# Localities:
# Gan Yavne, Yavne Region Industries, Yavne, Yavne Industrial Zone, Kvutzat Yavne, Kerem Yavneh, Kerem BeYavne, Yavne'el, Sheni LeYavne
# ========================================
# ['Gan Yavne',
#  'Yavne Region Industries',
#  'Yavne',
#  'Yavne Industrial Zone',
#  'Kvutzat Yavne',
#  'Kerem Yavneh',
#  'Kerem BeYavne',
#  "Yavne'el",
#  'Sheni LeYavne']

# %% [markdown]
# Only **Yavne** and the **Yavne Industrial Zone** are officially part of the city of Yavne. The other localities are separate entities and do not fall under Yavne's municipal jurisdiction.
#
# **Officially Part of Yavne:**
#
# - **Yavne**: The city itself, located in central Israel.
#
# - **Yavne Industrial Zone**: An industrial area within Yavne's municipal boundaries, serving as a hub for the city's industrial and economic activities.
#
# **Not Officially Part of Yavne:**
#
# - **Gan Yavne**: A local council situated east of Ashdod, operating as an independent municipality separate from Yavne.
#
# - **Yavne Region Industries**: This term likely refers to industrial areas in the broader Yavne region but not necessarily within Yavne's city limits.
#
# - **Hevel Yavne**: A regional council encompassing several communities in the area surrounding Yavne, but not part of the city itself.
#
# - **Kvutzat Yavne**: A religious kibbutz located near Yavne, falling under the jurisdiction of the Hevel Yavne Regional Council. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Kvutzat_Yavne?utm_source=chatgpt.com))
#
# - **Kerem Yavneh (Kerem BeYavne)**: A yeshiva and youth village adjacent to Kvutzat Yavne, also under the Hevel Yavne Regional Council. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Yeshivat_Kerem_B%27Yavneh?utm_source=chatgpt.com))
#
# - **Yavne'el**: A moshava in northern Israel, not geographically or administratively connected to the city of Yavne.
#
# - **Sheni LeYavne**: This term translates to "Second to Yavne" but does not correspond to a recognized locality within or near Yavne.

# %%
get_localities_by_city(detailed_df, "Kiryat Gat")
# Out:
# City: Kiryat Gat
# ========================================
# Localities:
# Kiryat Gat, Kiryat Gat - Industrial Zone
# ========================================
# ['Kiryat Gat', 'Kiryat Gat - Industrial Zone']

# %% [markdown]
# Both **Kiryat Gat** and **Kiryat Gat - Industrial Zone** officially belong to the city of **Kiryat Gat**.
#
# **Kiryat Gat**
# This is the city itself, located in the Southern District of Israel. It has its own municipality and serves as a regional center for the surrounding area.
#
# **Kiryat Gat - Industrial Zone**
# This industrial zone is officially part of Kiryat Gat’s municipal jurisdiction. It includes major industrial facilities and tech companies, contributing significantly to the city’s economy.

# %%
get_localities_by_city(detailed_df, "Yokneam Illit")
# Out:
# City: Yokneam Illit
# ========================================
# Localities:
# Yokneam Illit Industrial Zone, Yokneam Illit
# ========================================
# ['Yokneam Illit Industrial Zone', 'Yokneam Illit']

# %% [markdown]
#  Both **Yokneam Illit** and **Yokneam Illit Industrial Zone** are officially part of the city of **Yokneam Illit**.
#
# **Yokneam Illit**
# This is the city itself, located in northern Israel at the base of the Carmel Mountains. It has its own municipality and is known for its thriving high-tech industry.
#
# **Yokneam Illit Industrial Zone**
# This industrial area is officially part of Yokneam Illit’s municipal jurisdiction. It serves as a key hub for technological companies and industrial activities, contributing significantly to the city’s economy.

# %%
get_localities_by_city(detailed_df, "Arad")
# Out:
# City: Arad
# ========================================
# Localities:
# Tel Arad and El Pura, Arad, Tel Arad
# ========================================
# ['Tel Arad and El Pura', 'Arad', 'Tel Arad']

# %% [markdown]
# Only **Arad** is officially part of the city of **Arad**. The other localities mentioned are separate entities and do not fall under Arad's municipal jurisdiction.
#
# Officially Part of Arad:
#
# - **Arad**: This is the city itself, located in the Southern District of Israel, on the border of the Negev and Judean Deserts. It has its own municipality and administrative boundaries. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Arad%2C_Israel?utm_source=chatgpt.com))
#
# Not Officially Part of Arad:
#
# - **Tel Arad**: An archaeological site situated approximately 10 kilometers west of the modern city of Arad. It features the remains of a fortified Canaanite city and Israelite fortresses. Tel Arad is a national park and is not within the municipal boundaries of Arad. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Tel_Arad?utm_source=chatgpt.com))
#
# - **El Pura**: This locality is not widely recognized in available sources and does not appear to be officially associated with the city of Arad.

# %%
get_localities_by_city(detailed_df, "Kiryat Bialik")
# Out:
# City: Kiryat Bialik
# ========================================
# Localities:
# Kiryat Bialik Industrial Zone
# ========================================
# ['Kiryat Bialik Industrial Zone']

# %% [markdown]
# **The Kiryat Bialik Industrial Zone** is officially part of the city of **Kiryat Bialik**.

# %%
get_localities_by_city(detailed_df, "Kiryat Bialik")
# Out:
# City: Kiryat Bialik
# ========================================
# Localities:
# Kiryat Bialik Industrial Zone
# ========================================
# ['Kiryat Bialik Industrial Zone']

# %% [markdown]
# But there is also 'Kiryat Biyalik' in the dataset.

# %%
# Replace 'Herzliya' with 'Herzeliya' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Kiryat Biyalik', 'Kiryat Bialik', case=False, regex=True)

# %% [markdown]
# ### Updating the dataset (dividing zones)
#
# #### Haifa
# That is, we have 'Hadar and Downtown Lower City'
# We should divide them into 'Haifa - Hadar' and 'Haifa - Downtown Lower City'

# %%
expanded_rows = []
for _, row in detailed_df.iterrows():
    if row['locality'] == 'Hadar and Downtown Lower City':
        localities = ['Haifa - Hadar', 'Haifa - Downtown Lower City']
    elif row['locality'] == 'Haifa - Carmel and Lower City':
        localities = ['Haifa - Carmel', 'Haifa - Downtown Lower City']
    elif row['locality'] == "Haifa - Ramot HaCarmel and Neveh Sha'anan":
        localities = ['Haifa - Ramot HaCarmel', "Haifa - Neveh Sha'anan"]
    else:
        localities = [row['locality']]
    
    for loc in localities:
        new_row = row.copy()
        new_row['locality'] = loc
        expanded_rows.append(new_row)

# Overwrite the original DataFrame
detailed_df = pd.DataFrame(expanded_rows).reset_index(drop=True)

detailed_df[detailed_df['locality'].str.contains('Haifa', case=False, na=False)]
# Out:
#                   datetime     region                             locality  \
# 43174  2023-10-11 18:35:26    Menashe                       Haifa - Carmel
# 43175  2023-10-11 18:35:26    Menashe          Haifa - Downtown Lower City
# 43176  2023-10-11 18:35:26    Menashe                         Haifa - West
# 43177  2023-10-11 18:35:26    Menashe               Haifa - Ramot HaCarmel
# 43178  2023-10-11 18:35:26    Menashe               Haifa - Neveh Sha'anan
# ...                    ...        ...                                  ...
# 123678 2025-06-24 10:32:03  HaMifratz                         Haifa - West
# 123679 2025-06-24 10:32:03  HaMifratz                          Haifa - Bay
# 123680 2025-06-24 10:32:03  HaMifratz               Haifa - Ramot HaCarmel
# 123681 2025-06-24 10:32:03  HaMifratz               Haifa - Neveh Sha'anan
# 123682 2025-06-24 10:32:03  HaMifratz  Haifa - Kiryat Haim & Kiryat Shmuel
#
#                   threat_type  year
# 43174   Unrecognized Aircraft  2023
# 43175   Unrecognized Aircraft  2023
# 43176   Unrecognized Aircraft  2023
# 43177   Unrecognized Aircraft  2023
# 43178   Unrecognized Aircraft  2023
# ...                       ...   ...
# 123678              Red Alert  2025
# 123679              Red Alert  2025
# 123680              Red Alert  2025
# 123681              Red Alert  2025
# 123682              Red Alert  2025
#
# [552 rows x 5 columns]

# %% [markdown]
# In rare cases, in a text with localities, the city and zones are separated by commas, the line may be separated without specifying the city. For example, 'Haifa - Carmel, Hadar and Downtown Lower City'. It is worth checking how many rows in the dataset are separated in the case of Haifa.

# %%
keywords = ['Carmel', 'Downtown Lower City', 'Lower City', 'West', 
            'Hadar', 'Bay', 'Ramot HaCarmel', "Neveh Sha'anan"]

# Create a dictionary to store the counts
counts = {key: detailed_df[detailed_df['locality'] == key].shape[0] for key in keywords}

# Print the counts
for key, count in counts.items():
    print(f"{key}: {count} rows")
# Out:
# Carmel: 53 rows
# Downtown Lower City: 0 rows
# Lower City: 0 rows
# West: 0 rows
# Hadar: 0 rows
# Bay: 0 rows
# Ramot HaCarmel: 0 rows
# Neveh Sha'anan: 0 rows

# %%
# Replace 'Carmel' with 'Haifa - Carmel' in the 'locality' column except 'region' == 'Yehuda'
detailed_df['locality'] = detailed_df.apply(
    lambda row: (
        'Haifa - Carmel' 
        if row['locality'] == 'Carmel' and row['region'] != 'Yehuda' 
        else row['locality']
    ), 
    axis=1
)

# %%
# Check
get_localities_by_city(detailed_df, "Haifa")
# Out:
# City: Haifa
# ========================================
# Localities:
# Haifa - Carmel, Haifa - Downtown Lower City, Haifa - West, Haifa - Ramot HaCarmel, Haifa - Neveh Sha'anan, Haifa - Kiryat Haim & Kiryat Shmuel, Haifa Bay, Haifa - Bay, Haifa - Hadar
# ========================================
# ['Haifa - Carmel',
#  'Haifa - Downtown Lower City',
#  'Haifa - West',
#  'Haifa - Ramot HaCarmel',
#  "Haifa - Neveh Sha'anan",
#  'Haifa - Kiryat Haim & Kiryat Shmuel',
#  'Haifa Bay',
#  'Haifa - Bay',
#  'Haifa - Hadar']

# %%
# Print the counts
for key, count in counts.items():
    print(f"{key}: {count} rows")
# Out:
# Carmel: 53 rows
# Downtown Lower City: 0 rows
# Lower City: 0 rows
# West: 0 rows
# Hadar: 0 rows
# Bay: 0 rows
# Ramot HaCarmel: 0 rows
# Neveh Sha'anan: 0 rows

# %% [markdown]
# Nothing has changed for the name 'Carmel'.

# %% [markdown]
# #### Ashdod
# In the city of Ashdod, neighborhoods are often listed after the city's name, separated by commas. In the DataFrame, these neighborhoods are named directly as:
#
# Initially, we had these regions:
# - `Ashdod - Alef, Bet, Dalet, Heh`
# - `Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*`
# - `Ashdod - Gimmel, Vav, Zain`
# - `Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*`
# - `Ashdod-11,12,15,17,Marine,City`
#
# When creating detailed_df, these regions became separate rows in the dataframe, which could have skewed the distribution of the data.
#
# We have to do the following:
# - If we have 'Ashdod - Alef', we change it to 'Ashdod - Alef, Bet, Dalet, Heh'
# - If 'Ashdod - Yod Alef', we change it to 'Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*'
# - If we have 'Ashdod - Gimmel', we change it to 'Ashdod - Gimmel, Vav, Zain'
# - If we have 'Ashdod - Het', we change it to 'Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*'
# - If we have 'Ashdod-11', we change it to 'Ashdod - 11, 12, 15, 17, Marine, City'
#
# We also have strings from ashdod_zones =
# 'Alef', 'Bet', 'Dalet', 'Gimmel', 'Heh', 'Het', 'Tet',
# 'Yod', 'Yod Gimmel', 'Yod Dalet', 'Vav', 'Zain', 'Marine', 'City', '12', '15', '17',
#
# If 'locality' contains a string from ashdod_zones, it should be removed.

# %%
detailed_df[detailed_df['locality'] == 'Heh']
# Out:
#                   datetime        region locality threat_type  year
# 3105   2019-09-10 21:07:11  Lakhish Area      Heh   Red Alert  2019
# 3159   2019-11-12 05:50:59  Lakhish Area      Heh   Red Alert  2019
# 3302   2019-11-12 08:12:03  Lakhish Area      Heh   Red Alert  2019
# 3360   2019-11-12 08:31:19  Lakhish Area      Heh   Red Alert  2019
# 3955   2019-11-13 21:10:35  Lakhish Area      Heh   Red Alert  2019
# ...                    ...           ...      ...         ...   ...
# 117350 2025-06-22 07:46:05       Lachish      Heh   Red Alert  2025
# 118657 2025-06-23 10:27:57       Lachish      Heh   Red Alert  2025
# 120000 2025-06-23 10:46:16       Lachish      Heh   Red Alert  2025
# 125230 2025-07-22 05:50:09       Lachish      Heh   Red Alert  2025
# 128984 2025-10-01 20:48:40       Lachish      Heh   Red Alert  2025
#
# [249 rows x 5 columns]

# %%
# Dictionary for replacements
replacements = {
    'Ashdod - Alef': 'Ashdod - Alef, Bet, Dalet, Heh',
    'Ashdod - Yod Alef': 'Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*',
    'Ashdod - Gimmel': 'Ashdod - Gimmel, Vav, Zain',
    'Ashdod - Het': 'Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*',
    'Ashdod-11': 'Ashdod - 11, 12, 15, 17, Marine, City'
}

# Apply replacements
detailed_df['locality'] = detailed_df['locality'].replace(replacements)

# List of Ashdod zones to be removed
ashdod_zones = [
    'Alef', 'Bet', 'Dalet', 'Gimmel', 'Heh', 'Het', 'Tet', 'Ma*', 'Te*',
    'Yod', 'Yod Gimmel', 'Yod Dalet', 'Vav', 'Zain', 'Marine', 'City', '12', '15', '17'
]

# clean locality values
detailed_df = detailed_df[~detailed_df['locality'].isin(ashdod_zones)]

# %%
detailed_df[detailed_df['locality'] == 'Heh']
# Out:
# Empty DataFrame
# Columns: [datetime, region, locality, threat_type, year]
# Index: []

# %%
detailed_df[detailed_df['locality'].str.contains('Ashdod', case=False, na=False)]
# Out:
#                   datetime       region  \
# 732    2019-05-04 10:19:41  Lakhish 273
# 763    2019-05-04 10:19:47  Lakhish 271
# 985    2019-05-04 15:23:26  Lakhish 273
# 987    2019-05-04 15:23:29  Lakhish 271
# 1013   2019-05-04 15:24:17  Lakhish 273
# ...                    ...          ...
# 128981 2025-10-01 20:48:40      Lachish
# 128985 2025-10-01 20:48:40      Lachish
# 128991 2025-10-01 20:48:41      Lachish
# 128997 2025-10-01 20:48:41      Lachish
# 129000 2025-10-01 20:48:52      Lachish
#
#                                                  locality threat_type  year
# 732                                         Hatzor Ashdod   Red Alert  2019
# 763                                                Ashdod   Red Alert  2019
# 985                                         Hatzor Ashdod   Red Alert  2019
# 987                                                Ashdod   Red Alert  2019
# 1013                                        Hatzor Ashdod   Red Alert  2019
# ...                                                   ...         ...   ...
# 128981                     Ashdod - Alef, Bet, Dalet, Heh   Red Alert  2025
# 128985              Ashdod - 11, 12, 15, 17, Marine, City   Red Alert  2025
# 128991  Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet,...   Red Alert  2025
# 128997                         Ashdod - Gimmel, Vav, Zain   Red Alert  2025
# 129000                   Ashdod - Northen Industrial Zone   Red Alert  2025
#
# [1472 rows x 5 columns]

# %%
# Check
get_localities_by_city(detailed_df, "Ashdod")
# Out:
# City: Ashdod
# ========================================
# Localities:
# Hatzor Ashdod, Ashdod, Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*, Ashdod - Northern Industrial Zone and port, Ashdod - Alef, Bet, Dalet, Heh, Ashdod - Gimmel, Vav, Zain, Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Ashdod - Northen Industrial Zone, Ashdod - 11, 12, 15, 17, Marine, City, Ashdod Yacov Ichud
# ========================================
# ['Hatzor Ashdod',
#  'Ashdod',
#  'Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*',
#  'Ashdod - Northern Industrial Zone and port',
#  'Ashdod - Alef, Bet, Dalet, Heh',
#  'Ashdod - Gimmel, Vav, Zain',
#  'Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*',
#  'Ashdod - Northen Industrial Zone',
#  'Ashdod - 11, 12, 15, 17, Marine, City',
#  'Ashdod Yacov Ichud']

# %%
# Check
get_localities_by_city(detailed_df, "Eilat")
# Out:
# City: Eilat
# ========================================
# Localities:
# Eilat
# ========================================
# ['Eilat']

# %%
# Check
get_localities_by_city(detailed_df, "Eilot")
# Out:
# City: Eilot
# ========================================
# Localities:
# Eilot
# ========================================
# ['Eilot']

# %%
# Replace 'Eilot' with 'Eilat' in the 'locality' column
detailed_df.loc[:, 'locality'] = detailed_df['locality'].str.replace(r'Eilot', 'Eilat', case=False, regex=True)

# %%
detailed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125713 entries, 0 to 129202
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   datetime     125713 non-null  datetime64[ns]
#  1   region       125713 non-null  object
#  2   locality     125713 non-null  object
#  3   threat_type  125713 non-null  object
#  4   year         125713 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 5.8+ MB

# %%
detailed_df
# Out:
#                   datetime   region                 locality  \
# 0      2018-12-26 10:05:01  Dan 158    Tel Aviv (South West)
# 1      2018-12-26 10:05:01  Dan 156         Tel Aviv (North)
# 2      2018-12-26 10:05:01  Dan 157       Tel Aviv (Central)
# 3      2018-12-26 10:05:01  Dan 159    Tel Aviv (South East)
# 4      2018-12-26 10:05:01  Dan 162                     Azur
# ...                    ...      ...                      ...
# 129198 2025-10-05 04:59:22   Yarkon  Modi'in - Ishpro Center
# 129199 2025-10-05 18:34:40    Eilat                    Eilat
# 129200 2025-10-05 18:32:20    Eilat                    Eilat
# 129201 2025-10-05 18:33:24    Eilat                    Eilat
# 129202 2025-10-05 18:35:50    Eilat                    Eilat
#
#                   threat_type  year
# 0                   Red Alert  2018
# 1                   Red Alert  2018
# 2                   Red Alert  2018
# 3                   Red Alert  2018
# 4                   Red Alert  2018
# ...                       ...   ...
# 129198              Red Alert  2025
# 129199              Red Alert  2025
# 129200  Unrecognized Aircraft  2025
# 129201  Unrecognized Aircraft  2025
# 129202  Unrecognized Aircraft  2025
#
# [125713 rows x 5 columns]

# %% [markdown]
# ### ⚠ Handling Data Skew and Duplication in 2021
#
# Let's try to find the reasons for data skew.

# %%
# Separating the records for 2021 into a new dataset
detailed_df_2021 = detailed_df[detailed_df['year'] == 2021]

# %%
detailed_df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27503 entries, 4809 to 34176
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     27503 non-null  datetime64[ns]
#  1   region       27503 non-null  object
#  2   locality     27503 non-null  object
#  3   threat_type  27503 non-null  object
#  4   year         27503 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
# Looking at the first 60 entries
detailed_df_2021.head(60)
# Out:
#                 datetime                      region  \
# 4809 2021-03-11 21:08:41        Western Lakhish Area
# 4810 2021-03-11 21:08:41  Gaza Containment Zone Area
# 4811 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4812 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4813 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4814 2021-04-16 21:43:33  Gaza Containment Zone Area
# 4815 2021-04-16 21:43:33  Gaza Containment Zone Area
# 4816 2021-04-22 01:41:33         Southern Negev Area
# 4817 2021-04-23 22:59:05  Gaza Containment Zone Area
# 4818 2021-04-24 01:50:05  Gaza Containment Zone Area
# 4819 2021-04-24 01:50:11  Gaza Containment Zone Area
# 4820 2021-04-24 01:50:11  Gaza Containment Zone Area
# 4821 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4822 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4823 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4824 2021-04-24 02:12:11  Gaza Containment Zone Area
# 4825 2021-04-24 02:12:33  Gaza Containment Zone Area
# 4826 2021-04-24 02:30:34  Gaza Containment Zone Area
# 4827 2021-04-24 03:10:40  Gaza Containment Zone Area
# 4828 2021-04-24 03:10:40  Gaza Containment Zone Area
# 4829 2021-04-24 03:51:10  Gaza Containment Zone Area
# 4830 2021-04-24 04:58:28  Gaza Containment Zone Area
# 4831 2021-04-24 05:27:52  Gaza Containment Zone Area
# 4832 2021-04-24 05:27:55  Gaza Containment Zone Area
# 4833 2021-04-24 05:33:35  Gaza Containment Zone Area
# 4834 2021-04-24 05:35:19  Gaza Containment Zone Area
# 4835 2021-04-24 05:35:23  Gaza Containment Zone Area
# 4836 2021-04-24 05:35:47  Gaza Containment Zone Area
# 4837 2021-04-24 05:40:04  Gaza Containment Zone Area
# 4838 2021-04-24 05:41:04  Gaza Containment Zone Area
# 4839 2021-04-24 05:48:46        Western Lakhish Area
# 4840 2021-04-24 05:48:51  Gaza Containment Zone Area
# 4841 2021-04-24 05:48:51  Gaza Containment Zone Area
# 4842 2021-04-24 05:48:56  Gaza Containment Zone Area
# 4843 2021-04-24 05:48:56  Gaza Containment Zone Area
# 4844 2021-04-24 05:59:42        Western Lakhish Area
# 4845 2021-04-24 05:59:58  Gaza Containment Zone Area
# 4846 2021-04-24 05:59:58  Gaza Containment Zone Area
# 4847 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4848 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4849 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4850 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4851 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4852 2021-04-24 20:58:47  Gaza Containment Zone Area
# 4853 2021-04-24 20:58:47  Gaza Containment Zone Area
# 4854 2021-04-24 22:28:46  Gaza Containment Zone Area
# 4855 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4856 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4857 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4858 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4859 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4860 2021-04-28 00:18:55  Gaza Containment Zone Area
# 4861 2021-05-09 21:11:10             Western Lakhish
# 4862 2021-05-09 21:11:10       Gaza Containment Zone
# 4863 2021-05-09 21:11:10       Gaza Containment Zone
# 4864 2021-05-09 21:11:10       Gaza Containment Zone
# 4865 2021-05-09 21:11:10       Gaza Containment Zone
# 4866 2021-05-09 21:11:13             Western Lakhish
# 4867 2021-05-09 21:11:37             Western Lakhish
# 4868 2021-05-10 06:22:19       Gaza Containment Zone
#
#                                locality threat_type  year
# 4809  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4810                              Zikim   Red Alert  2021
# 4811                             Nir Am   Red Alert  2021
# 4812                             Sderot   Red Alert  2021
# 4813                               Ibim   Red Alert  2021
# 4814                              Holit   Red Alert  2021
# 4815                       Sdeh Avraham   Red Alert  2021
# 4816                         Abu Qrenat   Red Alert  2021
# 4817                           Kissufim   Red Alert  2021
# 4818             Kfar Maimon and Tushia   Red Alert  2021
# 4819                             Be'eri   Red Alert  2021
# 4820                             Alumim   Red Alert  2021
# 4821                          Mivtachim   Red Alert  2021
# 4822                              Amioz   Red Alert  2021
# 4823                              Yesha   Red Alert  2021
# 4824                         Nir Itzhak   Red Alert  2021
# 4825                    Tzohar and Ohad   Red Alert  2021
# 4826                     Netiv HaAssara   Red Alert  2021
# 4827                           Mefalsim   Red Alert  2021
# 4828                          Kfar Azza   Red Alert  2021
# 4829                          Nachal Oz   Red Alert  2021
# 4830                       Kerem Shalom   Red Alert  2021
# 4831                             Alumim   Red Alert  2021
# 4832                          Nachal Oz   Red Alert  2021
# 4833                     Netiv HaAssara   Red Alert  2021
# 4834                     Netiv HaAssara   Red Alert  2021
# 4835                           Kissufim   Red Alert  2021
# 4836                           Kissufim   Red Alert  2021
# 4837                           Kissufim   Red Alert  2021
# 4838                           Kissufim   Red Alert  2021
# 4839  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4840                              Zikim   Red Alert  2021
# 4841                             Karmia   Red Alert  2021
# 4842                      Yad Mordechai   Red Alert  2021
# 4843                     Netiv HaAssara   Red Alert  2021
# 4844  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4845                              Zikim   Red Alert  2021
# 4846                     Netiv HaAssara   Red Alert  2021
# 4847                              Gavim   Red Alert  2021
# 4848                      Sapir College   Red Alert  2021
# 4849                             Nir Am   Red Alert  2021
# 4850                             Sderot   Red Alert  2021
# 4851                               Ibim   Red Alert  2021
# 4852                           Mefalsim   Red Alert  2021
# 4853              Nir Am Shooting Range   Red Alert  2021
# 4854                              Nirim   Red Alert  2021
# 4855                             Nir Am   Red Alert  2021
# 4856                             Sderot   Red Alert  2021
# 4857                               Ibim   Red Alert  2021
# 4858                               Erez   Red Alert  2021
# 4859              Nir Am Shooting Range   Red Alert  2021
# 4860                           Kissufim   Red Alert  2021
# 4861  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4862                              Zikim   Red Alert  2021
# 4863                      Yad Mordechai   Red Alert  2021
# 4864                             Karmia   Red Alert  2021
# 4865                     Netiv HaAssara   Red Alert  2021
# 4866                           Ashkelon   Red Alert  2021
# 4867                           Mavki'im   Red Alert  2021
# 4868                          Kfar Azza   Red Alert  2021

# %% [markdown]
# Several lines with the same name of a locality can go one after the other. For example, Netiv HaAssara, Kissufim

# %%
detailed_df_2021[detailed_df_2021['locality'] == 'Kissufim'].head(10)
# Out:
#                 datetime                      region  locality threat_type  \
# 4817 2021-04-23 22:59:05  Gaza Containment Zone Area  Kissufim   Red Alert
# 4835 2021-04-24 05:35:23  Gaza Containment Zone Area  Kissufim   Red Alert
# 4836 2021-04-24 05:35:47  Gaza Containment Zone Area  Kissufim   Red Alert
# 4837 2021-04-24 05:40:04  Gaza Containment Zone Area  Kissufim   Red Alert
# 4838 2021-04-24 05:41:04  Gaza Containment Zone Area  Kissufim   Red Alert
# 4860 2021-04-28 00:18:55  Gaza Containment Zone Area  Kissufim   Red Alert
# 5246 2021-05-11 07:11:48       Gaza Containment Zone  Kissufim   Red Alert
# 5500 2021-05-11 13:29:50       Gaza Containment Zone  Kissufim   Red Alert
# 5523 2021-05-11 13:57:50       Gaza Containment Zone  Kissufim   Red Alert
# 5564 2021-05-11 15:13:17       Gaza Containment Zone  Kissufim   Red Alert
#
#       year
# 4817  2021
# 4835  2021
# 4836  2021
# 4837  2021
# 4838  2021
# 4860  2021
# 5246  2021
# 5500  2021
# 5523  2021
# 5564  2021

# %%
# Filtering the data for October 7, 2023 (massive attacks)
detailed_df[detailed_df['datetime'].dt.date == pd.to_datetime('2023-10-07').date()].head(50)
# Out:
#                  datetime         region                      locality  \
# 36407 2023-10-07 06:29:02            Dan                       Bat Yam
# 36408 2023-10-07 06:29:02        Lachish                     Palmachim
# 36409 2023-10-07 06:29:02       HaShfela          Rishon LeZion - West
# 36410 2023-10-07 06:29:03  Gaza Envelope                Netiv HaAssara
# 36411 2023-10-07 06:29:04  Gaza Envelope                 Yad Mordechai
# 36412 2023-10-07 06:29:20  Gaza Envelope                     Nachal Oz
# 36413 2023-10-07 06:29:22  Gaza Envelope                          Erez
# 36414 2023-10-07 06:29:24  Gaza Envelope                        Sderot
# 36415 2023-10-07 06:29:24  Gaza Envelope                          Ibim
# 36416 2023-10-07 06:29:24  Gaza Envelope                        Nir Am
# 36417 2023-10-07 06:29:27        Lachish  Kiryat Gat - Industrial Zone
# 36418 2023-10-07 06:29:27        Lachish                    Sdeh Moshe
# 36419 2023-10-07 06:29:31  Gaza Envelope                      Or HaNer
# 36420 2023-10-07 06:29:33  Gaza Envelope         Nir Am Shooting Range
# 36421 2023-10-07 06:29:33        Lachish                    Kiryat Gat
# 36422 2023-10-07 06:29:33        Lachish                    Karmei Gat
# 36423 2023-10-07 06:29:41  Gaza Envelope                     Kfar Azza
# 36424 2023-10-07 06:29:43  Gaza Envelope                         Tkuma
# 36425 2023-10-07 06:29:43  Gaza Envelope                        Zimrat
# 36426 2023-10-07 06:29:43  Gaza Envelope                         Shuva
# 36427 2023-10-07 06:29:48        Lachish                         Zohar
# 36428 2023-10-07 06:29:48        Lachish                       Shachar
# 36429 2023-10-07 06:29:48        Lachish                      Nir Chen
# 36430 2023-10-07 06:29:52  Gaza Envelope                         Zikim
# 36431 2023-10-07 06:30:08  Gaza Envelope                Netiv HaAssara
# 36432 2023-10-07 06:30:11  Gaza Envelope                      Mefalsim
# 36433 2023-10-07 06:30:14  Gaza Envelope                        Alumim
# 36434 2023-10-07 06:30:16  Gaza Envelope                        Nir Oz
# 36435 2023-10-07 06:30:16  Gaza Envelope                         Nirim
# 36436 2023-10-07 06:30:19  Gaza Envelope                      Kissufim
# 36437 2023-10-07 06:30:21  Gaza Envelope                     Nachal Oz
# 36438 2023-10-07 06:30:25  Gaza Envelope                          Sufa
# 36439 2023-10-07 06:30:26  Gaza Envelope                          Erez
# 36440 2023-10-07 06:30:32  Gaza Envelope                        Sderot
# 36441 2023-10-07 06:30:32  Gaza Envelope                          Ibim
# 36442 2023-10-07 06:30:32  Gaza Envelope                        Nir Am
# 36443 2023-10-07 06:30:35  Gaza Envelope                  Kerem Shalom
# 36444 2023-10-07 06:30:35  Gaza Envelope                 Ein HaShlosha
# 36445 2023-10-07 06:30:38  Gaza Envelope         Nir Am Shooting Range
# 36446 2023-10-07 06:30:39        Lachish                    Kiryat Gat
# 36447 2023-10-07 06:30:39        Lachish                    Karmei Gat
# 36448 2023-10-07 06:30:39  Gaza Envelope                      Or HaNer
# 36449 2023-10-07 06:30:45  Gaza Envelope                         Yevul
# 36450 2023-10-07 06:30:48  Gaza Envelope                         Holit
# 36451 2023-10-07 06:30:58     West Negev                          Urim
# 36452 2023-10-07 06:30:59  Gaza Envelope                       Pri Gan
# 36453 2023-10-07 06:31:01     West Negev                        Patish
# 36454 2023-10-07 06:31:01     West Negev                       Ze'elim
# 36455 2023-10-07 06:31:02  Gaza Envelope                  Sdeh Avraham
# 36456 2023-10-07 06:31:08        Lachish                       Shtulim
#
#       threat_type  year
# 36407   Red Alert  2023
# 36408   Red Alert  2023
# 36409   Red Alert  2023
# 36410   Red Alert  2023
# 36411   Red Alert  2023
# 36412   Red Alert  2023
# 36413   Red Alert  2023
# 36414   Red Alert  2023
# 36415   Red Alert  2023
# 36416   Red Alert  2023
# 36417   Red Alert  2023
# 36418   Red Alert  2023
# 36419   Red Alert  2023
# 36420   Red Alert  2023
# 36421   Red Alert  2023
# 36422   Red Alert  2023
# 36423   Red Alert  2023
# 36424   Red Alert  2023
# 36425   Red Alert  2023
# 36426   Red Alert  2023
# 36427   Red Alert  2023
# 36428   Red Alert  2023
# 36429   Red Alert  2023
# 36430   Red Alert  2023
# 36431   Red Alert  2023
# 36432   Red Alert  2023
# 36433   Red Alert  2023
# 36434   Red Alert  2023
# 36435   Red Alert  2023
# 36436   Red Alert  2023
# 36437   Red Alert  2023
# 36438   Red Alert  2023
# 36439   Red Alert  2023
# 36440   Red Alert  2023
# 36441   Red Alert  2023
# 36442   Red Alert  2023
# 36443   Red Alert  2023
# 36444   Red Alert  2023
# 36445   Red Alert  2023
# 36446   Red Alert  2023
# 36447   Red Alert  2023
# 36448   Red Alert  2023
# 36449   Red Alert  2023
# 36450   Red Alert  2023
# 36451   Red Alert  2023
# 36452   Red Alert  2023
# 36453   Red Alert  2023
# 36454   Red Alert  2023
# 36455   Red Alert  2023
# 36456   Red Alert  2023

# %% [markdown]
# In 2023, the duplication issue was fixed, and each alert is now uniquely generated, with no duplicate segments.

# %%
# Checking the unique names of localities
detailed_df_2021['locality'].unique()
# Out:
# array(['Ashkelon Southern Industrial Zone', 'Zikim', 'Nir Am', 'Sderot',
#        'Ibim', 'Holit', 'Sdeh Avraham', 'Abu Qrenat', 'Kissufim',
#        'Kfar Maimon and Tushia', "Be'eri", 'Alumim', 'Mivtachim', 'Amioz',
#        'Yesha', 'Nir Itzhak', 'Tzohar and Ohad', 'Netiv HaAssara',
#        'Mefalsim', 'Kfar Azza', 'Nachal Oz', 'Kerem Shalom', 'Karmia',
#        'Yad Mordechai', 'Gavim', 'Sapir College', 'Nir Am Shooting Range',
#        'Nirim', 'Erez', 'Ashkelon', "Mavki'im", "Sa'ad", 'Beit Nekofa',
#        'Mevasseret Zion', 'Motza Illit', 'Tzuba', 'Abu Ghosh',
#        'Givat Yearim', 'Ein Naqquba', 'Ein Rafa', 'Ramat Raziel',
#        'Shachar', 'Kiryat Gat', 'Karmei Gat', 'Even Sapir', 'Zanoah',
#        'Beit Zayit', 'Beit Shemesh', 'Bar Giora', 'Ness Harim',
#        'Har Adar', "Ma'aleh HaHamisha", 'Kiryat Anavim', 'Kiryat Yearim',
#        'Ksalon', 'Jerusalem - East', 'Center and West',
#        'Jerusalem - North and Alonim', 'Ein Kerem Boarding School',
#        'Zekharia', 'Agur', 'Sdot Micha', 'Srigim (Li-On)',
#        'Givat Ishayahu', 'Nehora', 'Nir Chen', 'Revacha', 'Beit Shikma',
#        'Nitzanim', "Ge'a", 'Nitzan', 'Bat Hadar', 'Talmei Yaffe',
#        'Ashkelon Northern Industrial Zone', 'Gvaram', 'Mishan',
#        'Havat Shikmim', 'Or HaNer', 'Zimrat and Shuva', 'Sufa',
#        'Ein HaShlosha', 'Berekhya', 'Kfar Silver', 'Pri Gan', 'Netivot',
#        'Shokeda', 'Dorot', 'Yakhini', 'Nir Moshe', 'Nir Akiva',
#        'Maagalim Givolim Melilot', "Be'er Ganim", 'Yevul',
#        'Mivtachim Amioz Yesha', 'Urim', 'Ein HaBsor', 'Hodaya',
#        'Bnei Ayish', 'Hatzor',
#        'Ashdod - Northern Industrial Zone and port', "Be'er Tuvia",
#        'Emunim', 'Beit Ezra', 'Givati', 'Ezer', 'Azrikam', 'Sdeh Uziahu',
#        'Shtulim', 'Ashdod - Alef, Bet, Dalet, Heh',
#        'Ashdod - Yod Alef, Yod Bet, Tet Vav, Yod Zain, Ma*', 'Yod Bet',
#        'Tet Vav', 'Yod Zain', 'Ashdod - Gimmel, Vav, Zain',
#        'Ashdod - Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*', 'Bnei Darom',
#        'Nir Galim', 'Gan HaDarom', 'Bnei Darom Compound',
#        'Ad Halom Industrial Zone', 'Gan Yavne', 'Kfar Aviv',
#        'Kerem BeYavne', 'Kvutzat Yavne', 'Bitzaron', 'Kfar Warburg',
#        'Masuot Itzhak', 'Givat Washington', 'Nir Israel', 'Magen',
#        'Nir Oz', 'Dekel', 'Yated', 'Talmei Yossef', 'Sdeh Nitzan',
#        "Tkuma and Havat Izra'am", 'Sharsheret', 'Tkuma', 'Beit HaGdi',
#        'Yoshivia', 'Tel Aviv - South and Jaffa', 'Bat Yam', 'Holon',
#        'Palmachim', 'Rishon LeZion - West', 'Kfar Yavetz', 'Kfar Avoda',
#        'Ein Vered', 'Ein Sarid', 'Porat', 'Tzoran', 'Qalansawe',
#        'Or Yehuda', 'Tel Aviv - East', 'Tel Aviv - Across the Yarkon',
#        'Azor', 'Bnei Brak', 'Givatayim', 'Yavne', 'Ben Zakai',
#        'Maon Tzofia', 'Rishon LeZion - East', 'Irus', 'Beit Hanan',
#        'Beit Oved', "Ge'alya", 'Kfar HaNagid', "Neta'im", 'Ness Ziona',
#        'Ayanot', 'Beit Dagan', 'Hemed', 'Mishmar HaShiva', 'Givat Hen',
#        'Givat HaShlosha', 'Gat Rimon', 'Kfar Sirkin', 'Maas', 'Elad',
#        "Be'erot Itzhak", 'Bnei Atarot', "Giv'at Ko'ah", 'Givat Shmuel',
#        'Yehud-Monosson', 'Savyon', 'Kiryat Ono', 'Ramat Gan - East',
#        'Gibton', 'Gan Shlomo', 'Beit Elazari', 'Gdera', 'Ganei Tal',
#        'Herzeliya - Pituach', 'Kfar Shmaryahu', 'Netanya - East',
#        'Netanya - West', 'Elishema', 'Beit Berl', 'Jaljulia', 'Gan Haim',
#        'Ganei Am', 'Netzer Sireni', 'Rehovot',
#        'Nesher Industrial Zone (Ramla)', 'Ahisemech', "Be'er Yacov",
#        'Ginaton', 'Gan Sorek', 'Orot', 'Mikveh Israel',
#        'Ramat Gan - West', 'Palmachin Industrial Park', 'Petah Tikva',
#        'Ramat HaSharon', 'Hod HaSharon', 'Ramot HaShavim', 'Bnei Zion',
#        'Batzra', 'HaSharon Prison', 'Tel Mond', 'Yanuv', 'Avigdor',
#        'Achva', 'Yinon', 'Kfar Achim', "Kfar HaRif and Re'em Junction",
#        'Arugot', 'Kiryat Malachi', 'Revadim', 'Timorim', 'Talmei Yehiel',
#        'Oranit', "Kokhav Ya'ir - Tzur Yigal", 'Alfei Menashe', 'Elkana',
#        'Eyal', 'Tayibe', "Ya'af", 'Azriel', 'Tzur Itzhak', 'Tzur Natan',
#        'Beit Hilkia', "Bnei Re'em", 'Hafetz Haim', 'Yad Binyamin',
#        'Ben Shemen', 'Ben Shemen Youth Village', 'Beit Hashmonai',
#        'Beit Uziel', 'Gezer', 'Hulda', 'Yad Rambam', 'Nirit',
#        'Beit Nechemia', "Beko'a", 'Tal Shachar', 'Yesodot',
#        'Netzer Hazani', 'Kfar Bin Nun', 'Kfar Shmuel', 'Karmei Yossef',
#        'Mishmar Ayalon', 'Mishmar David', 'Azaria', 'Pdaya', 'Ptachia',
#        "Modi'in - Ishpro Center", "Ma'aleh Shomron", 'Etz Ephraim',
#        'Tzofin', 'Karnei Shomron', "Sha'arei Tikva", 'Beit Arie', 'Salit',
#        'Elei Zahav', 'Paduel', 'Ofarim', 'Tira Industrial Area',
#        'Bnei Dror', 'Geulim', 'Herut', 'Mishmeret', 'Tzur Moshe',
#        'Kadima', 'Shafir', 'Timorimg Industrial Zone',
#        'Herzeliya - Center and Glil Yam', "Ra'anana", 'Kfar Saba',
#        'Sdeh Warburg', 'Ganei Tikva', 'Hagor', 'Horashim', 'Yafhiv',
#        'Yarkona', 'Kafr Bara', 'Kafr Misr', 'Kfar Kassem', 'Matan',
#        'Neveh Yamin', 'Neveh Yarak', 'Nir Eliyahu', 'Adanim', 'Tzofit',
#        'Sdei Hemed', 'Even Yehuda', 'Tira', 'Kfar Hess', 'Ramat HaKovesh',
#        'Yashresh', 'Lod', 'Matzliach', 'Nir Zvi', 'Ramla',
#        'Zrifin Industrial Zone', 'Kidron', 'Mazkeret Batya',
#        'Kiryat Ekron', 'Kannot Industrial Zone', 'Ganei Hadar',
#        'Ganei Yochanan', 'Kfar Bilu', "Na'an", 'Sitria', 'Ramot Meir',
#        'Arsuf', 'Udim', 'Beit Yehoshua', 'Kfar Netter', 'Kfar Yona',
#        'Nordia', 'Pardessiya', 'Beit Gamliel', 'Bnaya',
#        'Tel Aviv - City Center', 'Tel Itzhak', 'Misgav Dov', 'Shdema',
#        "Beit Yithak - Sha'ar Hefer", 'Ginot Hadar', 'Givat Brenner',
#        'Neveh Mivtach', 'Hatzav', 'Kannot', "Re'em Industrial Park",
#        'Meishar', 'Asseret', 'Ganot', 'Kfar Mordechai', 'Shefayim',
#        'Gelilot - Pi Compound', 'Achiezer', 'Yagel', 'Kfar Chabad',
#        'Magshimim', 'Mazor', 'Nofech', 'Nechalim', 'Rinatya',
#        'Merkaz Shapira', 'Ein Tzurim', 'Tzafria', 'Einat', 'Rishpon',
#        'Drom HaSharon Regional Council', 'Beit Arif', 'Bareket',
#        'Tirat Yehuda', 'Shoham', 'Kfar Truman', 'Zeitan', 'Gvulot',
#        'Talmei Eliyahu', 'Yad Natan', 'Zrahia', 'Kommemiut', 'Moladah',
#        'Al-Sayyid and the Bedouin diaspora', "Wadi al-Na'am", 'Tel Sheva',
#        'Umm Batin and the Bedouin Diaspora', 'Beer Sheva - South',
#        'Beer Sheva - East', 'Beer Sheva - West', 'Beer Sheva - North',
#        'Hatzerim', 'Lakiya and the Bedouin Diaspora', 'Omer', 'Ofakim',
#        'Maslul', 'Pduim', 'Renan', 'Eshel HaNassi', 'Bitha', 'Gilat',
#        'Tifrach', 'Merhavim Educational Campus',
#        'Segev Shalom and the Bedouin Diaspora',
#        'Abu Talul and the Bedouin Diaspora', 'Nevatim', 'Darijat',
#        'Tel Arad and El Pura', 'Kuseife and the Bedouin Diaspora',
#        'Shoket Junction Center', 'Kokhav Michael', 'Hura',
#        'Qasr al-Sir and the Bedouin Diaspora', 'Dimona Industrial Zone',
#        'Dimona', "Giv'ot Bar", 'Lehavim', 'Mishmar HaNegev',
#        'Tirabin al-Sana and the Bedouin Diaspora', 'Carmit', "Ze'elim",
#        'Arad', 'Ahuzam', 'Idan HaNegev Industrial Zone', 'Beit Kama',
#        'Rahat and the Bedouin Diaspora', 'Shoval', 'Gimzo', 'Hadid',
#        'Kfar Daniel', "Be'erotaim", 'Burgata', 'Olesh', 'Tnuvot',
#        "Mevo Modi'im", "Modi'in - Ligad Center", 'Kfar Rut', "Modi'in",
#        'Noga', 'Sdeh Yoav', 'Otzem', 'Yatzitz', 'Bror Hayil',
#        'Bnei Netzarim', 'Shlomit', 'Lahav', 'Patish', 'Eshkolot',
#        "Aroer (Ar'ara BaNegev)", 'Eshbol', "Pa'amei Tashaz", 'Klachim',
#        'Sdeh Zvi', 'Talmei Bilu', 'Negba', 'Avshalom', 'Reim', 'Brosh',
#        'Shibolim', "Ta'ashur", 'Tidhar', 'Naveh', 'Ahituv', 'Amatz',
#        'Gan Yoshia', 'bqa al-Gharbiyye', 'Jatt', 'Lehavot Haviva',
#        'Magal', 'Meiser', 'Metzer', 'umm al-Fahm', 'Umm al-Qutuf',
#        "Bart'a", 'Harish', "Mu'awiya", 'Mitzpeh Ilan', "Ar'ara",
#        'Givat Ela', 'Gvat', 'Zarzir', 'Nahalal', 'Ramat David',
#        'Shimshit', 'Timrat', 'Kfar Baruch', 'Midrach Oz',
#        'Mishmar HaEmek', 'Sdeh Itzhak', 'Katzir', 'Uzza', 'Eitan',
#        'Zohar', "Zru'a", "Mabu'im", 'Shavei Darom', 'Nataf', 'Mevo Horon',
#        'Heletz', 'Sdeh David', 'Tlamim', 'Even Shmuel', 'Nachshonim',
#        'Geffen', 'Tirosh', "Sha'ar Efraim", 'Nitzanei Oz', 'Rosh HaAyin',
#        'Megadlim', 'Eli', 'Kfar Tapuach', 'Rechelim', 'Gat', 'Sdeh Moshe',
#        'Hatzav Industrial Zone', 'Einav',
#        'Afek and Lev Ha"aretz Industrial Zone', 'Misgav Am', 'Ibillin',
#        'Shfaram', "Sha'ar Na'aman Industrial Zone", 'Kiryat Bialik',
#        'Kiryat Yam', 'Kiryat Motzkin', 'Kfar Masaryk', 'Ein HaMifratz',
#        'Acre - Industrial Zone', 'Acre', 'Rosh HaNikra',
#        'Netiv HaShayara', 'Sheikh Danun', 'Hanita', "Ya'ara", 'Cabri',
#        'Metzuba', 'Avdon', 'Idmit', 'Shlomi', 'Kfar Giladi', 'Tel Hai',
#        'Kiryat Shmona', 'Ein Quiniyye', 'Neveh Ativ', 'Snir',
#        'Carmiel Industrial Zone', 'Kiryat Atta', 'Kfar Kama', 'Karmiel',
#        "Yavne'el", 'Migdal', 'Laqiya', 'Tzemach Industrial Zone',
#        'Kinneret Academic College', "Ha'On", 'Masada', "Ma'agan",
#        "Sha'ar HaGolan", 'Tel Katzir', 'Hamat gader',
#        'Bnei Yehuda and Givat Yoav', 'Gshur', 'Kfar Haruv', 'Mevo Hama',
#        'Neot Golan', 'Kfar Vradim', 'Evron', 'Gonen', "Ga'aton",
#        'Yechiam', 'Kfar Szold', 'Lehavot HaBashan', 'Amir', 'Shamir',
#        'Ashkelon - North', 'Jerusalem - North', 'Hadera - West',
#        'Ashkelon - South', 'Jerusalem - Atarot Industrial Zone',
#        'Jerusalem - South', "Jerusalem - Qafr 'Aqab",
#        'Hadera - Neveh Haim', 'Jerusalem - Center', 'Hadera - Center',
#        'Jerusalem - West', 'Herzeliya - West'], dtype=object)

# %% [markdown]
# Localities contain 'locality' == " in their names. Delete them from the entire dataset

# %%
# Counting the number of such rows in the dataset
detailed_df[detailed_df['locality'] == ''].shape[0]
# Out:
# 0

# %%
# Cleaning data from rows with 'locality' == "
detailed_df = detailed_df[detailed_df['locality'] != '']

# %% [markdown]
# A post dated May 20, 2021, was found in the message files, containing information that
# - Fixed a bug that caused duplicate alerts.
#
# This means that previously, alarm alerts were duplicated, which led to incorrect distribution in the datas
#
#
# ⚠⚠⚠ Before May 20, 2021, the dataset contained duplicate alert blocks—identical lists of localities and timestamps were repeated within individual alerts. A May 20, 2021 update to Cumta’s Android app fixed this bug, but the duplicates skewed the yearly distribution of alerts.⚠⚠⚠

# %%
# Filter rows before May 20, 2021
df_before_may20 = detailed_df[detailed_df['datetime'] < pd.Timestamp('2021-05-20')].copy()

# Create a unique key for each alert (based on 'datetime', 'region', and 'locality' columns)
df_before_may20['unique_key'] = (
    df_before_may20['datetime'].astype(str).str.strip() + '_' +
    df_before_may20['region'].astype(str).str.strip() + '_' +
    df_before_may20['locality'].astype(str).str.strip()
)

# Remove duplicates based on the unique key
df_before_may20_clean = df_before_may20.drop_duplicates(subset='unique_key').copy()

# Drop the unique key column if it is no longer needed
df_before_may20_clean.drop(columns=['unique_key'], inplace=True)

# If needed, merge the cleaned data with the remaining dataset (rows from May 20, 2021, and later)
detailed_df = pd.concat([
    df_before_may20_clean,
    detailed_df[detailed_df['datetime'] >= pd.Timestamp('2021-05-20')]
])

# %% [markdown]
# The number of rows has decreased significantly

# %%
detailed_df[detailed_df['year'] == 2021].head(60)
# Out:
#                 datetime                      region  \
# 4809 2021-03-11 21:08:41        Western Lakhish Area
# 4810 2021-03-11 21:08:41  Gaza Containment Zone Area
# 4811 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4812 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4813 2021-04-15 21:01:29  Gaza Containment Zone Area
# 4814 2021-04-16 21:43:33  Gaza Containment Zone Area
# 4815 2021-04-16 21:43:33  Gaza Containment Zone Area
# 4816 2021-04-22 01:41:33         Southern Negev Area
# 4817 2021-04-23 22:59:05  Gaza Containment Zone Area
# 4818 2021-04-24 01:50:05  Gaza Containment Zone Area
# 4819 2021-04-24 01:50:11  Gaza Containment Zone Area
# 4820 2021-04-24 01:50:11  Gaza Containment Zone Area
# 4821 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4822 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4823 2021-04-24 02:11:46  Gaza Containment Zone Area
# 4824 2021-04-24 02:12:11  Gaza Containment Zone Area
# 4825 2021-04-24 02:12:33  Gaza Containment Zone Area
# 4826 2021-04-24 02:30:34  Gaza Containment Zone Area
# 4827 2021-04-24 03:10:40  Gaza Containment Zone Area
# 4828 2021-04-24 03:10:40  Gaza Containment Zone Area
# 4829 2021-04-24 03:51:10  Gaza Containment Zone Area
# 4830 2021-04-24 04:58:28  Gaza Containment Zone Area
# 4831 2021-04-24 05:27:52  Gaza Containment Zone Area
# 4832 2021-04-24 05:27:55  Gaza Containment Zone Area
# 4833 2021-04-24 05:33:35  Gaza Containment Zone Area
# 4834 2021-04-24 05:35:19  Gaza Containment Zone Area
# 4835 2021-04-24 05:35:23  Gaza Containment Zone Area
# 4836 2021-04-24 05:35:47  Gaza Containment Zone Area
# 4837 2021-04-24 05:40:04  Gaza Containment Zone Area
# 4838 2021-04-24 05:41:04  Gaza Containment Zone Area
# 4839 2021-04-24 05:48:46        Western Lakhish Area
# 4840 2021-04-24 05:48:51  Gaza Containment Zone Area
# 4841 2021-04-24 05:48:51  Gaza Containment Zone Area
# 4842 2021-04-24 05:48:56  Gaza Containment Zone Area
# 4843 2021-04-24 05:48:56  Gaza Containment Zone Area
# 4844 2021-04-24 05:59:42        Western Lakhish Area
# 4845 2021-04-24 05:59:58  Gaza Containment Zone Area
# 4846 2021-04-24 05:59:58  Gaza Containment Zone Area
# 4847 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4848 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4849 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4850 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4851 2021-04-24 20:58:43  Gaza Containment Zone Area
# 4852 2021-04-24 20:58:47  Gaza Containment Zone Area
# 4853 2021-04-24 20:58:47  Gaza Containment Zone Area
# 4854 2021-04-24 22:28:46  Gaza Containment Zone Area
# 4855 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4856 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4857 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4858 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4859 2021-04-26 03:16:55  Gaza Containment Zone Area
# 4860 2021-04-28 00:18:55  Gaza Containment Zone Area
# 4861 2021-05-09 21:11:10             Western Lakhish
# 4862 2021-05-09 21:11:10       Gaza Containment Zone
# 4863 2021-05-09 21:11:10       Gaza Containment Zone
# 4864 2021-05-09 21:11:10       Gaza Containment Zone
# 4865 2021-05-09 21:11:10       Gaza Containment Zone
# 4866 2021-05-09 21:11:13             Western Lakhish
# 4867 2021-05-09 21:11:37             Western Lakhish
# 4868 2021-05-10 06:22:19       Gaza Containment Zone
#
#                                locality threat_type  year
# 4809  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4810                              Zikim   Red Alert  2021
# 4811                             Nir Am   Red Alert  2021
# 4812                             Sderot   Red Alert  2021
# 4813                               Ibim   Red Alert  2021
# 4814                              Holit   Red Alert  2021
# 4815                       Sdeh Avraham   Red Alert  2021
# 4816                         Abu Qrenat   Red Alert  2021
# 4817                           Kissufim   Red Alert  2021
# 4818             Kfar Maimon and Tushia   Red Alert  2021
# 4819                             Be'eri   Red Alert  2021
# 4820                             Alumim   Red Alert  2021
# 4821                          Mivtachim   Red Alert  2021
# 4822                              Amioz   Red Alert  2021
# 4823                              Yesha   Red Alert  2021
# 4824                         Nir Itzhak   Red Alert  2021
# 4825                    Tzohar and Ohad   Red Alert  2021
# 4826                     Netiv HaAssara   Red Alert  2021
# 4827                           Mefalsim   Red Alert  2021
# 4828                          Kfar Azza   Red Alert  2021
# 4829                          Nachal Oz   Red Alert  2021
# 4830                       Kerem Shalom   Red Alert  2021
# 4831                             Alumim   Red Alert  2021
# 4832                          Nachal Oz   Red Alert  2021
# 4833                     Netiv HaAssara   Red Alert  2021
# 4834                     Netiv HaAssara   Red Alert  2021
# 4835                           Kissufim   Red Alert  2021
# 4836                           Kissufim   Red Alert  2021
# 4837                           Kissufim   Red Alert  2021
# 4838                           Kissufim   Red Alert  2021
# 4839  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4840                              Zikim   Red Alert  2021
# 4841                             Karmia   Red Alert  2021
# 4842                      Yad Mordechai   Red Alert  2021
# 4843                     Netiv HaAssara   Red Alert  2021
# 4844  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4845                              Zikim   Red Alert  2021
# 4846                     Netiv HaAssara   Red Alert  2021
# 4847                              Gavim   Red Alert  2021
# 4848                      Sapir College   Red Alert  2021
# 4849                             Nir Am   Red Alert  2021
# 4850                             Sderot   Red Alert  2021
# 4851                               Ibim   Red Alert  2021
# 4852                           Mefalsim   Red Alert  2021
# 4853              Nir Am Shooting Range   Red Alert  2021
# 4854                              Nirim   Red Alert  2021
# 4855                             Nir Am   Red Alert  2021
# 4856                             Sderot   Red Alert  2021
# 4857                               Ibim   Red Alert  2021
# 4858                               Erez   Red Alert  2021
# 4859              Nir Am Shooting Range   Red Alert  2021
# 4860                           Kissufim   Red Alert  2021
# 4861  Ashkelon Southern Industrial Zone   Red Alert  2021
# 4862                              Zikim   Red Alert  2021
# 4863                      Yad Mordechai   Red Alert  2021
# 4864                             Karmia   Red Alert  2021
# 4865                     Netiv HaAssara   Red Alert  2021
# 4866                           Ashkelon   Red Alert  2021
# 4867                           Mavki'im   Red Alert  2021
# 4868                          Kfar Azza   Red Alert  2021

# %% [markdown]
# There are no more duplicates

# %%
# Convert the 'datetime' column to datetime format
detailed_df['datetime'] = pd.to_datetime(detailed_df['datetime'], 
                                         errors='coerce', format='%d/%m/%Y %H:%M:%S')

# Extract the year from the 'datetime' column
detailed_df['year'] = detailed_df['datetime'].dt.year

# Count the number of alerts per year
warnings_by_year_clean = detailed_df['year'].value_counts().sort_index()

# Calculate the percentage distribution per year
percentages_clean = (warnings_by_year_clean / warnings_by_year_clean.sum()) * 100

# Combine the counts and percentage distribution into a DataFrame
result_df_clean = pd.DataFrame({
    'Count': warnings_by_year_clean,
    'Percentage': percentages_clean.round(2).astype(str) + '%'
})

# Display the result
print('Distribution of data by year in detailed_df_clean:')
result_df_clean
# Out:
# Distribution of data by year in detailed_df_clean:
#       Count Percentage
# year
# 2018     58      0.05%
# 2019   4277      4.02%
# 2020    312      0.29%
# 2021   8145      7.66%
# 2022    989      0.93%
# 2023  13838     13.01%
# 2024  32674     30.73%
# 2025  46040      43.3%

# %% [markdown]
# 🎉🎉🎉The distribution by year has become similar to the original one🎉🎉🎉

# %% [markdown]
# ### Processing of the 'region' column

# %%
# Check again
detailed_df['region'].unique()
# Out:
# array(['Dan 158', 'Dan 156', 'Dan 157', 'Dan 159', 'Dan 162', 'Dan 155',
#        'Dan 160', 'Sharon 140', 'Dan 161', 'Dan 165', 'Sharon 143',
#        'Sharon 141', 'Eilat 311', 'Arabah 310', 'Lakhish 246',
#        'Gaza Containment Zone 225', 'Gaza Containment Zone 224',
#        'Jerusalem 194', 'Maale Adumim 200', 'Samaria 127',
#        'Gaza Containment Zone 236',
#        'Central Negev / Gaza Containment Zone 238',
#        'Gaza Containment Zone 237', 'Gaza Containment Zone 230',
#        'Gaza Containment Zone 220', 'Gaza Containment Zone 219',
#        'Gaza Containment Zone 221', 'Hefer 139',
#        'Gaza Containment Zone 218', 'Central Negev 254',
#        'Central Negev 255', 'Central Negev / Gaza Containment Zone 216',
#        'Gaza Containment Zone 223', 'Gaza Containment Zone 233',
#        'Gaza Containment Zone 232', 'Gaza Containment Zone 231',
#        'Gaza Containment Zone 228', 'Gaza Containment Zone 222',
#        'Gaza Containment Zone 217', 'Lakhish 247', 'Gaza containment 224',
#        'Gaza containment 220', 'Gaza containment 219',
#        'Gaza containment 221', 'Central Negev 252',
#        'Gaza containment 225', 'Central Negev', 'Gaza containment 223',
#        'Gaza containment 222', 'Gaza containment 230',
#        'Gaza containment 218', 'Gaza containment 217', 'Lakhish 250',
#        'Lakhish 249', 'Lakhish 248', 'Central Negev 253',
#        'Gaza containment 227', 'Gaza containment 231', 'Lakhish 245',
#        'Southern Shfela 268', 'Shfela', 'Southern Shfela 187',
#        'Lakhish 276', 'Lakhish 275', 'Lakhish 273', 'Lakhish 272',
#        'Lakhish 271', 'Gaza containment 236', 'Gaza containment 233',
#        'Gaza containment 232', 'Gaza containment 237', 'Lakhish 281',
#        'Beit Shemesh', 'Lakhish 282', 'Lakhish 278', 'Central Negev 288',
#        'Central Negev 256', 'Central Negev 289', 'Central Negev 291',
#        'Central Negev 287', 'Central Negev 292', 'Southern Negev 297',
#        'Southern Negev 296', 'Central Negev 286', 'Lakhish 280',
#        'Southern Shfela 266', 'Southern Shfela 267', 'Central Negev 300',
#        'Southern Negev 299', 'Nirim', 'Lakhish', 'Confrontation line',
#        'Gaza Containment Zone', "Ye'arut HaCarmel (Carmel Forest)",
#        'Haifa', 'Hof HaCarmel', 'Menashe', 'Wadi Ara', 'Karkur',
#        'Pardes Hanna - Karkur', 'Nir Am', 'Lakhish Area',
#        'Gaza Containment Zone Area', 'Southern Shfela Area',
#        'Central Negev Area', 'Holon', 'Shfela (Lowlands) Area',
#        "Mivtachim Ami'oz Yesha", 'Tel Aviv - South and Jaffa',
#        'Tel Aviv - City Center', 'Bat Yam', 'Western Lakhish Area',
#        'Western Negev Area', 'Yarkon Area', 'Samaria Area',
#        'Beit Shemesh Area', 'Confrontation line Area', 'Golan Area',
#        'Southern Negev Area', 'Western Lakhish', 'Jerusalem',
#        'Western Negev', 'Southern Shfela', 'Dan', 'Shfela (Lowlands)',
#        'Hefer', 'Sharon', 'Yarkon', 'Samaria',
#        'Drom HaSharon Regional Council', 'Southern Negev',
#        'Kokhav Michael', 'Judea', 'Tavor', 'Lower Galilee', 'Hakrayot',
#        'Upper Galilee', 'Kiryat Shmona', 'Golan', 'Ibim', 'Gaza Envelope',
#        'West Lachish', 'HaMifratz', 'Center Galilee', 'Center Negev',
#        'South Golan', 'Confrontation Line', 'HaShfela', 'Shomron',
#        'Yehuda', 'Lachish', 'West Negev', 'Ashdod', 'Shfelat Yehuda',
#        "Bika'a", 'South Negev', 'HaCarmel', "Beit She'an Valley",
#        'North Golan', 'HaAmakim', 'Kfar Yehoshua Train Station', 'Eilat',
#        'Arava', 'Dead Sea', 'Lev Ha-Hula', 'Safed',
#        'Fast Lane Parking Lot', 'Modiin Maccabim Reut',
#        'Regem Industrial Zone', 'Mini Israel', 'Neot Kedumim',
#        'Yehud Monoson', 'Shoham', 'Nili', 'Airport City', 'Orevim Cliff',
#        'Ramat Trump', 'Jordan River Rafting', 'Kfar Naḥum', 'Tabgha',
#        'Goren Guest Farm', 'Miluot North Industrial Zone',
#        'Jordan Estate Hotel', 'Milouot Industrial\xa0Zone\xa0North',
#        'ברחבי הארץ'], dtype=object)

# %%
# Remove ' Area' from the 'region' column if it exists
detailed_df['region'] = detailed_df['region'].str.replace(' Area', '', regex=False).str.strip()
detailed_df['region'].unique()
# Out:
# array(['Dan 158', 'Dan 156', 'Dan 157', 'Dan 159', 'Dan 162', 'Dan 155',
#        'Dan 160', 'Sharon 140', 'Dan 161', 'Dan 165', 'Sharon 143',
#        'Sharon 141', 'Eilat 311', 'Arabah 310', 'Lakhish 246',
#        'Gaza Containment Zone 225', 'Gaza Containment Zone 224',
#        'Jerusalem 194', 'Maale Adumim 200', 'Samaria 127',
#        'Gaza Containment Zone 236',
#        'Central Negev / Gaza Containment Zone 238',
#        'Gaza Containment Zone 237', 'Gaza Containment Zone 230',
#        'Gaza Containment Zone 220', 'Gaza Containment Zone 219',
#        'Gaza Containment Zone 221', 'Hefer 139',
#        'Gaza Containment Zone 218', 'Central Negev 254',
#        'Central Negev 255', 'Central Negev / Gaza Containment Zone 216',
#        'Gaza Containment Zone 223', 'Gaza Containment Zone 233',
#        'Gaza Containment Zone 232', 'Gaza Containment Zone 231',
#        'Gaza Containment Zone 228', 'Gaza Containment Zone 222',
#        'Gaza Containment Zone 217', 'Lakhish 247', 'Gaza containment 224',
#        'Gaza containment 220', 'Gaza containment 219',
#        'Gaza containment 221', 'Central Negev 252',
#        'Gaza containment 225', 'Central Negev', 'Gaza containment 223',
#        'Gaza containment 222', 'Gaza containment 230',
#        'Gaza containment 218', 'Gaza containment 217', 'Lakhish 250',
#        'Lakhish 249', 'Lakhish 248', 'Central Negev 253',
#        'Gaza containment 227', 'Gaza containment 231', 'Lakhish 245',
#        'Southern Shfela 268', 'Shfela', 'Southern Shfela 187',
#        'Lakhish 276', 'Lakhish 275', 'Lakhish 273', 'Lakhish 272',
#        'Lakhish 271', 'Gaza containment 236', 'Gaza containment 233',
#        'Gaza containment 232', 'Gaza containment 237', 'Lakhish 281',
#        'Beit Shemesh', 'Lakhish 282', 'Lakhish 278', 'Central Negev 288',
#        'Central Negev 256', 'Central Negev 289', 'Central Negev 291',
#        'Central Negev 287', 'Central Negev 292', 'Southern Negev 297',
#        'Southern Negev 296', 'Central Negev 286', 'Lakhish 280',
#        'Southern Shfela 266', 'Southern Shfela 267', 'Central Negev 300',
#        'Southern Negev 299', 'Nirim', 'Lakhish', 'Confrontation line',
#        'Gaza Containment Zone', "Ye'arut HaCarmel (Carmel Forest)",
#        'Haifa', 'Hof HaCarmel', 'Menashe', 'Wadi Ara', 'Karkur',
#        'Pardes Hanna - Karkur', 'Nir Am', 'Southern Shfela', 'Holon',
#        'Shfela (Lowlands)', "Mivtachim Ami'oz Yesha",
#        'Tel Aviv - South and Jaffa', 'Tel Aviv - City Center', 'Bat Yam',
#        'Western Lakhish', 'Western Negev', 'Yarkon', 'Samaria', 'Golan',
#        'Southern Negev', 'Jerusalem', 'Dan', 'Hefer', 'Sharon',
#        'Drom HaSharon Regional Council', 'Kokhav Michael', 'Judea',
#        'Tavor', 'Lower Galilee', 'Hakrayot', 'Upper Galilee',
#        'Kiryat Shmona', 'Ibim', 'Gaza Envelope', 'West Lachish',
#        'HaMifratz', 'Center Galilee', 'Center Negev', 'South Golan',
#        'Confrontation Line', 'HaShfela', 'Shomron', 'Yehuda', 'Lachish',
#        'West Negev', 'Ashdod', 'Shfelat Yehuda', "Bika'a", 'South Negev',
#        'HaCarmel', "Beit She'an Valley", 'North Golan', 'HaAmakim',
#        'Kfar Yehoshua Train Station', 'Eilat', 'Arava', 'Dead Sea',
#        'Lev Ha-Hula', 'Safed', 'Fast Lane Parking Lot',
#        'Modiin Maccabim Reut', 'Regem Industrial Zone', 'Mini Israel',
#        'Neot Kedumim', 'Yehud Monoson', 'Shoham', 'Nili', 'Airport City',
#        'Orevim Cliff', 'Ramat Trump', 'Jordan River Rafting',
#        'Kfar Naḥum', 'Tabgha', 'Goren Guest Farm',
#        'Miluot North Industrial Zone', 'Jordan Estate Hotel',
#        'Milouot Industrial\xa0Zone\xa0North', 'ברחבי הארץ'], dtype=object)

# %%
# Replace the incorrect region name with the corrected version
detailed_df['region'] = detailed_df['region'].replace('Milouot Industrial\xa0Zone\xa0North', 
                                                      'Milouot Industrial Zone North')

# %% [markdown]
# ### Adding the 'district' column

# %%
# List of major cities with their corresponding districts
city_to_district = {
    "Tel Aviv": "Tel Aviv District",
    "Dan Area": "Tel Aviv District",
    "Ramat Gan": "Tel Aviv District",
    "Herzeliya": "Tel Aviv District",
    "Holon": "Tel Aviv District",
    "Bat Yam": "Tel Aviv District",
    "Bnei Brak": "Tel Aviv District",
    "Givatayim": "Tel Aviv District",
    "Kiryat Ono": "Tel Aviv District",
    "Or Yehuda": "Tel Aviv District",
    "Ramat HaSharon": "Tel Aviv District",
    "Rishon LeZion": "Central District",
    "Netanya": "Central District",
    "Rehovot": "Central District",
    "Petah Tikva": "Central District",
    "Lod": "Central District",
    "Ramla": "Central District",
    "Kfar Saba": "Central District",
    "Yavne": "Central District",
    "Modi'in-Maccabim-Re'ut": "Central District",
    "Modi'in": "Central District",
    "Be'er Ya'akov": "Central District",
    "El'ad": "Central District",
    "Ganei Tikva": "Central District",
    "Giv'at Shmuel": "Central District",
    "Hod Hasharon": "Central District",
    "Kafr Qasim": "Central District",
    "Kfar Yona": "Central District",
    "Ness Ziona": "Central District",
    "Qalansawe": "Central District",
    "Ra'anana": "Central District",
    "Rosh HaAyin": "Central District",
    "Tayibe": "Central District",
    "Tira": "Central District",
    "Yehud-Monosson": "Central District",
    "Haifa": "Haifa District",
    "Hadera": "Haifa District",
    "Caesarea": "Haifa District",
    "Nesher": "Haifa District",
    "Or Akiva": "Haifa District",
    "Tirat Carmel": "Haifa District",
    "Kiryat Ata": "Haifa District",
    "Kiryat Bialik": "Haifa District",
    "Kiryat Yam": "Haifa District",
    "Kiryat Motzkin": "Haifa District",
    "Pardes Hanna-Karkur": "Haifa District",
    "Jerusalem": "Jerusalem District",
    "Beit Shemesh": "Jerusalem District",
    "Ma'ale Adumim": "Jerusalem District",
    "Nazareth": "Northern District",
    "Acre": "Northern District",
    "Gan Yavne": "Central District",
    "Dead Sea Factories": "Southern District",
    "Dead Sea Industries": "Southern District",
    "Lakhish": "Southern District",
    "Atlit": "Haifa District",
    "Kiryat Malachi": "Southern District",
    "Gdera": "Central District",
    "Bnei Darom": "Southern District",
    "Sdeh Yoav": "Southern District",
    "Palmachim": "Central District",
    "Tiberias": "Northern District",
    "Nahariya": "Northern District",
    "Safed": "Northern District",
    "Kiryat Shmona": "Northern District",
    "Afula": "Northern District",
    "Karmiel": "Northern District",
    "Ma'alot-Tarshiha": "Northern District",
    "Migdal HaEmek": "Northern District",
    "Yokneam Illit": "Northern District",
    "Ashdod": "Southern District",
    "Ashkelon": "Southern District",
    "Beer Sheva": "Southern District",
    "Eilat": "Southern District",
    "Sderot": "Southern District",
    "Ofakim": "Southern District",
    "Dimona": "Southern District",
    "Arad": "Southern District",
    "Kiryat Gat": "Southern District",
    "Kiryat Malakhi": "Southern District"
}

# Simplified mapping based on keywords in the 'region' column
district_mapping_patterns = {
    'Dan': 'Tel Aviv District',
    'Sharon': 'Central District',
    'Hefer': 'Central District',
    'Yarkon': 'Central District',
    'Drom HaSharon': 'Central District',
    'Haifa': 'Haifa District',
    'Pardes Hanna': 'Haifa District',
    'Karkur': 'Haifa District',
    'Hof HaCarmel': 'Haifa District',
    'Menashe': 'Haifa District',
    'Hakrayot': 'Haifa District',
    'Wadi Ara': 'Haifa District',
    'Jerusalem': 'Jerusalem District',
    'Maale Adumim': 'Jerusalem District',
    'Beit Shemesh': 'Jerusalem District',
    'Samaria': 'Judea and Samaria Area',
    'Shomron': 'Judea and Samaria Area',
    'Judea': 'Judea and Samaria Area',
    'Yehuda': 'Judea and Samaria Area',
    'Shfelat Yehuda': 'Judea and Samaria Area',
    'Lakhish': 'Southern District',
    'Gaza': 'Southern District',
    'Confrontation': 'Southern District',
    'Nirim': 'Southern District',
    'Nir Am': 'Southern District',
    'Eilat': 'Southern District',
    'Arava': 'Southern District',
    'Dead Sea': 'Southern District',
    'Negev': 'Southern District',
    'Western Negev': 'Southern District',
    'Safed': 'Northern District',
    'Galilee': 'Northern District',
    'Golan': 'Northern District',
    'Tavor': 'Northern District',
    'HaAmakim': 'Northern District',
    "Beit She'an": 'Northern District',
    'Lev Ha-Hula': 'Northern District',
    'Shfela': 'Central District',
    'Southern Shfela': 'Central District',
    'HaMifratz': 'Haifa District',
    'Ibim': 'Southern District',
    'Gaza Envelope': 'Southern District',
    'West Lachish': 'Southern District',
    'Center Galilee': 'Northern District',
    'Center Negev': 'Southern District',
    'South Golan': 'Northern District',
    'Lower Galilee': 'Northern District',
    'Upper Galilee': 'Northern District',
    'North Golan': 'Northern District', 
    "Beit She'an Valley": 'Northern District',
    'Fast Lane Parking Lot': 'Central District',
    'Mini Israel': 'Central District',
    'Modiin Maccabim Reut': 'Central District',
    'Neot Kedumim': 'Central District',
    'Regem Industrial Zone': 'Southern District',
    'Yehud Monoson': 'Central District',
    'Orevim Cliff': 'Northern District',
    'Ramat Trump': 'Northern District',
    'Jordan River Rafting': 'Northern District',
    'Kfar Naḥum': 'Northern District',
    'Tabgha': 'Northern District',
    "Arabah 310": "Southern District",
    "Ye'arut HaCarmel (Carmel Forest)": "Haifa District",
    "Mivtachim Ami'oz Yesha": "Central District",
    "Kokhav Michael": "Central District",
    "Lachish": "Southern District",
    "Bika'a": "Central District",
    "HaCarmel": "Haifa District",
    "Kfar Yehoshua Train Station": "Central District",
    "Shoham": "Central District",
    "Nili": "Central District",
    "Airport City": "Central District",
    'Goren Guest Farm': 'Northern District',
    'Miluot North Industrial Zone': 'Northern District',
    'Jordan Estate Hotel': 'Northern District',
    'Milouot Industrial Zone North': 'Northern District'
}

# %%
# Function to match keywords in the 'region' column and assign districts
def map_to_district(region):
    for keyword, district in district_mapping_patterns.items():
        if keyword.lower() in region.lower():
            return district
    return 'Undefined'  # Default if no match is found

# Apply logic to create the 'district' column
detailed_df['district'] = detailed_df.apply(
    lambda row: "Southern District" if "ashdod" in row['locality'].lower()  # Ensure all 'Ashdod' locations are categorized correctly
                else city_to_district[row['locality']] if row['locality'] in city_to_district  # Match exact locality if found in city_to_district
                else map_to_district(row['region']),  # Otherwise, try mapping based on region keywords
    axis=1
)

# Drop the 'year' column as it's not needed
detailed_df = detailed_df.drop(columns=['year'])

# Reset the index for better data structure
detailed_df = detailed_df.reset_index(drop=True)

# Display the updated DataFrame
detailed_df
# Out:
#                   datetime   region                 locality  \
# 0      2018-12-26 10:05:01  Dan 158    Tel Aviv (South West)
# 1      2018-12-26 10:05:01  Dan 156         Tel Aviv (North)
# 2      2018-12-26 10:05:01  Dan 157       Tel Aviv (Central)
# 3      2018-12-26 10:05:01  Dan 159    Tel Aviv (South East)
# 4      2018-12-26 10:05:01  Dan 162                     Azur
# ...                    ...      ...                      ...
# 106328 2025-10-05 04:59:22   Yarkon  Modi'in - Ishpro Center
# 106329 2025-10-05 18:34:40    Eilat                    Eilat
# 106330 2025-10-05 18:32:20    Eilat                    Eilat
# 106331 2025-10-05 18:33:24    Eilat                    Eilat
# 106332 2025-10-05 18:35:50    Eilat                    Eilat
#
#                   threat_type           district
# 0                   Red Alert  Tel Aviv District
# 1                   Red Alert  Tel Aviv District
# 2                   Red Alert  Tel Aviv District
# 3                   Red Alert  Tel Aviv District
# 4                   Red Alert  Tel Aviv District
# ...                       ...                ...
# 106328              Red Alert   Central District
# 106329              Red Alert  Southern District
# 106330  Unrecognized Aircraft  Southern District
# 106331  Unrecognized Aircraft  Southern District
# 106332  Unrecognized Aircraft  Southern District
#
# [106333 rows x 5 columns]

# %%
# Check 'Undefined' district
detailed_df[detailed_df['district'] == 'Undefined']['locality'].unique()
# Out:
# array(['ברחבי הארץ'], dtype=object)

# %%
detailed_df[detailed_df['district'] == 'Undefined']['region'].unique()
# Out:
# array(['ברחבי הארץ'], dtype=object)

# %%
detailed_df[detailed_df['region'] == 'ברחבי הארץ']
# Out:
#                  datetime      region    locality threat_type   district
# 74878 2025-06-14 01:12:14  ברחבי הארץ  ברחבי הארץ   Red Alert  Undefined
# 75203 2025-06-14 01:12:14  ברחבי הארץ  ברחבי הארץ   Red Alert  Undefined
# 91456 2025-06-20 15:44:15  ברחבי הארץ  ברחבי הארץ   Red Alert  Undefined

# %%
# Find duplicate nationwide rows based on datetime
nationwide_duplicates = detailed_df[detailed_df['region'] == 'ברחבי הארץ'].duplicated(subset=['datetime'])

# Remove only the duplicate nationwide rows
detailed_df = detailed_df[~(detailed_df['region'] == 'ברחבי הארץ') | ~nationwide_duplicates]

# Check
detailed_df[detailed_df['region'] == 'ברחבי הארץ']
# Out:
#                  datetime      region    locality threat_type   district
# 74878 2025-06-14 01:12:14  ברחבי הארץ  ברחבי הארץ   Red Alert  Undefined
# 91456 2025-06-20 15:44:15  ברחבי הארץ  ברחבי הארץ   Red Alert  Undefined

# %%
# Get all unique locality-region-district pairs from the dataset
locality_region_district_pairs = detailed_df[
    (detailed_df['locality'] != 'ברחבי הארץ') & 
    (detailed_df['region'] != 'ברחבי הארץ')
][['locality', 'region', 'district']].drop_duplicates()

# Find nationwide alerts (across the whole country)
nationwide = detailed_df[
    (detailed_df['locality'] == 'ברחבי הארץ') & 
    (detailed_df['region'] == 'ברחבי הארץ')
]

# Create expanded copies for each locality with correct region and district
expanded = []
for _, alert in nationwide.iterrows():
    for _, location in locality_region_district_pairs.iterrows():
        new_alert = alert.copy()
        new_alert['locality'] = location['locality']
        new_alert['region'] = location['region']
        new_alert['district'] = location['district']
        expanded.append(new_alert)

# Combine back together
detailed_df = pd.concat([
    detailed_df[~((detailed_df['locality'] == 'ברחבי הארץ') & (detailed_df['region'] == 'ברחבי הארץ'))],
    pd.DataFrame(expanded)
], ignore_index=True)

# %%
detailed_df[detailed_df['datetime'] == '2025-06-14 01:12:14']
# Out:
#                   datetime       region                   locality  \
# 106330 2025-06-14 01:12:14      Dan 158      Tel Aviv (South West)
# 106331 2025-06-14 01:12:14      Dan 156           Tel Aviv (North)
# 106332 2025-06-14 01:12:14      Dan 157         Tel Aviv (Central)
# 106333 2025-06-14 01:12:14      Dan 159      Tel Aviv (South East)
# 106334 2025-06-14 01:12:14      Dan 162                       Azur
# ...                    ...          ...                        ...
# 108868 2025-06-14 01:12:14        Arava     Elipaz and Timna Mines
# 108869 2025-06-14 01:12:14        Arava                      Samar
# 108870 2025-06-14 01:12:14        Arava  Six Senses Shaharut Hotel
# 108871 2025-06-14 01:12:14        Arava              Ardanel Ranch
# 108872 2025-06-14 01:12:14  South Negev                       Azuz
#
#        threat_type           district
# 106330   Red Alert  Tel Aviv District
# 106331   Red Alert  Tel Aviv District
# 106332   Red Alert  Tel Aviv District
# 106333   Red Alert  Tel Aviv District
# 106334   Red Alert  Tel Aviv District
# ...            ...                ...
# 108868   Red Alert  Southern District
# 108869   Red Alert  Southern District
# 108870   Red Alert  Southern District
# 108871   Red Alert  Southern District
# 108872   Red Alert  Southern District
#
# [2543 rows x 5 columns]

# %%
detailed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111416 entries, 0 to 111415
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   datetime     111416 non-null  datetime64[ns]
#  1   region       111416 non-null  object
#  2   locality     111416 non-null  object
#  3   threat_type  111416 non-null  object
#  4   district     111416 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 4.3+ MB

# %% [markdown]
# ### Saving the dataframe

# %%
# Save the cleaned dataset to a CSV file
detailed_df.to_csv('cumta_detailed_df.csv', index=False, encoding='utf-8')

# %% [markdown]
# **Summary of Detailed Dataset Processing and Cleaning**
#
# 1️⃣ **Dataset Creation**
# - Constructed a dataset with **detailed locality information** based on `raw_df`.
#
# 2️⃣ **Yearly Data Distribution Analysis**
# - Identified a significant discrepancy in the **distribution of alerts by year** between `detailed_df` and `raw_df`:
#   - **In `detailed_df`**: 2021 accounts for **35.09%** of all records.
#   - **In `raw_df`**: 2021 makes up only **14.06%** of all records.
# - Given that the original dataset consists of **15 files**, and **2021 alert data spans less than 2 files (~13-14%)**, the distribution in `detailed_df` appeared skewed.
#
# 3️⃣ **Localization Processing**
# - Checked **localities and regions in Hebrew** and translated them into **English**.
#
# 4️⃣ **City Name Standardization**
# - Identified **large cities** that were divided into **zones**.
# - Verified how many such **zones exist** and ensured proper classification.
# - Paid special attention to **Ashdod**, where zone names had **non-standard formats**.
#
# 5️⃣ **Handling Data Skew and Duplication in 2021**
# - Found that **several consecutive lines** contained **the same locality names** (e.g., *Netiv HaAssara, Kissufim*).
# - Discovered a **message dated May 20, 2021**, stating:
#
#   > “Fixed a bug that caused duplicate alerts.”
#
# - This confirmed that **prior to May 20, 2021**, **duplicate alert blocks** existed, where **identical localities and timestamps** were repeated **within the same alert**.
# - This duplication issue **skewed the yearly distribution**.
#
# 6️⃣ **Deduplication & Final Data Cleaning**
# - **Removed duplicate alert records** from **before May 20, 2021**.
# - Successfully restored the **yearly distribution** to reflect **the original dataset structure**.
#
# ---
#
# ✅ **Final Result:** The dataset is now **cleaned, properly localized, and free from duplicate alerts** that previously distorted historical distributions.

# %% [markdown]
# - **Total rows:** 111416
# - **Duplicates:** None
# - **Time column (`'time'`):** Converted to `datetime64[ns]` format
# - **Missing value** None
#
# **Columns:**
#
# | Column Name | Description |
# |-------------|------------|
# | **datetime** | Date and time of the warning in `datetime64[ns]` format |
# | **locality** | Name of the locality (city, town, or settlement) |
# | **region** | Region to which the locality belongs |
# | **threat_type** | Type of warning. Possible values: `'Red Alert'`, `'Unrecognized Aircraft'`, `'Terrorist Infiltration'`, `'Interception Pieces'`, `'Earthquake'` |
# | **district** | Administrative district or region where the locality is located; an official governmental division. |

# %% [markdown]
# ## Creating a dataset where zones of large cities are combined into a single record

# %%
# List of major cities
major_cities_list = [
    "Modi'in", "Hadera", "Caesarea", "Ramat Gan", "Haifa", "Beer Sheva", "Netanya",
    "Rishon LeZion", "Tel Aviv", "Ashdod", "Herzeliya", "Jerusalem", "Nahariya", 
    "Safed", "Dimona", "Kiryat Gat", "Yokneam Illit", "Acre", "Ashkelon", "Kiryat Bialik"
]

# Map for special cases
special_cases = {
    'Hatzor Ashdod': 'Hatzor Ashdod',
    'Hevel Modi\'in': 'Hevel Modi\'in',
    'Modi\'in Illit': 'Modi\'in Illit',
    'Haifa - Kiryat Haim & Kiryat Shmuel': 'Haifa - Kiryat Haim & Kiryat Shmuel'
}

# Function to determine locality and district label
def map_to_locality_and_district(row):
    locality = row['locality']
    # Check if the locality is in special cases
    if locality in special_cases:
        return special_cases[locality], "all"
    # Check if the locality contains a major city name
    for city in major_cities_list:
        if city in locality:
            # Remove city name and clean up
            district = locality.replace(city, "").strip(" -")
            # Remove parentheses using regex
            district = re.sub(r'[()]', '', district).strip()
            return city, district  # Return city and cleaned district name
    # If not in major cities, mark it as its own locality with "all" zones
    return locality, "All"

# %%
# Step 1: Apply the mapping logic to determine locality and district
detailed_df[['locality', 'district']] = detailed_df.apply(
    lambda row: pd.Series(map_to_locality_and_district(row)), axis=1
)

# Step 2: Group by 'time' and 'locality', and aggregate zones
# First, create time groups to combine alerts within 2-minute windows
df_grouped = (
    detailed_df
    .sort_values(['locality', 'datetime'])  # Sort by time for correct grouping
    .assign(
        # Create groups: reset group counter when time difference > 2minutes
        time_group=lambda x: (
            x.groupby('locality')['datetime']
            .diff() > pd.Timedelta(minutes=2)
        ).cumsum()
    )
    .groupby(['locality', 'time_group'], as_index=False)
    .agg({
        'datetime': 'first',  # Take the time of the first alert in the group
        'district': lambda x: ', '.join(
            filter(None, [item.strip() for item in set(x) if item and item.strip()])
        ).strip(', '),  # Combine UNIQUE districts
        'region': 'first',
        'threat_type': 'first'
    })
    .drop('time_group', axis=1)  # Remove temporary column
)

# Then perform the original grouping by date and locality (with already combined data)
df = (
    df_grouped
    .groupby(['datetime', 'locality'])
    .agg({
        'district': lambda x: ', '.join(
            filter(None, [item.strip() for item in set(x) if item and item.strip()])
        ).strip(', '),
        'region': 'first',
        'threat_type': 'first'
    })
    .reset_index()
)

# %%
# Rename 'district' column for clarity
df.rename(columns={'district': 'zones'}, inplace=True)

# Step 3: Replace empty 'zones' with 'All'
df['zones'] = df['zones'].apply(lambda x: 'All' if not x.strip() else x)

# Step 4: Remove numbers from the 'region' column if locality is in major_cities_list
def clean_region(region, locality):
    if locality in major_cities_list:
        return re.sub(r'\d+', '', region).strip()
    return region

df['region'] = df.apply(lambda row: clean_region(row['region'], row['locality']), axis=1)

# %%
df
# Out:
#                  datetime                locality zones          region  \
# 0     2018-12-26 10:05:01                  Adanim   All      Sharon 143
# 1     2018-12-26 10:05:01                    Azur   All         Dan 162
# 2     2018-12-26 10:05:01                 Bat Yam   All         Dan 165
# 3     2018-12-26 10:05:01               Beit Berl   All      Sharon 141
# 4     2018-12-26 10:05:01               Bnei Brak   All         Dan 160
# ...                   ...                     ...   ...             ...
# 79665 2025-10-05 04:58:41                  Yish'i   All  Shfelat Yehuda
# 79666 2025-10-05 04:58:41                  Zanoah   All  Shfelat Yehuda
# 79667 2025-10-05 04:58:41                  Zeitan   All        HaShfela
# 79668 2025-10-05 04:58:41  Zrifin Industrial Zone   All        HaShfela
# 79669 2025-10-05 18:32:20                   Eilat   All           Eilat
#
#                  threat_type
# 0                  Red Alert
# 1                  Red Alert
# 2                  Red Alert
# 3                  Red Alert
# 4                  Red Alert
# ...                      ...
# 79665              Red Alert
# 79666              Red Alert
# 79667              Red Alert
# 79668              Red Alert
# 79669  Unrecognized Aircraft
#
# [79670 rows x 5 columns]

# %% [markdown]
# ### Checking the main cities in the final dataset

# %%
df[df['locality'] == 'Tel Aviv']
# Out:
#                  datetime  locality  \
# 49    2018-12-26 10:05:01  Tel Aviv
# 156   2019-03-14 21:05:33  Tel Aviv
# 4275  2021-05-11 20:46:26  Tel Aviv
# 4494  2021-05-11 20:50:59  Tel Aviv
# 4625  2021-05-11 20:58:52  Tel Aviv
# ...                   ...       ...
# 78283 2025-09-03 09:39:46  Tel Aviv
# 78675 2025-09-13 03:47:38  Tel Aviv
# 79150 2025-09-18 20:32:11  Tel Aviv
# 79367 2025-09-25 22:42:15  Tel Aviv
# 79501 2025-09-29 00:59:00  Tel Aviv
#
#                                                    zones region threat_type
# 49                South East, North, South West, Central    Dan   Red Alert
# 156                      South East, South West, Central    Dan   Red Alert
# 4275            South and Jaffa, Across the Yarkon, East    Dan   Red Alert
# 4494   South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# 4625   South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# ...                                                  ...    ...         ...
# 78283  South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# 78675  South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# 79150  South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# 79367  South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
# 79501  South and Jaffa, Across the Yarkon, City Cente...    Dan   Red Alert
#
# [174 rows x 5 columns]

# %%
df[df['locality'] == 'Haifa']
# Out:
#                  datetime locality  \
# 16556 2023-10-11 18:35:26    Haifa
# 22763 2024-01-19 20:45:09    Haifa
# 26824 2024-06-11 09:51:51    Haifa
# 30625 2024-09-23 17:41:38    Haifa
# 30747 2024-09-23 19:42:35    Haifa
# ...                   ...      ...
# 72908 2025-06-23 10:40:53    Haifa
# 73856 2025-06-24 05:13:00    Haifa
# 75154 2025-06-24 06:57:09    Haifa
# 75439 2025-06-24 07:17:13    Haifa
# 75607 2025-06-24 10:31:48    Haifa
#
#                                                    zones     region  \
# 16556  Downtown Lower City, Bay, Neveh Sha'anan, Carm...    Menashe
# 22763                  Downtown Lower City, West, Carmel    Menashe
# 26824                                               West    Menashe
# 30625                                                Bay    Menashe
# 30747  Hadar, Downtown Lower City, Bay, Neveh Sha'ana...    Menashe
# ...                                                  ...        ...
# 72908                                          West, Bay  HaMifratz
# 73856  Hadar, Downtown Lower City, Bay, Neveh Sha'ana...  HaMifratz
# 75154  Hadar, Downtown Lower City, Bay, Neveh Sha'ana...  HaMifratz
# 75439          Neveh Sha'anan, West, Ramot HaCarmel, Bay  HaMifratz
# 75607  Hadar, Downtown Lower City, Bay, Neveh Sha'ana...  HaMifratz
#
#                  threat_type
# 16556  Unrecognized Aircraft
# 22763              Red Alert
# 26824              Red Alert
# 30625              Red Alert
# 30747              Red Alert
# ...                      ...
# 72908              Red Alert
# 73856              Red Alert
# 75154              Red Alert
# 75439              Red Alert
# 75607              Red Alert
#
# [94 rows x 5 columns]

# %%
df[df['locality'] == "Modi'in"]
# Out:
#                  datetime locality  \
# 2748  2019-11-12 10:16:42  Modi'in
# 4410  2021-05-11 20:46:33  Modi'in
# 5086  2021-05-12 03:02:57  Modi'in
# 6076  2021-05-13 01:35:06  Modi'in
# 6586  2021-05-13 22:14:59  Modi'in
# ...                   ...      ...
# 78837 2025-09-16 18:51:38  Modi'in
# 78936 2025-09-18 20:32:06  Modi'in
# 79231 2025-09-25 22:42:12  Modi'in
# 79469 2025-09-29 00:59:00  Modi'in
# 79618 2025-10-05 04:58:41  Modi'in
#
#                                                    zones  \
# 2748                                       Ishpro Center
# 4410                                       Ishpro Center
# 5086                                        Ligad Center
# 6076                         Ishpro Center, Ligad Center
# 6586                                        Ligad Center
# ...                                                  ...
# 78837  Ishpro Center, Maccabim Re'ut, Regional Counci...
# 78936  Ishpro Center, Maccabim Re'ut, Regional Counci...
# 79231            Regional Council Hevel  Industrial Park
# 79469  Ishpro Center, Maccabim Re'ut, Regional Counci...
# 79618  Maccabim Re'ut, Regional Council Hevel  Indust...
#
#                       region threat_type
# 2748   Gaza Containment Zone   Red Alert
# 4410       Shfela (Lowlands)   Red Alert
# 5086       Shfela (Lowlands)   Red Alert
# 6076       Shfela (Lowlands)   Red Alert
# 6586       Shfela (Lowlands)   Red Alert
# ...                      ...         ...
# 78837               HaShfela   Red Alert
# 78936               HaShfela   Red Alert
# 79231               HaShfela   Red Alert
# 79469               HaShfela   Red Alert
# 79618               HaShfela   Red Alert
#
# [109 rows x 5 columns]

# %%
df[df['locality'] == 'Hadera']
# Out:
#                  datetime locality                           zones   region  \
# 2417  2019-07-31 10:10:03   Hadera                            East  Menashe
# 2418  2019-07-31 10:15:05   Hadera                          Center  Menashe
# 2419  2019-07-31 10:20:05   Hadera                      Neveh Haim  Menashe
# 2420  2019-07-31 10:25:02   Hadera                            West  Menashe
# 9922  2021-11-03 18:05:03   Hadera                            West  Menashe
# 9927  2021-11-03 18:15:02   Hadera                      Neveh Haim  Menashe
# 9932  2021-11-03 18:25:01   Hadera                          Center  Menashe
# 33287 2024-10-01 19:34:14   Hadera  Center, West, Neveh Haim, East  Menashe
# 34178 2024-10-01 19:39:44   Hadera  Center, West, Neveh Haim, East  Menashe
# 34902 2024-10-01 19:44:21   Hadera              Center, West, East  Menashe
# 35044 2024-10-01 19:50:19   Hadera  Center, West, Neveh Haim, East  Menashe
# 37007 2024-10-06 08:28:39   Hadera                      Neveh Haim  Menashe
# 38814 2024-10-14 17:33:29   Hadera                    Center, East  Menashe
# 38920 2024-10-14 17:36:07   Hadera  Center, West, Neveh Haim, East  Menashe
# 42016 2024-10-30 06:17:15   Hadera                    Center, East  Menashe
# 42207 2024-10-30 17:56:57   Hadera                    Center, East  Menashe
# 44246 2024-11-13 17:44:28   Hadera  Center, West, Neveh Haim, East  Menashe
# 44928 2024-11-19 08:53:59   Hadera                    Center, East  Menashe
# 45459 2024-11-24 07:27:04   Hadera                    Center, East  Menashe
# 45878 2024-11-24 18:47:11   Hadera                            East  Menashe
# 46149 2024-11-26 22:14:33   Hadera                    Center, East  Menashe
# 57115 2025-06-14 01:12:14   Hadera  Center, West, Neveh Haim, East  Menashe
# 60738 2025-06-15 16:12:03   Hadera  Center, West, Neveh Haim, East  Menashe
# 62966 2025-06-16 04:12:32   Hadera              Center, Neveh Haim  Menashe
# 63473 2025-06-16 11:03:39   Hadera              Center, Neveh Haim  Menashe
# 65590 2025-06-18 00:42:11   Hadera                            West  Menashe
# 66969 2025-06-19 07:11:59   Hadera  Center, West, Neveh Haim, East  Menashe
# 68838 2025-06-20 15:42:42   Hadera  Center, West, Neveh Haim, East  Menashe
# 70851 2025-06-22 07:37:14   Hadera  Center, West, Neveh Haim, East  Menashe
# 74874 2025-06-24 06:40:51   Hadera  Center, West, Neveh Haim, East  Menashe
# 75316 2025-06-24 07:15:12   Hadera  Center, West, Neveh Haim, East  Menashe
#
#                  threat_type
# 2417               Red Alert
# 2418               Red Alert
# 2419               Red Alert
# 2420               Red Alert
# 9922               Red Alert
# 9927               Red Alert
# 9932               Red Alert
# 33287              Red Alert
# 34178              Red Alert
# 34902              Red Alert
# 35044              Red Alert
# 37007              Red Alert
# 38814              Red Alert
# 38920              Red Alert
# 42016              Red Alert
# 42207              Red Alert
# 44246              Red Alert
# 44928              Red Alert
# 45459              Red Alert
# 45878              Red Alert
# 46149              Red Alert
# 57115              Red Alert
# 60738              Red Alert
# 62966              Red Alert
# 63473  Unrecognized Aircraft
# 65590              Red Alert
# 66969              Red Alert
# 68838              Red Alert
# 70851              Red Alert
# 74874              Red Alert
# 75316              Red Alert

# %%
df[df['locality'] == 'Caesarea']
# Out:
#                  datetime  locality                           zones   region  \
# 2348  2019-07-31 10:05:05  Caesarea  Industrial Zone, Marine Center  Menashe
# 33363 2024-10-01 19:34:17  Caesarea  Industrial Zone, Marine Center  Menashe
# 34363 2024-10-01 19:39:47  Caesarea  Marine Center, Industrial Zone  Menashe
# 35032 2024-10-01 19:50:19  Caesarea  Industrial Zone, Marine Center  Menashe
# 36684 2024-10-04 10:49:20  Caesarea                   Marine Center  Menashe
# 37006 2024-10-06 08:28:39  Caesarea  Marine Center, Industrial Zone  Menashe
# 37769 2024-10-09 08:26:38  Caesarea                   Marine Center  Menashe
# 38879 2024-10-14 17:34:59  Caesarea                 Industrial Zone  Menashe
# 39027 2024-10-15 07:27:06  Caesarea  Industrial Zone, Marine Center  Menashe
# 40401 2024-10-22 07:43:18  Caesarea                   Marine Center  Menashe
# 41045 2024-10-25 06:46:58  Caesarea  Industrial Zone, Marine Center  Menashe
# 44229 2024-11-13 17:44:28  Caesarea                 Industrial Zone  Menashe
# 44455 2024-11-14 19:15:51  Caesarea                             All  Menashe
# 45457 2024-11-24 07:27:04  Caesarea                 Industrial Zone  Menashe
# 46223 2024-11-26 22:16:54  Caesarea                 Industrial Zone  Menashe
# 56902 2025-06-14 01:12:14  Caesarea  Industrial Zone, Marine Center  Menashe
# 60715 2025-06-15 16:12:03  Caesarea  Industrial Zone, Marine Center  Menashe
# 62987 2025-06-16 04:12:36  Caesarea  Industrial Zone, Marine Center  Menashe
# 63466 2025-06-16 11:02:28  Caesarea  Industrial Zone, Marine Center  Menashe
# 64329 2025-06-17 04:33:45  Caesarea                   Marine Center  Menashe
# 66956 2025-06-19 07:11:59  Caesarea  Marine Center, Industrial Zone  Menashe
# 68835 2025-06-20 15:42:42  Caesarea  Marine Center, Industrial Zone  Menashe
# 70848 2025-06-22 07:37:14  Caesarea  Marine Center, Industrial Zone  Menashe
# 74914 2025-06-24 06:40:52  Caesarea  Marine Center, Industrial Zone  Menashe
# 75290 2025-06-24 07:15:12  Caesarea  Industrial Zone, Marine Center  Menashe
#
#                  threat_type
# 2348               Red Alert
# 33363              Red Alert
# 34363              Red Alert
# 35032              Red Alert
# 36684              Red Alert
# 37006              Red Alert
# 37769              Red Alert
# 38879              Red Alert
# 39027              Red Alert
# 40401              Red Alert
# 41045              Red Alert
# 44229              Red Alert
# 44455  Unrecognized Aircraft
# 45457              Red Alert
# 46223              Red Alert
# 56902              Red Alert
# 60715              Red Alert
# 62987              Red Alert
# 63466  Unrecognized Aircraft
# 64329              Red Alert
# 66956              Red Alert
# 68835              Red Alert
# 70848              Red Alert
# 74914              Red Alert
# 75290              Red Alert

# %%
df[df['locality'] == 'Ramat Gan']
# Out:
#                  datetime   locality  \
# 42    2018-12-26 10:05:01  Ramat Gan
# 155   2019-03-14 21:05:33  Ramat Gan
# 4341  2021-05-11 20:46:29  Ramat Gan
# 4561  2021-05-11 20:51:34  Ramat Gan
# 4620  2021-05-11 20:58:52  Ramat Gan
# ...                   ...        ...
# 78661 2025-09-13 03:47:38  Ramat Gan
# 78865 2025-09-16 18:51:38  Ramat Gan
# 78944 2025-09-18 20:32:06  Ramat Gan
# 79237 2025-09-25 22:42:12  Ramat Gan
# 79488 2025-09-29 00:59:00  Ramat Gan
#
#                                                  zones region threat_type
# 42     Bar Ilan University, Ramat Ef'al & Tel Hashomer    Dan   Red Alert
# 155                                                All    Dan   Red Alert
# 4341                                        West, East    Dan   Red Alert
# 4561                                        West, East    Dan   Red Alert
# 4620                                        West, East    Dan   Red Alert
# ...                                                ...    ...         ...
# 78661                                       West, East    Dan   Red Alert
# 78865                                             East    Dan   Red Alert
# 78944                                       West, East    Dan   Red Alert
# 79237                                       West, East    Dan   Red Alert
# 79488                                       West, East    Dan   Red Alert
#
# [156 rows x 5 columns]

# %%
df[df['locality'] == 'Beer Sheva']
# Out:
#                  datetime    locality                     zones  \
# 3270  2019-11-16 01:56:58  Beer Sheva  North, West, East, South
# 4807  2021-05-12 02:49:32  Beer Sheva  North, West, East, South
# 4914  2021-05-12 02:55:56  Beer Sheva  North, West, East, South
# 5098  2021-05-12 03:03:28  Beer Sheva  North, West, East, South
# 5168  2021-05-12 03:09:00  Beer Sheva  North, West, East, South
# ...                   ...         ...                       ...
# 68223 2025-06-20 05:51:39  Beer Sheva  North, West, East, South
# 68532 2025-06-20 15:40:18  Beer Sheva  North, West, East, South
# 69097 2025-06-20 15:44:15  Beer Sheva  North, West, East, South
# 74210 2025-06-24 05:40:09  Beer Sheva  North, West, East, South
# 75917 2025-06-28 07:10:34  Beer Sheva  North, West, East, South
#
#               region threat_type
# 3270   Central Negev   Red Alert
# 4807   Central Negev   Red Alert
# 4914   Central Negev   Red Alert
# 5098   Central Negev   Red Alert
# 5168   Central Negev   Red Alert
# ...              ...         ...
# 68223   Center Negev   Red Alert
# 68532   Center Negev   Red Alert
# 69097  Central Negev   Red Alert
# 74210   Center Negev   Red Alert
# 75917   Center Negev   Red Alert
#
# [122 rows x 5 columns]

# %%
df[df['locality'] == 'Rishon LeZion']
# Out:
#                  datetime       locality       zones             region  \
# 2538  2019-11-12 07:05:25  Rishon LeZion        West  Shfela (Lowlands)
# 2598  2019-11-12 08:00:35  Rishon LeZion        West  Shfela (Lowlands)
# 2673  2019-11-12 09:11:04  Rishon LeZion  West, East  Shfela (Lowlands)
# 4274  2021-05-11 20:46:26  Rishon LeZion  West, East  Shfela (Lowlands)
# 4459  2021-05-11 20:50:14  Rishon LeZion  West, East  Shfela (Lowlands)
# ...                   ...            ...         ...                ...
# 78871 2025-09-16 18:51:38  Rishon LeZion        East           HaShfela
# 78949 2025-09-18 20:32:06  Rishon LeZion  West, East           HaShfela
# 79242 2025-09-25 22:42:12  Rishon LeZion  West, East           HaShfela
# 79495 2025-09-29 00:59:00  Rishon LeZion  West, East           HaShfela
# 79644 2025-10-05 04:58:41  Rishon LeZion        East           HaShfela
#
#       threat_type
# 2538    Red Alert
# 2598    Red Alert
# 2673    Red Alert
# 4274    Red Alert
# 4459    Red Alert
# ...           ...
# 78871   Red Alert
# 78949   Red Alert
# 79242   Red Alert
# 79495   Red Alert
# 79644   Red Alert
#
# [213 rows x 5 columns]

# %%
df[df['locality'] == 'Ashdod']
# Out:
#                  datetime locality  \
# 605   2019-05-04 10:19:47   Ashdod
# 822   2019-05-04 15:23:29   Ashdod
# 1139  2019-05-04 21:57:37   Ashdod
# 1167  2019-05-04 22:41:20   Ashdod
# 1187  2019-05-04 22:47:06   Ashdod
# ...                   ...      ...
# 72451 2025-06-23 10:27:57   Ashdod
# 73169 2025-06-23 10:46:16   Ashdod
# 76832 2025-07-22 05:50:09   Ashdod
# 79174 2025-09-21 10:01:16   Ashdod
# 79515 2025-10-01 20:48:40   Ashdod
#
#                                                    zones   region threat_type
# 605                                                  All  Lakhish   Red Alert
# 822                                                  All  Lakhish   Red Alert
# 1139                                                 All  Lakhish   Red Alert
# 1167                                                 All  Lakhish   Red Alert
# 1187                                                 All  Lakhish   Red Alert
# ...                                                  ...      ...         ...
# 72451  Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Ale...  Lachish   Red Alert
# 73169  Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Ale...  Lachish   Red Alert
# 76832  Alef, Bet, Dalet, Heh, 11, 12, 15, 17, Marine,...  Lachish   Red Alert
# 79174  Het, Tet, Yod, Yod Gimmel, Yod Dalet, Te*, Gim...  Lachish   Red Alert
# 79515  Alef, Bet, Dalet, Heh, 11, 12, 15, 17, Marine,...  Lachish   Red Alert
#
# [232 rows x 5 columns]

# %%
df[df['locality'] == 'Ashkelon']
# Out:
#                  datetime  locality  \
# 80    2019-01-07 03:18:50  Ashkelon
# 359   2019-03-26 01:32:56  Ashkelon
# 362   2019-03-26 01:55:24  Ashkelon
# 383   2019-03-26 23:37:40  Ashkelon
# 384   2019-03-27 03:57:23  Ashkelon
# ...                   ...       ...
# 69062 2025-06-20 15:44:15  Ashkelon
# 71409 2025-06-22 07:42:11  Ashkelon
# 72535 2025-06-23 10:28:35  Ashkelon
# 73089 2025-06-23 10:45:44  Ashkelon
# 79172 2025-09-20 19:08:26  Ashkelon
#
#                                                    zones        region  \
# 80                                                   All       Lakhish
# 359                                      Industrial Area       Lakhish
# 362                                      Industrial Area       Lakhish
# 383                                      Industrial Area       Lakhish
# 384                                      Industrial Area       Lakhish
# ...                                                  ...           ...
# 69062  North, Industrial Area, South, Northern Indust...       Lakhish
# 71409             North, Northern Industrial Zone, South  West Lachish
# 72535                    North, Northern Industrial Zone  West Lachish
# 73089  North, Northern Industrial Zone, Southern Indu...  West Lachish
# 79172                           Southern Industrial Zone  West Lachish
#
#       threat_type
# 80      Red Alert
# 359     Red Alert
# 362     Red Alert
# 383     Red Alert
# 384     Red Alert
# ...           ...
# 69062   Red Alert
# 71409   Red Alert
# 72535   Red Alert
# 73089   Red Alert
# 79172   Red Alert
#
# [551 rows x 5 columns]

# %%
df[df['locality'] == 'Herzeliya']
# Out:
#                  datetime   locality                         zones  region  \
# 17    2018-12-26 10:05:01  Herzeliya                           All     Dan
# 4331  2021-05-11 20:46:29  Herzeliya  Center and Glil Yam, Pituach  Sharon
# 4491  2021-05-11 20:50:59  Herzeliya  Center and Glil Yam, Pituach  Sharon
# 4652  2021-05-11 21:00:50  Herzeliya  Center and Glil Yam, Pituach  Sharon
# 4681  2021-05-11 21:08:19  Herzeliya  Center and Glil Yam, Pituach  Sharon
# ...                   ...        ...                           ...     ...
# 77960 2025-08-22 20:59:34  Herzeliya     Center and Glil Yam, West     Dan
# 78343 2025-09-03 09:39:52  Herzeliya     Center and Glil Yam, West     Dan
# 78629 2025-09-13 03:47:38  Herzeliya     Center and Glil Yam, West     Dan
# 79036 2025-09-18 20:32:11  Herzeliya     Center and Glil Yam, West     Dan
# 79297 2025-09-25 22:42:15  Herzeliya     Center and Glil Yam, West     Dan
#
#       threat_type
# 17      Red Alert
# 4331    Red Alert
# 4491    Red Alert
# 4652    Red Alert
# 4681    Red Alert
# ...           ...
# 77960   Red Alert
# 78343   Red Alert
# 78629   Red Alert
# 79036   Red Alert
# 79297   Red Alert
#
# [102 rows x 5 columns]

# %% [markdown]
# Сhecking if the dataset contains the words 'Herzliya' instead of 'Herzeliya'

# %%
df[df['locality'] == 'Herzliya']
# Out:
# Empty DataFrame
# Columns: [datetime, locality, zones, region, threat_type]
# Index: []

# %% [markdown]
# Everything is OK now

# %%
df[df['locality'] == "Ra'anana"]
# Out:
#                  datetime  locality zones  region threat_type
# 4416  2021-05-11 20:46:33  Ra'anana   All  Sharon   Red Alert
# 4657  2021-05-11 21:00:50  Ra'anana   All  Sharon   Red Alert
# 4683  2021-05-11 21:08:19  Ra'anana   All  Sharon   Red Alert
# 4716  2021-05-11 21:15:07  Ra'anana   All  Sharon   Red Alert
# 4859  2021-05-12 02:50:14  Ra'anana   All  Sharon   Red Alert
# ...                   ...       ...   ...     ...         ...
# 77819 2025-08-17 16:16:14  Ra'anana   All  Sharon   Red Alert
# 78032 2025-08-22 20:59:34  Ra'anana   All  Sharon   Red Alert
# 78244 2025-09-03 09:39:43  Ra'anana   All  Sharon   Red Alert
# 78943 2025-09-18 20:32:06  Ra'anana   All  Sharon   Red Alert
# 79236 2025-09-25 22:42:12  Ra'anana   All  Sharon   Red Alert
#
# [84 rows x 5 columns]

# %%
df[df['locality'] == 'Jerusalem']
# Out:
#                  datetime   locality  \
# 102   2019-02-06 10:04:58  Jerusalem
# 3638  2021-05-10 18:03:07  Jerusalem
# 9923  2021-11-03 18:05:03  Jerusalem
# 9929  2021-11-03 18:15:02  Jerusalem
# 9933  2021-11-03 18:25:01  Jerusalem
# ...                   ...        ...
# 77726 2025-08-17 16:16:14  Jerusalem
# 78120 2025-08-27 05:30:40  Jerusalem
# 78514 2025-09-09 20:05:56  Jerusalem
# 78797 2025-09-16 18:51:38  Jerusalem
# 79043 2025-09-18 20:32:11  Jerusalem
#
#                                                    zones     region  \
# 102                                                  All  Jerusalem
# 3638                              North and Alonim, East  Jerusalem
# 9923                                               North  Jerusalem
# 9929     East, Qafr 'Aqab, Atarot Industrial Zone, South  Jerusalem
# 9933                                 Center, North, East  Jerusalem
# ...                                                  ...        ...
# 77726                                               West  Jerusalem
# 78120  Center, East, North, Atarot Industrial Zone, S...  Jerusalem
# 78514                   Center, East, North, South, West  Jerusalem
# 78797  Center, East, North, Atarot Industrial Zone, S...  Jerusalem
# 79043                                 North, West, South  Jerusalem
#
#       threat_type
# 102     Red Alert
# 3638    Red Alert
# 9923    Red Alert
# 9929    Red Alert
# 9933    Red Alert
# ...           ...
# 77726   Red Alert
# 78120   Red Alert
# 78514   Red Alert
# 78797   Red Alert
# 79043   Red Alert
#
# [65 rows x 5 columns]

# %%
df[df['locality'] == 'Netanya']
# Out:
#                  datetime locality       zones  region threat_type
# 4338  2021-05-11 20:46:29  Netanya  West, East  Sharon   Red Alert
# 4493  2021-05-11 20:50:59  Netanya  West, East  Sharon   Red Alert
# 9938  2021-11-03 18:35:02  Netanya        West  Sharon   Red Alert
# 31142 2024-09-25 06:32:25  Netanya  West, East  Sharon   Red Alert
# 33466 2024-10-01 19:34:17  Netanya  West, East  Sharon   Red Alert
# 34298 2024-10-01 19:39:45  Netanya  West, East  Sharon   Red Alert
# 35399 2024-10-01 19:50:22  Netanya  West, East  Sharon   Red Alert
# 38605 2024-10-14 11:19:26  Netanya  West, East  Sharon   Red Alert
# 38799 2024-10-14 17:33:28  Netanya  West, East  Sharon   Red Alert
# 38929 2024-10-14 17:36:29  Netanya  West, East  Sharon   Red Alert
# 40888 2024-10-23 20:33:22  Netanya        West  Sharon   Red Alert
# 42041 2024-10-30 06:17:26  Netanya  West, East  Sharon   Red Alert
# 43021 2024-11-06 11:21:25  Netanya        East  Sharon   Red Alert
# 44263 2024-11-13 17:44:28  Netanya  West, East  Sharon   Red Alert
# 44840 2024-11-18 20:46:44  Netanya  West, East  Sharon   Red Alert
# 44937 2024-11-19 08:54:07  Netanya        East  Sharon   Red Alert
# 45466 2024-11-24 07:27:16  Netanya  West, East  Sharon   Red Alert
# 49419 2025-03-23 07:23:22  Netanya  West, East  Sharon   Red Alert
# 51634 2025-05-04 09:22:19  Netanya  West, East  Sharon   Red Alert
# 51853 2025-05-09 16:24:35  Netanya  West, East  Sharon   Red Alert
# 52718 2025-05-18 02:02:33  Netanya        West  Sharon   Red Alert
# 53301 2025-05-29 21:21:59  Netanya        West  Sharon   Red Alert
# 54049 2025-06-03 21:57:11  Netanya  West, East  Sharon   Red Alert
# 55461 2025-06-13 21:41:17  Netanya  West, East  Sharon   Red Alert
# 56484 2025-06-14 01:09:47  Netanya  West, East  Sharon   Red Alert
# 58665 2025-06-14 05:12:09  Netanya  West, East  Sharon   Red Alert
# 59847 2025-06-15 02:42:41  Netanya  West, East  Sharon   Red Alert
# 60596 2025-06-15 16:09:18  Netanya  West, East  Sharon   Red Alert
# 61809 2025-06-15 20:42:09  Netanya  West, East  Sharon   Red Alert
# 62790 2025-06-16 04:12:11  Netanya  West, East  Sharon   Red Alert
# 64782 2025-06-17 17:15:13  Netanya  West, East  Sharon   Red Alert
# 65595 2025-06-18 00:42:11  Netanya  West, East  Sharon   Red Alert
# 66141 2025-06-18 01:27:22  Netanya  West, East  Sharon   Red Alert
# 66928 2025-06-19 07:11:55  Netanya  West, East  Sharon   Red Alert
# 68860 2025-06-20 15:42:43  Netanya  West, East  Sharon   Red Alert
# 70339 2025-06-21 02:39:51  Netanya  West, East  Sharon   Red Alert
# 70950 2025-06-22 07:37:19  Netanya        West  Sharon   Red Alert
# 71360 2025-06-22 07:41:26  Netanya        East  Sharon   Red Alert
# 74137 2025-06-24 05:39:26  Netanya  West, East  Sharon   Red Alert
# 74532 2025-06-24 06:15:45  Netanya  West, East  Sharon   Red Alert
# 74760 2025-06-24 06:39:56  Netanya  West, East  Sharon   Red Alert
# 75353 2025-06-24 07:15:12  Netanya  West, East  Sharon   Red Alert
# 77797 2025-08-17 16:16:14  Netanya  West, East  Sharon   Red Alert
# 78013 2025-08-22 20:59:34  Netanya  West, East  Sharon   Red Alert
# 78237 2025-09-03 09:39:43  Netanya  West, East  Sharon   Red Alert

# %%
df[df['locality'] == 'Petah Tikva']
# Out:
#                  datetime     locality zones  region threat_type
# 4351  2021-05-11 20:46:30  Petah Tikva   All  Yarkon   Red Alert
# 4560  2021-05-11 20:51:34  Petah Tikva   All  Yarkon   Red Alert
# 4619  2021-05-11 20:58:52  Petah Tikva   All  Yarkon   Red Alert
# 4734  2021-05-11 21:15:23  Petah Tikva   All  Yarkon   Red Alert
# 4996  2021-05-12 03:00:25  Petah Tikva   All  Yarkon   Red Alert
# ...                   ...          ...   ...     ...         ...
# 78243 2025-09-03 09:39:43  Petah Tikva   All     Dan   Red Alert
# 78660 2025-09-13 03:47:38  Petah Tikva   All     Dan   Red Alert
# 78942 2025-09-18 20:32:06  Petah Tikva   All     Dan   Red Alert
# 79235 2025-09-25 22:42:12  Petah Tikva   All     Dan   Red Alert
# 79486 2025-09-29 00:59:00  Petah Tikva   All     Dan   Red Alert
#
# [127 rows x 5 columns]

# %% [markdown]
# ⚠ **WARNING!** ⚠
# Some localities may refer to different original regions at different times (for example: Herzliya may be attributed to Sharon and Dan, Petah Tikva to Yarkon and Dan). This is due to changes in the data in the telegram channel.

# %% [markdown]
# ### Checking for duplicates

# %%
print('Number of duplicates:', df.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79670 entries, 0 to 79669
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     79670 non-null  datetime64[ns]
#  1   locality     79670 non-null  object
#  2   zones        79670 non-null  object
#  3   region       79670 non-null  object
#  4   threat_type  79670 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ### Saving the dataframe

# %%
df.to_csv('cumta_df.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Conclusion
# **Data Preprocessing**:
#
# - Initially, we constructed a dataframe where each row corresponded to a single message from the Telegram channel. Each message contained information about warnings spanning several minutes.
# - Next, we transformed the dataframe so that each row represented a locality. We then merged zones of major cities, assigning the city name to the `'locality'` column, while district names were stored in the `'zones'` column.
# - If a locality was not a major city, the `'zones'` column was set to `'All`'
#
# **Final Processed Dataframe:**
#
# - **Total rows:** 79670
# - **Duplicates:** None
# - **Time column (`'time'`):** Converted to `datetime64[ns]` format
# - **Missing value** None
#
# **Columns:**
#
# | Column Name | Description |
# |-------------|------------|
# | **datetime** | Date and time of the warning in `datetime64[ns]` format |
# | **locality** | Name of the locality (city, town, or settlement) |
# | **zones** | Zones within a locality. If the locality is not a major city, this column contains `'All'` |
# | **region** | Region to which the locality belongs |
# | **threat_type** | Type of warning. Possible values: `'Red Alert'`, `'Unrecognized Aircraft'`, `'Terrorist Infiltration'`, `'Interception Pieces'`, `'Earthquake'` |
# | **district** | Administrative district or region where the locality is located; an official governmental division. |
#
# This structured dataset is now ready for further analysis and visualization.
